# %% [markdown]
# <a href="https://colab.research.google.com/github/kundajelab/adar_editing/blob/master/xgboost_with_shap/CROSS_SUBSTRATE_TRAINING_XGBOOST_WITH_TREESHAP_TRAIN_NEIL1_AND_AJUBA_PREDICT_TTYH2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Uncomment these lines if running as a google colab notebook: 
#!pip install numpy==1.15
#! git clone https://github.com/kundajelab/adar_editing
#import os
#os.chdir("adar_editing/xgboost_with_shap/")
#!pip install shap
#!pip install --upgrade xgboost
#!pip install cufflinks
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#helper utilities for model training and interpretation 
import shap
import sys 
sys.path.append('..')

from helpers import * 

#set a random seed so code is reproducible 
random.seed(1234)

# load JS visualization code to notebook
shap.initjs()
import warnings
warnings.filterwarnings('ignore')

#visualization utilities 
import matplotlib
import matplotlib.pyplot as plt 
# %matplotlib inline
import chart_studio.plotly as plotly
import numpy as np
from plotly.offline import iplot
from plotly.graph_objs import Heatmap

import feature_subsets
import xgboost
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
## Load all the datasets : TTYH2
ttyh2_comp=pd.read_csv("../../xin_feature_matrices/ttyh2_computational.features.csv",header=0,sep=',',index_col=0)
#remove any null editing level values 
ttyh2_comp=ttyh2_comp[~ttyh2_comp["editing_value"].isnull().values]
ttyh2_comp=format_for_xgboost(ttyh2_comp)
# Out:
# (601, 205)

# %%
## Load all the datasets: NEIL1
neil1_comp=pd.read_csv("../../xin_feature_matrices/neil1_computational.features.csv",header=0,sep=',',index_col=0)
#remove any null editing level values 
neil1_comp=neil1_comp[~neil1_comp["editing_value"].isnull().values]
neil1_comp=format_for_xgboost(neil1_comp)
# Out:
# (432, 202)

# %%
## Load all the dtasets: AJUBA
ajuba_comp=pd.read_csv("../../xin_feature_matrices/ajuba_bc_computational.features.csv",header=0,sep=',',index_col=0)
#remove any null editing level values 
ajuba_comp=ajuba_comp[~ajuba_comp["editing_value"].isnull().values]
ajuba_comp=format_for_xgboost(ajuba_comp)
# Out:
# (482, 195)

# %%
random.seed(1234)
train_split,eval_split=split_train_eval_by_mut_pos(ajuba_comp[~ajuba_comp['mut_pos'].isna()])
null_mut_pos=train_split[train_split['mut_pos'].isna()]
train_split=pd.concat((train_split,null_mut_pos),axis=0)
# Out:
# {64.0: 22, 65.0: 21, 66.0: 22, 67.0: 22, 68.0: 22, 69.0: 23, 70.0: 23, 71.0: 24, 72.0: 23, 73.0: 33, 75.0: 33, 76.0: 24, 77.0: 24, 78.0: 23, 79.0: 23, 80.0: 22, 81.0: 22, 82.0: 22, 83.0: 44}

# %% [markdown]
# ## Train AJUBA, predict NEIL1

# %%
test_split=neil1_comp

# %%
train_split.reset_index(inplace=True, drop=True) 
eval_split.reset_index(inplace=True,drop=True)
test_split.reset_index(inplace=True,drop=True)

# %%
#Remove any non-varying features 
train_novar=get_singleval_features(train_split)
eval_novar=get_singleval_features(eval_split)
test_novar=get_singleval_features(test_split)
uniform_features_to_drop=list(set(train_novar+eval_novar+test_novar))

# %%
#Remove any null features 
train_null=get_high_missingness_features(train_split)
eval_null=get_high_missingness_features(eval_split)
test_null=get_high_missingness_features(test_split)
null_features_to_drop=list(set(train_null+eval_null+test_null))

# %%
to_drop=list(set(uniform_features_to_drop+null_features_to_drop))
print("\n".join(to_drop))
# Out:
# u1_5prm_cp_bulge
# d1_exist
# d3_length_internal_es
# u1_3prm_cp_bulge
# d1_length_bulge
# d3_5prm_cp_hairpin
# d1_struct:S
# u3_3prm_cp_internal:U:A
# site_5prm_cp_hairpin
# u3_length_internal_ecs
# site_length_bulge
# mut_exist
# u1_length_internal_ecs
# d2_3prm_cp_bulge:G:U
# u1_5prm_cp_hairpin
# u3_length_hairpin
# d2_exist
# u3_3prm_cp_internal
# site_length_stem
# site_next_nt:U
# d1_5prm_cp_bulge
# u3_3prm_cp_bulge:U:A
# mut_type:indel
# site_next_struct:S
# u3_5prm_cp_internal
# u1_distance
# u3_5prm_cp_hairpin
# d2_3prm_cp_internal:C:G
# u1_length_bulge
# d1_length_hairpin
# d1_5prm_cp_internal
# u2_5prm_cp_internal:C:G
# d3_length_bulge
# mut_prev_struct:H
# mut_same_as_site
# u2_3prm_cp_bulge:C:G
# u1_length_internal_es
# u2_5prm_cp_bulge:U:A
# u1_5prm_cp_internal
# d1_length_internal_ecs
# site_prev_nt:U
# u2_exist
# d1_3prm_cp_bulge
# d3_length_hairpin
# u3_5prm_cp_internal:G:C
# mut_ref_nt:G
# site_prev_nt:A
# u2_length_stem
# d1_length_internal_es
# d2_3prm_cp_internal:U:A
# d3_5prm_cp_internal
# site_next_nt:A
# mut_type:mismatch
# d2_5prm_cp_hairpin
# d3_5prm_cp_bulge
# u3_length_internal_es
# site_5prm_cp_bulge:C:G
# site_3prm_cp_bulge:A:U
# d1_5prm_cp_hairpin
# d3_3prm_cp_internal
# d2_3prm_cp_internal:A:U
# site_length_hairpin
# d2_5prm_cp_bulge:A:U
# d2_5prm_cp_bulge:G:U
# u2_length_internal_es
# d3_struct:S
# d3_length_internal_ecs
# u3_length_stem
# u3_length_bulge
# d2_5prm_cp_bulge:C:G
# u2_3prm_cp_bulge:G:C
# mut_ref_nt:A
# u3_exist
# d2_length_stem
# d1_3prm_cp_internal
# u3_length
# u1_length_hairpin
# u2_5prm_cp_bulge:G:C
# d2_length_bulge
# site_prev_struct:S
# d2_length_hairpin
# u3_3prm_cp_bulge
# u1_3prm_cp_internal
# d1_distance
# u2_length_internal_ecs
# u2_length_bulge
# u1_exist
# mut_type:wt
# d3_3prm_cp_bulge
# u2_length_hairpin
# d3_exist
# u3_5prm_cp_bulge
# u2_5prm_cp_hairpin

# %%
#remove teh features that don't change across isoforms , or are null for all isoforms
for cur_to_drop in to_drop: 
    try:
        train_split=train_split.drop(cur_to_drop,axis=1)
    except: 
        pass
    try:
        eval_split=eval_split.drop(cur_to_drop,axis=1)
    except: 
        pass 
    try:
        test_split=test_split.drop(to_drop,axis=1)
    except: 
        pass

# %%
train_y=train_split['editing_value']
train_X=train_split.drop(['editing_value'],axis=1)
eval_y=eval_split['editing_value']
eval_X=eval_split.drop(['editing_value'],axis=1)
test_y=test_split['editing_value']
test_X=test_split.drop(['editing_value'],axis=1)

# %%
print(train_X.shape)
print(train_y.shape)
print(eval_X.shape)
print(eval_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (361, 109)
# (361,)
# (89, 109)
# (89,)
# (432, 201)
# (432,)

# %%
train_cols=set(train_X.columns)
eval_cols=set(eval_X.columns)
test_cols=set(test_X.columns)

# %%
common=train_cols.intersection(eval_cols)
common=list(common.intersection(test_cols))
print(common)
train_X=train_X[common]
eval_X=eval_X[common]
test_X=test_X[common]
print(train_X.shape)
print(train_y.shape)
print(eval_X.shape)
print(eval_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# ['d2_5prm_cp_bulge:G:C', 'site_1_1:A:C', 'u1_length', 'num_mutations', 'u2_distance', 'u2_5prm_cp_bulge:C:G', 'mut_nt:G', 'd2_length', 'u3_distance', 'd2_length_internal_es', 'mut_ref_struct:I', 'site_length_internal_ecs', 'site_prev_nt:C', 'site_length', 'u2_struct:I', 'u1_length_stem', 'mut_ref_nt:U', 'minimum_free_energy', 'd2_struct:I', 'sim_nor_score', 'd2_3prm_cp_internal:G:U', 'mut_next_struct:B', 'site_struct:I', 'd1_length_stem', 'mut_struct:I', 'd2_5prm_cp_internal:G:C', 'd_all_stem_length', 'site_3prm_cp_bulge:G:C', 'u1_struct:S', 'd2_5prm_cp_internal:U:G', 'd2_5prm_cp_internal:A:U', 'd3_length', 'mfe_frequency', 'site_struct:B', 'd2_5prm_cp_bulge:U:G', 'd2_3prm_cp_bulge:U:A', 'd_count', 'd2_length_internal_ecs', 'site_5prm_cp_internal:U:G', 'mut_nt:A', 'all_stem_length', 'mut_nt:C', 'site_3prm_cp_internal:G:C', 'u2_5prm_cp_internal:G:C', 'mut_struct:S', 'u2_3prm_cp_internal:G:C', 'mut_struct:B', 'probability_active_conf', 'd1_length', 'u_count', 'mut_nt:U', 'u2_length', 'mut_ref_struct:S', 'd2_distance', 'mut_prev_struct:I', 'site_struct:S', 'ensemble_diversity', 'd2_3prm_cp_bulge:C:G', 'd2_struct:B', 'mut_prev_struct:S', 'u_all_stem_length', 'site_1_1:A:U', 'mut_ref_nt:C', 'site_5prm_cp_bulge:A:U', 'u3_struct:S', 'd2_3prm_cp_internal:G:C', 'u2_struct:B', 'u_hairpin_length', 'd3_distance', 'ensemble_free_energy', 'site_5prm_cp_internal:G:C', 'site_next_nt:C', 'mut_pos', 'site_length_internal_es', 'd2_5prm_cp_internal:U:A', 'site_5prm_cp_internal:C:G', 'd3_length_stem', 'site_3prm_cp_internal:A:U', 'mut_prev_struct:B', 'mut_next_struct:S', 'mut_site_dist', 'u2_5prm_cp_internal:U:A', 'mut_next_struct:I']
# (361, 83)
# (361,)
# (89, 83)
# (89,)
# (432, 83)
# (432,)

# %%
## format matrixes for xgboost 
import xgboost
dtrain=xgboost.DMatrix(train_X,train_y)
deval=xgboost.DMatrix(eval_X,eval_y)
dtest=xgboost.DMatrix(test_X,test_y)

# %%
## set model training parameters 
from __future__ import unicode_literals
param=dict() 
param['nthread'] = 20
#rmse -- root mean square error 
# mae -- mean absolute error 
# map -- mean average precision 
# auc -- area under ROC curve 
# aucpr -- area under precision recall curve 

#Note: the last metric in your 'eval_metric' list will get optimized 
param['eval_metric'] = ['aucpr','auc','mae','map','rmse']

# %%
evallist = [(deval, 'eval'), (dtrain, 'train')]

# %%
num_round = 1000
random.seed(1234)
bst = xgboost.train(param, dtrain, num_round, evallist,early_stopping_rounds=10)
# Out:
# [0]	eval-aucpr:0.11026	eval-auc:0.73102	eval-mae:0.33258	eval-map:1.00000	eval-rmse:0.33453	train-aucpr:0.13050	train-auc:0.70318	train-mae:0.32443	train-map:1.00000	train-rmse:0.32724
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 10 rounds.
# [1]	eval-aucpr:0.10195	eval-auc:0.72998	eval-mae:0.23931	eval-map:1.00000	eval-rmse:0.24208	train-aucpr:0.14874	train-auc:0.70591	train-mae:0.22781	train-map:1.00000	train-rmse:0.23029
# [2]	eval-aucpr:0.10153	eval-auc:0.72930	eval-mae:0.17173	eval-map:1.00000	eval-rmse:0.17558	train-aucpr:0.15789	train-auc:0.70815	train-mae:0.16006	train-map:1.00000	train-rmse:0.16237
# [3]	eval-aucpr:0.10532	eval-auc:0.76381	eval-mae:0.12593	eval-map:1.00000	eval-rmse:0.13240	train-aucpr:0.16409	train-auc:0.75847	train-mae:0.11276	train-map:1.00000	train-rmse:0.11491
# [4]	eval-aucpr:0.10704	eval-auc:0.76546	eval-mae:0.09300	eval-map:1.00000	eval-rmse:0.10136	train-aucpr:0.16797	train-auc:0.76252	train-mae:0.07964	train-map:1.00000	train-rmse:0.08173
# [5]	eval-aucpr:0.10824	eval-auc:0.76520	eval-mae:0.07158	eval-map:1.00000	eval-rmse:0.08325	train-aucpr:0.17152	train-auc:0.77506	train-mae:0.05634	train-map:1.00000	train-rmse:0.05847
# [6]	eval-aucpr:0.11006	eval-auc:0.77288	eval-mae:0.05638	eval-map:1.00000	eval-rmse:0.07067	train-aucpr:0.17436	train-auc:0.78558	train-mae:0.04003	train-map:1.00000	train-rmse:0.04233
# [7]	eval-aucpr:0.11041	eval-auc:0.77440	eval-mae:0.04559	eval-map:1.00000	eval-rmse:0.06284	train-aucpr:0.17590	train-auc:0.79008	train-mae:0.02872	train-map:1.00000	train-rmse:0.03111
# [8]	eval-aucpr:0.10953	eval-auc:0.77165	eval-mae:0.04473	eval-map:1.00000	eval-rmse:0.06282	train-aucpr:0.17666	train-auc:0.79150	train-mae:0.02076	train-map:1.00000	train-rmse:0.02348
# [9]	eval-aucpr:0.11030	eval-auc:0.77464	eval-mae:0.03896	eval-map:1.00000	eval-rmse:0.05921	train-aucpr:0.17709	train-auc:0.79566	train-mae:0.01542	train-map:1.00000	train-rmse:0.01817
# [10]	eval-aucpr:0.11044	eval-auc:0.77511	eval-mae:0.03494	eval-map:1.00000	eval-rmse:0.05677	train-aucpr:0.17782	train-auc:0.79693	train-mae:0.01167	train-map:1.00000	train-rmse:0.01446
# [11]	eval-aucpr:0.11102	eval-auc:0.77541	eval-mae:0.03227	eval-map:1.00000	eval-rmse:0.05479	train-aucpr:0.17829	train-auc:0.79832	train-mae:0.00931	train-map:1.00000	train-rmse:0.01209
# [12]	eval-aucpr:0.11115	eval-auc:0.77581	eval-mae:0.03069	eval-map:1.00000	eval-rmse:0.05416	train-aucpr:0.17860	train-auc:0.79899	train-mae:0.00772	train-map:1.00000	train-rmse:0.01039
# [13]	eval-aucpr:0.11262	eval-auc:0.77646	eval-mae:0.02955	eval-map:1.00000	eval-rmse:0.05343	train-aucpr:0.17880	train-auc:0.79945	train-mae:0.00657	train-map:1.00000	train-rmse:0.00918
# [14]	eval-aucpr:0.11587	eval-auc:0.78018	eval-mae:0.02797	eval-map:1.00000	eval-rmse:0.05187	train-aucpr:0.17947	train-auc:0.80111	train-mae:0.00548	train-map:1.00000	train-rmse:0.00777
# [15]	eval-aucpr:0.11636	eval-auc:0.78137	eval-mae:0.02700	eval-map:1.00000	eval-rmse:0.05146	train-aucpr:0.17977	train-auc:0.80265	train-mae:0.00465	train-map:1.00000	train-rmse:0.00687
# [16]	eval-aucpr:0.11651	eval-auc:0.78226	eval-mae:0.02660	eval-map:1.00000	eval-rmse:0.05127	train-aucpr:0.17992	train-auc:0.80302	train-mae:0.00434	train-map:1.00000	train-rmse:0.00637
# [17]	eval-aucpr:0.11608	eval-auc:0.78194	eval-mae:0.02944	eval-map:1.00000	eval-rmse:0.05319	train-aucpr:0.18022	train-auc:0.80352	train-mae:0.00397	train-map:1.00000	train-rmse:0.00579
# [18]	eval-aucpr:0.11617	eval-auc:0.78257	eval-mae:0.02892	eval-map:1.00000	eval-rmse:0.05283	train-aucpr:0.18036	train-auc:0.80407	train-mae:0.00356	train-map:1.00000	train-rmse:0.00526
# [19]	eval-aucpr:0.11630	eval-auc:0.78301	eval-mae:0.02849	eval-map:1.00000	eval-rmse:0.05258	train-aucpr:0.18038	train-auc:0.80418	train-mae:0.00343	train-map:1.00000	train-rmse:0.00510
# [20]	eval-aucpr:0.11626	eval-auc:0.78292	eval-mae:0.02833	eval-map:1.00000	eval-rmse:0.05260	train-aucpr:0.18049	train-auc:0.80446	train-mae:0.00316	train-map:1.00000	train-rmse:0.00470
# [21]	eval-aucpr:0.11628	eval-auc:0.78293	eval-mae:0.02822	eval-map:1.00000	eval-rmse:0.05254	train-aucpr:0.18053	train-auc:0.80472	train-mae:0.00300	train-map:1.00000	train-rmse:0.00452
# [22]	eval-aucpr:0.11636	eval-auc:0.78346	eval-mae:0.02798	eval-map:1.00000	eval-rmse:0.05247	train-aucpr:0.18059	train-auc:0.80502	train-mae:0.00273	train-map:1.00000	train-rmse:0.00407
# [23]	eval-aucpr:0.11637	eval-auc:0.78354	eval-mae:0.02786	eval-map:1.00000	eval-rmse:0.05244	train-aucpr:0.18060	train-auc:0.80508	train-mae:0.00267	train-map:1.00000	train-rmse:0.00401
# [24]	eval-aucpr:0.11648	eval-auc:0.78380	eval-mae:0.02782	eval-map:1.00000	eval-rmse:0.05239	train-aucpr:0.18065	train-auc:0.80529	train-mae:0.00248	train-map:1.00000	train-rmse:0.00382
# [25]	eval-aucpr:0.11665	eval-auc:0.78423	eval-mae:0.02771	eval-map:1.00000	eval-rmse:0.05242	train-aucpr:0.18069	train-auc:0.80538	train-mae:0.00232	train-map:1.00000	train-rmse:0.00349
# [26]	eval-aucpr:0.11670	eval-auc:0.78453	eval-mae:0.02757	eval-map:1.00000	eval-rmse:0.05225	train-aucpr:0.18071	train-auc:0.80546	train-mae:0.00225	train-map:1.00000	train-rmse:0.00336
# [27]	eval-aucpr:0.11837	eval-auc:0.78497	eval-mae:0.02757	eval-map:1.00000	eval-rmse:0.05233	train-aucpr:0.18089	train-auc:0.80559	train-mae:0.00208	train-map:1.00000	train-rmse:0.00307
# [28]	eval-aucpr:0.11837	eval-auc:0.78496	eval-mae:0.02753	eval-map:1.00000	eval-rmse:0.05231	train-aucpr:0.18090	train-auc:0.80564	train-mae:0.00203	train-map:1.00000	train-rmse:0.00302
# [29]	eval-aucpr:0.11847	eval-auc:0.78559	eval-mae:0.02758	eval-map:1.00000	eval-rmse:0.05235	train-aucpr:0.18107	train-auc:0.80569	train-mae:0.00194	train-map:1.00000	train-rmse:0.00283
# [30]	eval-aucpr:0.11847	eval-auc:0.78562	eval-mae:0.02756	eval-map:1.00000	eval-rmse:0.05235	train-aucpr:0.18110	train-auc:0.80572	train-mae:0.00186	train-map:1.00000	train-rmse:0.00275
# [31]	eval-aucpr:0.11848	eval-auc:0.78566	eval-mae:0.02756	eval-map:1.00000	eval-rmse:0.05241	train-aucpr:0.18112	train-auc:0.80580	train-mae:0.00175	train-map:1.00000	train-rmse:0.00258
# [32]	eval-aucpr:0.11850	eval-auc:0.78574	eval-mae:0.02748	eval-map:1.00000	eval-rmse:0.05237	train-aucpr:0.18113	train-auc:0.80586	train-mae:0.00168	train-map:1.00000	train-rmse:0.00251
# [33]	eval-aucpr:0.11854	eval-auc:0.78596	eval-mae:0.02740	eval-map:1.00000	eval-rmse:0.05235	train-aucpr:0.18115	train-auc:0.80596	train-mae:0.00158	train-map:1.00000	train-rmse:0.00240
# [34]	eval-aucpr:0.11855	eval-auc:0.78603	eval-mae:0.02741	eval-map:1.00000	eval-rmse:0.05241	train-aucpr:0.18118	train-auc:0.80606	train-mae:0.00146	train-map:1.00000	train-rmse:0.00218
# [35]	eval-aucpr:0.11855	eval-auc:0.78602	eval-mae:0.02737	eval-map:1.00000	eval-rmse:0.05238	train-aucpr:0.18119	train-auc:0.80609	train-mae:0.00141	train-map:1.00000	train-rmse:0.00209
# [36]	eval-aucpr:0.11856	eval-auc:0.78612	eval-mae:0.02736	eval-map:1.00000	eval-rmse:0.05241	train-aucpr:0.18120	train-auc:0.80615	train-mae:0.00131	train-map:1.00000	train-rmse:0.00193
# [37]	eval-aucpr:0.11860	eval-auc:0.78640	eval-mae:0.02741	eval-map:1.00000	eval-rmse:0.05248	train-aucpr:0.18121	train-auc:0.80619	train-mae:0.00124	train-map:1.00000	train-rmse:0.00184
# [38]	eval-aucpr:0.11860	eval-auc:0.78643	eval-mae:0.02744	eval-map:1.00000	eval-rmse:0.05251	train-aucpr:0.18122	train-auc:0.80625	train-mae:0.00113	train-map:1.00000	train-rmse:0.00165
# [39]	eval-aucpr:0.11862	eval-auc:0.78660	eval-mae:0.02739	eval-map:1.00000	eval-rmse:0.05250	train-aucpr:0.18123	train-auc:0.80628	train-mae:0.00107	train-map:1.00000	train-rmse:0.00158
# [40]	eval-aucpr:0.11862	eval-auc:0.78652	eval-mae:0.02741	eval-map:1.00000	eval-rmse:0.05252	train-aucpr:0.18130	train-auc:0.80632	train-mae:0.00100	train-map:1.00000	train-rmse:0.00146
# [41]	eval-aucpr:0.11862	eval-auc:0.78655	eval-mae:0.02736	eval-map:1.00000	eval-rmse:0.05250	train-aucpr:0.18131	train-auc:0.80635	train-mae:0.00095	train-map:1.00000	train-rmse:0.00141
# [42]	eval-aucpr:0.11862	eval-auc:0.78648	eval-mae:0.02732	eval-map:1.00000	eval-rmse:0.05247	train-aucpr:0.18132	train-auc:0.80637	train-mae:0.00090	train-map:1.00000	train-rmse:0.00134
# [43]	eval-aucpr:0.11861	eval-auc:0.78645	eval-mae:0.02729	eval-map:1.00000	eval-rmse:0.05248	train-aucpr:0.18125	train-auc:0.80638	train-mae:0.00088	train-map:1.00000	train-rmse:0.00129
# [44]	eval-aucpr:0.11856	eval-auc:0.78639	eval-mae:0.02777	eval-map:1.00000	eval-rmse:0.05282	train-aucpr:0.18132	train-auc:0.80641	train-mae:0.00081	train-map:1.00000	train-rmse:0.00118
# [45]	eval-aucpr:0.11857	eval-auc:0.78651	eval-mae:0.02774	eval-map:1.00000	eval-rmse:0.05282	train-aucpr:0.18133	train-auc:0.80642	train-mae:0.00078	train-map:1.00000	train-rmse:0.00116
# [46]	eval-aucpr:0.11858	eval-auc:0.78661	eval-mae:0.02771	eval-map:1.00000	eval-rmse:0.05280	train-aucpr:0.18133	train-auc:0.80644	train-mae:0.00073	train-map:1.00000	train-rmse:0.00107
# [47]	eval-aucpr:0.11853	eval-auc:0.78648	eval-mae:0.02802	eval-map:1.00000	eval-rmse:0.05303	train-aucpr:0.18133	train-auc:0.80645	train-mae:0.00072	train-map:1.00000	train-rmse:0.00104
# [48]	eval-aucpr:0.11853	eval-auc:0.78648	eval-mae:0.02802	eval-map:1.00000	eval-rmse:0.05302	train-aucpr:0.18133	train-auc:0.80645	train-mae:0.00072	train-map:1.00000	train-rmse:0.00104
# [49]	eval-aucpr:0.11853	eval-auc:0.78648	eval-mae:0.02802	eval-map:1.00000	eval-rmse:0.05302	train-aucpr:0.18133	train-auc:0.80645	train-mae:0.00072	train-map:1.00000	train-rmse:0.00104
# [50]	eval-aucpr:0.11853	eval-auc:0.78648	eval-mae:0.02802	eval-map:1.00000	eval-rmse:0.05302	train-aucpr:0.18133	train-auc:0.80645	train-mae:0.00072	train-map:1.00000	train-rmse:0.00104
# [51]	eval-aucpr:0.11853	eval-auc:0.78648	eval-mae:0.02802	eval-map:1.00000	eval-rmse:0.05302	train-aucpr:0.18133	train-auc:0.80645	train-mae:0.00072	train-map:1.00000	train-rmse:0.00104
# [52]	eval-aucpr:0.11853	eval-auc:0.78648	eval-mae:0.02802	eval-map:1.00000	eval-rmse:0.05302	train-aucpr:0.18133	train-auc:0.80645	train-mae:0.00072	train-map:1.00000	train-rmse:0.00104
# [53]	eval-aucpr:0.11853	eval-auc:0.78648	eval-mae:0.02802	eval-map:1.00000	eval-rmse:0.05302	train-aucpr:0.18133	train-auc:0.80645	train-mae:0.00072	train-map:1.00000	train-rmse:0.00104
# [54]	eval-aucpr:0.11853	eval-auc:0.78648	eval-mae:0.02802	eval-map:1.00000	eval-rmse:0.05302	train-aucpr:0.18133	train-auc:0.80645	train-mae:0.00072	train-map:1.00000	train-rmse:0.00104
# [55]	eval-aucpr:0.11853	eval-auc:0.78648	eval-mae:0.02802	eval-map:1.00000	eval-rmse:0.05302	train-aucpr:0.18133	train-auc:0.80645	train-mae:0.00072	train-map:1.00000	train-rmse:0.00104
# [56]	eval-aucpr:0.11853	eval-auc:0.78648	eval-mae:0.02802	eval-map:1.00000	eval-rmse:0.05302	train-aucpr:0.18133	train-auc:0.80645	train-mae:0.00072	train-map:1.00000	train-rmse:0.00104
# [57]	eval-aucpr:0.11853	eval-auc:0.78648	eval-mae:0.02802	eval-map:1.00000	eval-rmse:0.05302	train-aucpr:0.18133	train-auc:0.80645	train-mae:0.00072	train-map:1.00000	train-rmse:0.00104
# Stopping. Best iteration:
# [47]	eval-aucpr:0.11853	eval-auc:0.78648	eval-mae:0.02802	eval-map:1.00000	eval-rmse:0.05303	train-aucpr:0.18133	train-auc:0.80645	train-mae:0.00072	train-map:1.00000	train-rmse:0.00104

# %%
## get model predictions on the test, training, and eval splits 
test_pred = bst.predict(dtest)
train_pred=bst.predict(dtrain)
eval_pred=bst.predict(deval)

# %%
## Get performance metrics on full dataset 
from helpers import * 
print_aggregate_peformance_metrics(train_y,train_pred,
                                   eval_y,eval_pred,
                                   test_y,test_pred,
                                   positive_thresh=0.2)
# Out:
# Train
# 	Spearman corr : SpearmanrResult(correlation=0.9974756169800476, pvalue=0.0)
# 	Pearson corr : (0.9998280474925781, 0.0)
# 	MAE : 0.0007170246120456345
# 	MAPE : 0.024078652387808826
# 	RMSE : 0.001043199075288303
# 	auPRC : 0.9999999999999998
# 	auROC : 1.0
# Eval
# 	Spearman corr : SpearmanrResult(correlation=0.8608027336393701, pvalue=2.980158926784681e-27)
# 	Pearson corr : (0.7621237645764347, 4.1620489418081676e-18)
# 	MAE : 0.028020753731710434
# 	MAPE : 0.6495224698488177
# 	RMSE : 0.05302300701886039
# 	auPRC : 0.4492424242424243
# 	auROC : 0.961764705882353
# Test
# 	Spearman corr : SpearmanrResult(correlation=0.623205138366301, pvalue=7.613863449859707e-48)
# 	Pearson corr : (0.5978748988411109, 3.2055689154158055e-43)
# 	MAE : 0.19053255617342615
# 	MAPE : 0.7430835480737995
# 	RMSE : 0.25963148477449804
# 	auPRC : 0.830704144384615
# 	auROC : 0.8117000451739196

# %%
## Correlation values 
from scipy.stats import spearmanr,pearsonr
spearman_train=spearmanr(train_y,train_pred)
spearman_eval=spearmanr(eval_y,eval_pred)
spearman_test=spearmanr(test_y,test_pred)

pearson_train=pearsonr(train_y,train_pred)
pearson_eval=pearsonr(eval_y,eval_pred)
pearson_test=pearsonr(test_y,test_pred)

print("Spearman correlation:")
print("Train:"+str(spearman_train))
print("Eval:"+str(spearman_eval))
print("Test:"+str(spearman_test))
print("\n")
print("Pearson correlation:")
print("Train:"+str(pearson_train))
print("Eval:"+str(pearson_eval))
print("Test:"+str(pearson_test))
# Out:
# Spearman correlation:
# Train:SpearmanrResult(correlation=0.9974756169800476, pvalue=0.0)
# Eval:SpearmanrResult(correlation=0.8608027336393701, pvalue=2.980158926784681e-27)
# Test:SpearmanrResult(correlation=0.623205138366301, pvalue=7.613863449859707e-48)
#
#
# Pearson correlation:
# Train:(0.9998280474925781, 0.0)
# Eval:(0.7621237645764347, 4.1620489418081676e-18)
# Test:(0.5978748988411109, 3.2055689154158055e-43)

# %%
## MAE
from sklearn.metrics import mean_absolute_error
mae_train=mean_absolute_error(train_y,train_pred)
print("MAE Train:"+str(mae_train))

mae_eval=mean_absolute_error(eval_y,eval_pred)
print("MAE Eval:"+str(mae_eval))

mae_test=mean_absolute_error(test_y,test_pred)
print("MAE Test:"+str(mae_test))
# Out:
# MAE Train:0.0007170246120456345
# MAE Eval:0.028020753731710434
# MAE Test:0.19053255617342615

# %%
## MAPE
pseudocount=0.01
mape_train=np.mean(np.abs((train_y - train_pred) /(pseudocount+train_y))) * 100
print("MAPE Train:"+str(mape_train)+"%")

mape_eval=np.mean(np.abs((eval_y - eval_pred) /(pseudocount+eval_y))) * 100
print("MAPE Eval:"+str(mape_eval)+"%")

mape_test=np.mean(np.abs((test_y - test_pred) /(pseudocount+test_y))) * 100
print("MAPE Test:"+str(mape_test)+"%")
# Out:
# MAPE Train:2.4078652387808828%
# MAPE Eval:64.95224698488177%
# MAPE Test:74.30835480737996%

# %%
## RMSE
from sklearn.metrics import mean_squared_error
import math 
rmse_train=math.sqrt(mean_squared_error(train_y,train_pred))
print("RMSE Train:"+str(rmse_train))

rmse_eval=math.sqrt(mean_squared_error(eval_y,eval_pred))
print("RMSE Eval:"+str(rmse_eval))

rmse_test=math.sqrt(mean_squared_error(test_y,test_pred))
print("RMSE Test:"+str(rmse_test))
# Out:
# RMSE Train:0.001043199075288303
# RMSE Eval:0.05302300701886039
# RMSE Test:0.25963148477449804

# %%
## PRC 
## PRC only valid for binary outcomes. 
## Editing levels < 0.5 are labeled as "0". 
## Editing levels >= 0.5 are labeled as "1". 

from sklearn.metrics import auc, precision_recall_curve

precision_train,recall_train,prc_thresholds_train=precision_recall_curve(train_y>=0.2,train_pred)
precision_eval,recall_eval,prc_thresholds_eval=precision_recall_curve(eval_y>=0.2,eval_pred)
precision_test,recall_test,prc_thresholds_test=precision_recall_curve(test_y>=0.5,test_pred)

auprc_train=auc(recall_train,precision_train)
auprc_eval=auc(recall_eval,precision_eval)
auprc_test=auc(recall_test,precision_test)

plt.plot(recall_train,precision_train,'r',label="Train:"+str(round(auprc_train,2)))
plt.plot(recall_eval,precision_eval,'g',label="Eval:"+str(round(auprc_eval,2)))
plt.plot(recall_test,precision_test,'b',label="Test:"+str(round(auprc_test,2)))
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("PRC")
plt.legend()

# %%
## ROC
from sklearn.metrics import roc_curve, roc_auc_score
fpr_train,tpr_train,roc_thresholds_train=roc_curve(train_y>=0.2,train_pred)
fpr_eval,tpr_eval,roc_thresholds_eval=roc_curve(eval_y>=0.2,eval_pred)
fpr_test,tpr_test,roc_thresholds_test=roc_curve(test_y>=0.5,test_pred)

auroc_train=roc_auc_score(train_y>=0.2,train_pred)
auroc_eval=roc_auc_score(eval_y>=0.2,eval_pred)
auroc_test=roc_auc_score(test_y>=0.5,test_pred)

plt.plot(fpr_train,tpr_train,'r',label="Train:"+str(round(auroc_train,2)))
plt.plot(fpr_eval,tpr_eval,'g',label="Eval:"+str(round(auroc_eval,2)))
plt.plot(fpr_test,tpr_test,'b',label="Test:"+str(round(auroc_test,2)))
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC")
plt.legend()

# %%
#plot the test set predictions 
matplotlib.rcParams['figure.figsize'] = [20, 8]
plt.subplot(1,3,1)
plt.plot(list(train_y),list(train_pred),'o')
plt.xlabel("Observed train set editing level, AJUBA Comp")
plt.ylabel("Predicted train set editing level, AJUBA Comp")
plt.subplot(1,3,2)
plt.plot(list(eval_y),list(eval_pred),'o')
plt.xlabel("Observed eval set editing level, AJUBA Comp")
plt.ylabel("Predicted eval set editing level, AJUBA Comp")
plt.subplot(1,3,3)
plt.plot(list(test_y),list(test_pred),'o')
plt.xlabel("Observed test set editing level, NEIL1 Comp")
plt.ylabel("Predicted test set editing level, NEIL1 Comp")

plt.show()

# %%
#calculate R^2, which is representative of variance explained 
# https://datascienceplus.com/extreme-gradient-boosting-with-r/
# https://arxiv.org/pdf/1706.06060.pdf

residuals = test_y - test_pred

y_test_mean = np.mean(test_pred)
print(y_test_mean)
#calculate total sum of squares 
tss=sum((test_y-y_test_mean)*(test_y-y_test_mean))
print(tss)
# Calculate residual sum of squares
rss =  sum(residuals*residuals)
print(rss)
# Calculate R-squared
rsq  =  1 - (rss/tss)
print('The R-square of the test data is ', round(rsq,3), '\n')
# Out:
# 0.1097433
# 37.80022294932375
# 29.120475406842903
# The R-square of the test data is  0.23

# %% [markdown]
# ## Train AJUBA, predict TTYH2

# %%
test_split=ttyh2_comp

# %%
train_split.reset_index(inplace=True, drop=True) 
eval_split.reset_index(inplace=True,drop=True)
test_split.reset_index(inplace=True,drop=True)

# %%
#Remove any non-varying features 
train_novar=get_singleval_features(train_split)
eval_novar=get_singleval_features(eval_split)
test_novar=get_singleval_features(test_split)
uniform_features_to_drop=list(set(train_novar+eval_novar+test_novar))

# %%
#Remove any null features 
train_null=get_high_missingness_features(train_split)
eval_null=get_high_missingness_features(eval_split)
test_null=get_high_missingness_features(test_split)
null_features_to_drop=list(set(train_null+eval_null+test_null))

# %%
to_drop=list(set(uniform_features_to_drop+null_features_to_drop))
print("\n".join(to_drop))
# Out:
# u1_5prm_cp_bulge
# d1_exist
# d3_length_internal_es
# d2_length_internal_ecs
# d3_length_internal_ecs
# u1_3prm_cp_bulge
# d1_length_bulge
# u3_length_bulge
# u2_exist
# u1_distance
# d3_5prm_cp_hairpin
# u3_5prm_cp_hairpin
# d1_3prm_cp_bulge
# u3_5prm_cp_bulge
# d3_length_hairpin
# site_5prm_cp_hairpin
# u1_length_bulge
# u3_length_internal_ecs
# site_length_bulge
# u_hairpin_length
# d1_length_hairpin
# d2_length_internal_es
# d2_length_stem
# u2_length_stem
# d3_length_bulge
# u1_length_hairpin
# d1_length_internal_es
# u1_length_internal_ecs
# d3_5prm_cp_internal
# u1_5prm_cp_hairpin
# u3_length_hairpin
# u3_3prm_cp_bulge
# d2_length_hairpin
# u3_length_internal_es
# d2_5prm_cp_hairpin
# u1_length_internal_es
# d1_distance
# u2_length_bulge
# u1_exist
# d1_5prm_cp_hairpin
# d3_3prm_cp_internal
# site_length_stem
# d1_5prm_cp_bulge
# site_length_hairpin
# u2_length_hairpin
# d1_length_internal_ecs

# %%
#remove teh features that don't change across isoforms , or are null for all isoforms
for cur_to_drop in to_drop: 
    try:
        train_split=train_split.drop(cur_to_drop,axis=1)
    except: 
        pass
    try:
        eval_split=eval_split.drop(cur_to_drop,axis=1)
    except: 
        pass 
    try:
        test_split=test_split.drop(to_drop,axis=1)
    except: 
        pass

# %%
train_y=train_split['editing_value']
train_X=train_split.drop(['editing_value'],axis=1)
eval_y=eval_split['editing_value']
eval_X=eval_split.drop(['editing_value'],axis=1)
test_y=test_split['editing_value']
test_X=test_split.drop(['editing_value'],axis=1)

# %%
print(train_X.shape)
print(train_y.shape)
print(eval_X.shape)
print(eval_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (361, 106)
# (361,)
# (89, 106)
# (89,)
# (601, 158)
# (601,)

# %%
train_cols=set(train_X.columns)
eval_cols=set(eval_X.columns)
test_cols=set(test_X.columns)

# %%
common=train_cols.intersection(eval_cols)
common=list(common.intersection(test_cols))
print(common)
train_X=train_X[common]
eval_X=eval_X[common]
test_X=test_X[common]
print(train_X.shape)
print(train_y.shape)
print(eval_X.shape)
print(eval_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# ['d2_5prm_cp_bulge:G:C', 'site_1_1:A:C', 'u1_length', 'num_mutations', 'u2_distance', 'u2_3prm_cp_internal:A:U', 'u2_5prm_cp_bulge:C:G', 'mut_nt:G', 'd2_length', 'u3_distance', 'mut_ref_struct:I', 'site_prev_nt:G', 'site_length_internal_ecs', 'u1_5prm_cp_internal:U:A', 'site_prev_nt:C', 'site_length', 'u2_struct:I', 'u1_length_stem', 'mut_ref_nt:U', 'minimum_free_energy', 'd2_struct:I', 'u2_3prm_cp_bulge:U:A', 'sim_nor_score', 'mut_next_struct:B', 'site_struct:I', 'd1_length_stem', 'mut_struct:I', 'd2_5prm_cp_internal:G:C', 'd_all_stem_length', 'site_3prm_cp_bulge:G:C', 'u1_struct:S', 'd2_5prm_cp_internal:U:G', 'd2_5prm_cp_internal:A:U', 'd3_length', 'mfe_frequency', 'site_struct:B', 'd2_3prm_cp_bulge:U:A', 'd_count', 'site_5prm_cp_internal:U:G', 'mut_nt:A', 'u2_3prm_cp_internal:C:G', 'all_stem_length', 'mut_nt:C', 'site_3prm_cp_internal:G:C', 'u1_struct:I', 'u2_5prm_cp_internal:G:C', 'mut_struct:S', 'u2_3prm_cp_internal:G:C', 'mut_struct:B', 'probability_active_conf', 'd1_length', 'u_count', 'mut_nt:U', 'u2_length', 'mut_ref_struct:S', 'd2_distance', 'mut_prev_struct:I', 'u2_3prm_cp_internal:U:A', 'site_struct:S', 'ensemble_diversity', 'd2_3prm_cp_bulge:C:G', 'd2_struct:B', 'mut_prev_struct:S', 'site_5prm_cp_bulge:G:C', 'u_all_stem_length', 'site_1_1:A:U', 'mut_ref_nt:C', 'u3_struct:S', 'd2_3prm_cp_internal:G:C', 'site_next_nt:G', 'u2_struct:B', 'u3_struct:I', 'd3_distance', 'ensemble_free_energy', 'site_5prm_cp_internal:G:C', 'site_next_nt:C', 'mut_pos', 'site_length_internal_es', 'd2_3prm_cp_bulge:G:C', 'site_5prm_cp_internal:C:G', 'site_prev_struct:I', 'd3_length_stem', 'u2_struct:S', 'mut_prev_struct:B', 'mut_next_struct:S', 'mut_site_dist', 'u2_5prm_cp_internal:U:A', 'mut_next_struct:I']
# (361, 88)
# (361,)
# (89, 88)
# (89,)
# (601, 88)
# (601,)

# %%
## format matrixes for xgboost 
import xgboost
dtrain=xgboost.DMatrix(train_X,train_y)
deval=xgboost.DMatrix(eval_X,eval_y)
dtest=xgboost.DMatrix(test_X,test_y)

# %%
## set model training parameters 
from __future__ import unicode_literals
param=dict() 
param['nthread'] = 20
#rmse -- root mean square error 
# mae -- mean absolute error 
# map -- mean average precision 
# auc -- area under ROC curve 
# aucpr -- area under precision recall curve 

#Note: the last metric in your 'eval_metric' list will get optimized 
param['eval_metric'] = ['aucpr','auc','mae','map','rmse']

# %%
evallist = [(deval, 'eval'), (dtrain, 'train')]

# %%
num_round = 1000
random.seed(1234)
bst = xgboost.train(param, dtrain, num_round, evallist,early_stopping_rounds=10)
# Out:
# [0]	eval-aucpr:0.11026	eval-auc:0.73102	eval-mae:0.33258	eval-map:1.00000	eval-rmse:0.33453	train-aucpr:0.13050	train-auc:0.70318	train-mae:0.32443	train-map:1.00000	train-rmse:0.32724
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 10 rounds.
# [1]	eval-aucpr:0.10195	eval-auc:0.72998	eval-mae:0.23931	eval-map:1.00000	eval-rmse:0.24208	train-aucpr:0.14874	train-auc:0.70591	train-mae:0.22781	train-map:1.00000	train-rmse:0.23029
# [2]	eval-aucpr:0.10153	eval-auc:0.72930	eval-mae:0.17173	eval-map:1.00000	eval-rmse:0.17558	train-aucpr:0.15789	train-auc:0.70815	train-mae:0.16006	train-map:1.00000	train-rmse:0.16237
# [3]	eval-aucpr:0.10532	eval-auc:0.76381	eval-mae:0.12593	eval-map:1.00000	eval-rmse:0.13240	train-aucpr:0.16409	train-auc:0.75847	train-mae:0.11276	train-map:1.00000	train-rmse:0.11491
# [4]	eval-aucpr:0.10704	eval-auc:0.76546	eval-mae:0.09300	eval-map:1.00000	eval-rmse:0.10136	train-aucpr:0.16797	train-auc:0.76252	train-mae:0.07964	train-map:1.00000	train-rmse:0.08173
# [5]	eval-aucpr:0.10824	eval-auc:0.76520	eval-mae:0.07158	eval-map:1.00000	eval-rmse:0.08325	train-aucpr:0.17152	train-auc:0.77506	train-mae:0.05634	train-map:1.00000	train-rmse:0.05847
# [6]	eval-aucpr:0.11006	eval-auc:0.77288	eval-mae:0.05638	eval-map:1.00000	eval-rmse:0.07067	train-aucpr:0.17436	train-auc:0.78558	train-mae:0.04003	train-map:1.00000	train-rmse:0.04233
# [7]	eval-aucpr:0.11041	eval-auc:0.77440	eval-mae:0.04559	eval-map:1.00000	eval-rmse:0.06284	train-aucpr:0.17590	train-auc:0.79008	train-mae:0.02872	train-map:1.00000	train-rmse:0.03111
# [8]	eval-aucpr:0.10953	eval-auc:0.77165	eval-mae:0.04473	eval-map:1.00000	eval-rmse:0.06282	train-aucpr:0.17666	train-auc:0.79150	train-mae:0.02076	train-map:1.00000	train-rmse:0.02348
# [9]	eval-aucpr:0.11041	eval-auc:0.77502	eval-mae:0.03882	eval-map:1.00000	eval-rmse:0.05913	train-aucpr:0.17704	train-auc:0.79520	train-mae:0.01541	train-map:1.00000	train-rmse:0.01819
# [10]	eval-aucpr:0.11053	eval-auc:0.77541	eval-mae:0.03480	eval-map:1.00000	eval-rmse:0.05670	train-aucpr:0.17777	train-auc:0.79650	train-mae:0.01173	train-map:1.00000	train-rmse:0.01449
# [11]	eval-aucpr:0.11113	eval-auc:0.77571	eval-mae:0.03212	eval-map:1.00000	eval-rmse:0.05472	train-aucpr:0.17826	train-auc:0.79812	train-mae:0.00936	train-map:1.00000	train-rmse:0.01211
# [12]	eval-aucpr:0.11256	eval-auc:0.77668	eval-mae:0.03019	eval-map:1.00000	eval-rmse:0.05317	train-aucpr:0.17807	train-auc:0.79876	train-mae:0.00784	train-map:1.00000	train-rmse:0.01050
# [13]	eval-aucpr:0.11263	eval-auc:0.77666	eval-mae:0.02895	eval-map:1.00000	eval-rmse:0.05223	train-aucpr:0.17872	train-auc:0.79941	train-mae:0.00669	train-map:1.00000	train-rmse:0.00918
# [14]	eval-aucpr:0.11217	eval-auc:0.77452	eval-mae:0.02746	eval-map:1.00000	eval-rmse:0.05204	train-aucpr:0.17943	train-auc:0.80082	train-mae:0.00575	train-map:1.00000	train-rmse:0.00815
# [15]	eval-aucpr:0.11268	eval-auc:0.77683	eval-mae:0.02657	eval-map:1.00000	eval-rmse:0.05161	train-aucpr:0.17979	train-auc:0.80261	train-mae:0.00492	train-map:1.00000	train-rmse:0.00719
# [16]	eval-aucpr:0.11290	eval-auc:0.77919	eval-mae:0.02576	eval-map:1.00000	eval-rmse:0.05129	train-aucpr:0.17994	train-auc:0.80352	train-mae:0.00424	train-map:1.00000	train-rmse:0.00639
# [17]	eval-aucpr:0.11305	eval-auc:0.77956	eval-mae:0.02539	eval-map:1.00000	eval-rmse:0.05112	train-aucpr:0.17999	train-auc:0.80381	train-mae:0.00393	train-map:1.00000	train-rmse:0.00596
# [18]	eval-aucpr:0.11305	eval-auc:0.77945	eval-mae:0.02507	eval-map:1.00000	eval-rmse:0.05094	train-aucpr:0.18014	train-auc:0.80404	train-mae:0.00367	train-map:1.00000	train-rmse:0.00554
# [19]	eval-aucpr:0.11312	eval-auc:0.77970	eval-mae:0.02475	eval-map:1.00000	eval-rmse:0.05072	train-aucpr:0.18025	train-auc:0.80422	train-mae:0.00345	train-map:1.00000	train-rmse:0.00519
# [20]	eval-aucpr:0.11321	eval-auc:0.78002	eval-mae:0.02470	eval-map:1.00000	eval-rmse:0.05075	train-aucpr:0.18033	train-auc:0.80457	train-mae:0.00321	train-map:1.00000	train-rmse:0.00494
# [21]	eval-aucpr:0.11335	eval-auc:0.78088	eval-mae:0.02446	eval-map:1.00000	eval-rmse:0.05060	train-aucpr:0.18039	train-auc:0.80475	train-mae:0.00305	train-map:1.00000	train-rmse:0.00480
# [22]	eval-aucpr:0.11345	eval-auc:0.78149	eval-mae:0.02420	eval-map:1.00000	eval-rmse:0.05040	train-aucpr:0.18045	train-auc:0.80492	train-mae:0.00286	train-map:1.00000	train-rmse:0.00459
# [23]	eval-aucpr:0.11360	eval-auc:0.78206	eval-mae:0.02410	eval-map:1.00000	eval-rmse:0.05041	train-aucpr:0.18050	train-auc:0.80519	train-mae:0.00264	train-map:1.00000	train-rmse:0.00439
# [24]	eval-aucpr:0.11365	eval-auc:0.78258	eval-mae:0.02395	eval-map:1.00000	eval-rmse:0.05023	train-aucpr:0.18054	train-auc:0.80528	train-mae:0.00251	train-map:1.00000	train-rmse:0.00414
# [25]	eval-aucpr:0.11299	eval-auc:0.78249	eval-mae:0.02391	eval-map:1.00000	eval-rmse:0.05028	train-aucpr:0.18083	train-auc:0.80549	train-mae:0.00225	train-map:1.00000	train-rmse:0.00362
# [26]	eval-aucpr:0.11298	eval-auc:0.78245	eval-mae:0.02385	eval-map:1.00000	eval-rmse:0.05022	train-aucpr:0.18087	train-auc:0.80558	train-mae:0.00213	train-map:1.00000	train-rmse:0.00342
# [27]	eval-aucpr:0.11387	eval-auc:0.78285	eval-mae:0.02377	eval-map:1.00000	eval-rmse:0.05011	train-aucpr:0.18088	train-auc:0.80569	train-mae:0.00204	train-map:1.00000	train-rmse:0.00333
# [28]	eval-aucpr:0.11456	eval-auc:0.78315	eval-mae:0.02371	eval-map:1.00000	eval-rmse:0.05013	train-aucpr:0.18092	train-auc:0.80586	train-mae:0.00184	train-map:1.00000	train-rmse:0.00299
# [29]	eval-aucpr:0.11389	eval-auc:0.78313	eval-mae:0.02367	eval-map:1.00000	eval-rmse:0.05009	train-aucpr:0.18094	train-auc:0.80589	train-mae:0.00176	train-map:1.00000	train-rmse:0.00287
# [30]	eval-aucpr:0.11391	eval-auc:0.78314	eval-mae:0.02357	eval-map:1.00000	eval-rmse:0.05004	train-aucpr:0.18097	train-auc:0.80598	train-mae:0.00161	train-map:1.00000	train-rmse:0.00264
# [31]	eval-aucpr:0.11307	eval-auc:0.78302	eval-mae:0.02353	eval-map:1.00000	eval-rmse:0.05001	train-aucpr:0.18097	train-auc:0.80602	train-mae:0.00156	train-map:1.00000	train-rmse:0.00261
# [32]	eval-aucpr:0.11308	eval-auc:0.78312	eval-mae:0.02348	eval-map:1.00000	eval-rmse:0.05003	train-aucpr:0.18099	train-auc:0.80607	train-mae:0.00150	train-map:1.00000	train-rmse:0.00251
# [33]	eval-aucpr:0.11391	eval-auc:0.78327	eval-mae:0.02355	eval-map:1.00000	eval-rmse:0.05012	train-aucpr:0.18101	train-auc:0.80609	train-mae:0.00143	train-map:1.00000	train-rmse:0.00234
# [34]	eval-aucpr:0.11391	eval-auc:0.78329	eval-mae:0.02349	eval-map:1.00000	eval-rmse:0.05008	train-aucpr:0.18104	train-auc:0.80615	train-mae:0.00138	train-map:1.00000	train-rmse:0.00228
# [35]	eval-aucpr:0.11393	eval-auc:0.78329	eval-mae:0.02348	eval-map:1.00000	eval-rmse:0.05006	train-aucpr:0.18105	train-auc:0.80620	train-mae:0.00129	train-map:1.00000	train-rmse:0.00218
# [36]	eval-aucpr:0.11352	eval-auc:0.78360	eval-mae:0.02342	eval-map:1.00000	eval-rmse:0.05002	train-aucpr:0.18105	train-auc:0.80623	train-mae:0.00121	train-map:1.00000	train-rmse:0.00200
# [37]	eval-aucpr:0.11352	eval-auc:0.78368	eval-mae:0.02338	eval-map:1.00000	eval-rmse:0.04998	train-aucpr:0.18106	train-auc:0.80624	train-mae:0.00118	train-map:1.00000	train-rmse:0.00196
# [38]	eval-aucpr:0.11434	eval-auc:0.78373	eval-mae:0.02340	eval-map:1.00000	eval-rmse:0.05006	train-aucpr:0.18122	train-auc:0.80627	train-mae:0.00111	train-map:1.00000	train-rmse:0.00178
# [39]	eval-aucpr:0.11435	eval-auc:0.78375	eval-mae:0.02341	eval-map:1.00000	eval-rmse:0.05006	train-aucpr:0.18122	train-auc:0.80629	train-mae:0.00107	train-map:1.00000	train-rmse:0.00174
# [40]	eval-aucpr:0.11353	eval-auc:0.78385	eval-mae:0.02340	eval-map:1.00000	eval-rmse:0.05009	train-aucpr:0.18122	train-auc:0.80632	train-mae:0.00103	train-map:1.00000	train-rmse:0.00168
# [41]	eval-aucpr:0.11358	eval-auc:0.78416	eval-mae:0.02359	eval-map:1.00000	eval-rmse:0.05039	train-aucpr:0.18123	train-auc:0.80634	train-mae:0.00098	train-map:1.00000	train-rmse:0.00154
# [42]	eval-aucpr:0.11359	eval-auc:0.78415	eval-mae:0.02359	eval-map:1.00000	eval-rmse:0.05038	train-aucpr:0.18124	train-auc:0.80637	train-mae:0.00092	train-map:1.00000	train-rmse:0.00146
# [43]	eval-aucpr:0.11359	eval-auc:0.78418	eval-mae:0.02357	eval-map:1.00000	eval-rmse:0.05038	train-aucpr:0.18124	train-auc:0.80639	train-mae:0.00089	train-map:1.00000	train-rmse:0.00142
# [44]	eval-aucpr:0.11360	eval-auc:0.78428	eval-mae:0.02353	eval-map:1.00000	eval-rmse:0.05035	train-aucpr:0.18125	train-auc:0.80643	train-mae:0.00084	train-map:1.00000	train-rmse:0.00136
# [45]	eval-aucpr:0.11358	eval-auc:0.78420	eval-mae:0.02353	eval-map:1.00000	eval-rmse:0.05036	train-aucpr:0.18125	train-auc:0.80644	train-mae:0.00080	train-map:1.00000	train-rmse:0.00127
# [46]	eval-aucpr:0.11360	eval-auc:0.78430	eval-mae:0.02350	eval-map:1.00000	eval-rmse:0.05036	train-aucpr:0.18126	train-auc:0.80646	train-mae:0.00076	train-map:1.00000	train-rmse:0.00117
# [47]	eval-aucpr:0.11358	eval-auc:0.78417	eval-mae:0.02348	eval-map:1.00000	eval-rmse:0.05038	train-aucpr:0.18126	train-auc:0.80648	train-mae:0.00072	train-map:1.00000	train-rmse:0.00109
# [48]	eval-aucpr:0.11360	eval-auc:0.78425	eval-mae:0.02346	eval-map:1.00000	eval-rmse:0.05036	train-aucpr:0.18133	train-auc:0.80649	train-mae:0.00070	train-map:1.00000	train-rmse:0.00105
# [49]	eval-aucpr:0.11362	eval-auc:0.78431	eval-mae:0.02346	eval-map:1.00000	eval-rmse:0.05037	train-aucpr:0.18134	train-auc:0.80650	train-mae:0.00067	train-map:1.00000	train-rmse:0.00101
# [50]	eval-aucpr:0.11362	eval-auc:0.78431	eval-mae:0.02346	eval-map:1.00000	eval-rmse:0.05037	train-aucpr:0.18134	train-auc:0.80650	train-mae:0.00067	train-map:1.00000	train-rmse:0.00101
# [51]	eval-aucpr:0.11362	eval-auc:0.78431	eval-mae:0.02346	eval-map:1.00000	eval-rmse:0.05037	train-aucpr:0.18134	train-auc:0.80650	train-mae:0.00067	train-map:1.00000	train-rmse:0.00101
# [52]	eval-aucpr:0.11362	eval-auc:0.78431	eval-mae:0.02346	eval-map:1.00000	eval-rmse:0.05037	train-aucpr:0.18134	train-auc:0.80650	train-mae:0.00067	train-map:1.00000	train-rmse:0.00101
# [53]	eval-aucpr:0.11362	eval-auc:0.78431	eval-mae:0.02345	eval-map:1.00000	eval-rmse:0.05037	train-aucpr:0.18134	train-auc:0.80650	train-mae:0.00067	train-map:1.00000	train-rmse:0.00101
# [54]	eval-aucpr:0.11362	eval-auc:0.78431	eval-mae:0.02345	eval-map:1.00000	eval-rmse:0.05037	train-aucpr:0.18134	train-auc:0.80650	train-mae:0.00067	train-map:1.00000	train-rmse:0.00101
# [55]	eval-aucpr:0.11362	eval-auc:0.78431	eval-mae:0.02345	eval-map:1.00000	eval-rmse:0.05037	train-aucpr:0.18134	train-auc:0.80650	train-mae:0.00067	train-map:1.00000	train-rmse:0.00101
# [56]	eval-aucpr:0.11362	eval-auc:0.78431	eval-mae:0.02345	eval-map:1.00000	eval-rmse:0.05037	train-aucpr:0.18134	train-auc:0.80650	train-mae:0.00067	train-map:1.00000	train-rmse:0.00101
# [57]	eval-aucpr:0.11362	eval-auc:0.78431	eval-mae:0.02345	eval-map:1.00000	eval-rmse:0.05037	train-aucpr:0.18134	train-auc:0.80650	train-mae:0.00067	train-map:1.00000	train-rmse:0.00101
# [58]	eval-aucpr:0.11362	eval-auc:0.78431	eval-mae:0.02345	eval-map:1.00000	eval-rmse:0.05037	train-aucpr:0.18134	train-auc:0.80650	train-mae:0.00067	train-map:1.00000	train-rmse:0.00101
# [59]	eval-aucpr:0.11362	eval-auc:0.78431	eval-mae:0.02345	eval-map:1.00000	eval-rmse:0.05037	train-aucpr:0.18134	train-auc:0.80650	train-mae:0.00067	train-map:1.00000	train-rmse:0.00101
# Stopping. Best iteration:
# [49]	eval-aucpr:0.11362	eval-auc:0.78431	eval-mae:0.02346	eval-map:1.00000	eval-rmse:0.05037	train-aucpr:0.18134	train-auc:0.80650	train-mae:0.00067	train-map:1.00000	train-rmse:0.00101

# %%
## get model predictions on the test, training, and eval splits 
test_pred = bst.predict(dtest)
train_pred=bst.predict(dtrain)
eval_pred=bst.predict(deval)

# %%
## Get performance metrics on full dataset 
from helpers import * 
print_aggregate_peformance_metrics(train_y,train_pred,
                                   eval_y,eval_pred,
                                   test_y,test_pred,
                                   positive_thresh=0.2)
# Out:
# Train
# 	Spearman corr : SpearmanrResult(correlation=0.9982243465217968, pvalue=0.0)
# 	Pearson corr : (0.9998387766055953, 0.0)
# 	MAE : 0.0006718311480582187
# 	MAPE : 0.021412017230934582
# 	RMSE : 0.0010091055046103784
# 	auPRC : 0.9999999999999998
# 	auROC : 1.0
# Eval
# 	Spearman corr : SpearmanrResult(correlation=0.8492831338390272, pvalue=7.323233603889085e-26)
# 	Pearson corr : (0.7706045057954971, 1.0460540101625007e-18)
# 	MAE : 0.023454090616830583
# 	MAPE : 0.47938764417790264
# 	RMSE : 0.050372529657097
# 	auPRC : 0.39924242424242423
# 	auROC : 0.9558823529411765
# Test
# 	Spearman corr : SpearmanrResult(correlation=0.39050362481755685, pvalue=2.4911328385117202e-23)
# 	Pearson corr : (0.3228690551776022, 4.772846977247374e-16)
# 	MAE : 0.11307398633710954
# 	MAPE : 0.7740931980898841
# 	RMSE : 0.15821798941233692
# 	auPRC : 0.5453796203027333
# 	auROC : 0.6688965742099258

# %%
## Correlation values 
from scipy.stats import spearmanr,pearsonr
spearman_train=spearmanr(train_y,train_pred)
spearman_eval=spearmanr(eval_y,eval_pred)
spearman_test=spearmanr(test_y,test_pred)

pearson_train=pearsonr(train_y,train_pred)
pearson_eval=pearsonr(eval_y,eval_pred)
pearson_test=pearsonr(test_y,test_pred)

print("Spearman correlation:")
print("Train:"+str(spearman_train))
print("Eval:"+str(spearman_eval))
print("Test:"+str(spearman_test))
print("\n")
print("Pearson correlation:")
print("Train:"+str(pearson_train))
print("Eval:"+str(pearson_eval))
print("Test:"+str(pearson_test))
# Out:
# Spearman correlation:
# Train:SpearmanrResult(correlation=0.9982243465217968, pvalue=0.0)
# Eval:SpearmanrResult(correlation=0.8492831338390272, pvalue=7.323233603889085e-26)
# Test:SpearmanrResult(correlation=0.39050362481755685, pvalue=2.4911328385117202e-23)
#
#
# Pearson correlation:
# Train:(0.9998387766055953, 0.0)
# Eval:(0.7706045057954971, 1.0460540101625007e-18)
# Test:(0.3228690551776022, 4.772846977247374e-16)

# %%
## MAE
from sklearn.metrics import mean_absolute_error
mae_train=mean_absolute_error(train_y,train_pred)
print("MAE Train:"+str(mae_train))

mae_eval=mean_absolute_error(eval_y,eval_pred)
print("MAE Eval:"+str(mae_eval))

mae_test=mean_absolute_error(test_y,test_pred)
print("MAE Test:"+str(mae_test))
# Out:
# MAE Train:0.0006718311480582187
# MAE Eval:0.023454090616830583
# MAE Test:0.11307398633710954

# %%
## MAPE
pseudocount=0.01
mape_train=np.mean(np.abs((train_y - train_pred) /(pseudocount+train_y))) * 100
print("MAPE Train:"+str(mape_train)+"%")

mape_eval=np.mean(np.abs((eval_y - eval_pred) /(pseudocount+eval_y))) * 100
print("MAPE Eval:"+str(mape_eval)+"%")

mape_test=np.mean(np.abs((test_y - test_pred) /(pseudocount+test_y))) * 100
print("MAPE Test:"+str(mape_test)+"%")
# Out:
# MAPE Train:2.141201723093458%
# MAPE Eval:47.93876441779027%
# MAPE Test:77.40931980898841%

# %%
## RMSE
from sklearn.metrics import mean_squared_error
import math 
rmse_train=math.sqrt(mean_squared_error(train_y,train_pred))
print("RMSE Train:"+str(rmse_train))

rmse_eval=math.sqrt(mean_squared_error(eval_y,eval_pred))
print("RMSE Eval:"+str(rmse_eval))

rmse_test=math.sqrt(mean_squared_error(test_y,test_pred))
print("RMSE Test:"+str(rmse_test))
# Out:
# RMSE Train:0.0010091055046103784
# RMSE Eval:0.050372529657097
# RMSE Test:0.15821798941233692

# %%
## PRC 
## PRC only valid for binary outcomes. 
## Editing levels < 0.5 are labeled as "0". 
## Editing levels >= 0.5 are labeled as "1". 

from sklearn.metrics import auc, precision_recall_curve

precision_train,recall_train,prc_thresholds_train=precision_recall_curve(train_y>=0.2,train_pred)
precision_eval,recall_eval,prc_thresholds_eval=precision_recall_curve(eval_y>=0.2,eval_pred)
precision_test,recall_test,prc_thresholds_test=precision_recall_curve(test_y>=0.4,test_pred)

auprc_train=auc(recall_train,precision_train)
auprc_eval=auc(recall_eval,precision_eval)
auprc_test=auc(recall_test,precision_test)

plt.plot(recall_train,precision_train,'r',label="Train:"+str(round(auprc_train,2)))
plt.plot(recall_eval,precision_eval,'g',label="Eval:"+str(round(auprc_eval,2)))
plt.plot(recall_test,precision_test,'b',label="Test:"+str(round(auprc_test,2)))
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("PRC")
plt.legend()

# %%
## ROC
from sklearn.metrics import roc_curve, roc_auc_score
fpr_train,tpr_train,roc_thresholds_train=roc_curve(train_y>=0.2,train_pred)
fpr_eval,tpr_eval,roc_thresholds_eval=roc_curve(eval_y>=0.2,eval_pred)
fpr_test,tpr_test,roc_thresholds_test=roc_curve(test_y>=0.4,test_pred)

auroc_train=roc_auc_score(train_y>=0.2,train_pred)
auroc_eval=roc_auc_score(eval_y>=0.2,eval_pred)
auroc_test=roc_auc_score(test_y>=0.4,test_pred)

plt.plot(fpr_train,tpr_train,'r',label="Train:"+str(round(auroc_train,2)))
plt.plot(fpr_eval,tpr_eval,'g',label="Eval:"+str(round(auroc_eval,2)))
plt.plot(fpr_test,tpr_test,'b',label="Test:"+str(round(auroc_test,2)))
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC")
plt.legend()

# %%
#plot the test set predictions 
matplotlib.rcParams['figure.figsize'] = [20, 8]
plt.subplot(1,3,1)
plt.plot(list(train_y),list(train_pred),'o')
plt.xlabel("Observed train set editing level, TTYH2 Comp")
plt.ylabel("Predicted train set editing level, TTYH2 Comp")
plt.subplot(1,3,2)
plt.plot(list(eval_y),list(eval_pred),'o')
plt.xlabel("Observed eval set editing level, TTYH2 Comp")
plt.ylabel("Predicted eval set editing level, TTYH2 Comp")
plt.subplot(1,3,3)
plt.plot(list(test_y),list(test_pred),'o')
plt.xlabel("Observed test set editing level, AJUBA Comp")
plt.ylabel("Predicted test set editing level, AJUBA Comp")

plt.show()

# %%
#calculate R^2, which is representative of variance explained 
# https://datascienceplus.com/extreme-gradient-boosting-with-r/
# https://arxiv.org/pdf/1706.06060.pdf

residuals = test_y - test_pred

y_test_mean = np.mean(test_pred)
print(y_test_mean)
#calculate total sum of squares 
tss=sum((test_y-y_test_mean)*(test_y-y_test_mean))
print(tss)
# Calculate residual sum of squares
rss =  sum(residuals*residuals)
print(rss)
# Calculate R-squared
rsq  =  1 - (rss/tss)
print('The R-square of the test data is ', round(rsq,3), '\n')
# Out:
# 0.06556241
# 15.328899338361934
# 15.044792236383078
# The R-square of the test data is  0.019
