# %% [markdown]
# <a href="https://colab.research.google.com/github/kundajelab/adar_editing/blob/master/xgboost_with_shap/NEIL1_XGBOOST_WITH_TREESHAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Uncomment these lines if running as a google colab notebook: 
#!pip install numpy==1.15
#! git clone https://github.com/kundajelab/adar_editing
#import os
#os.chdir("adar_editing/xgboost_with_shap/")
#!pip install shap
#!pip install --upgrade xgboost
#!pip install cufflinks

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# def configure_plotly_browser_state():
#   import IPython
#   display(IPython.core.display.HTML('''
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
#         '''))

# %%
#helper utilities for model training and interpretation 
import shap
from helpers import * 

#set a random seed so code is reproducible 
random.seed(1234)

# load JS visualization code to notebook
shap.initjs()
import warnings
warnings.filterwarnings('ignore')

#visualization utilities 
import matplotlib
import matplotlib.pyplot as plt 
# %matplotlib inline
import chart_studio.plotly as plotly
import numpy as np
from plotly.offline import iplot
from plotly.graph_objs import Heatmap
#rom chart_studio.plotly.offline import iplot
#rom chart_studio.plotly.graph_objs import Heatmap
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# ## Neil1 xgboost with TreeShap <a name='outline'>
# <ol>
#     <li><a href=#3>Computational Dataset</a></li>
#     <li><a href=#4>Computational Dataset Feature Subsets</a></li>
#     <li><a href=#5>Exclude mut features</a></li>
#  </ol>

# %% [markdown]
# ## Neil1 Computational features <a name='3'>
# <a href=#outline>Home</a>

# %%
import pandas as pd 
import xgboost
#data=pd.read_csv("../xin_feature_matrices/neil1_computational.features.csv",header=0,sep=',',index_col=0)
#impute missing features 
data=pd.read_csv("../missing_feature_imputation/neil1.computational.imputed.tsv",header=0,sep='\t',index_col=0)

# %%
data.head()
# Out:
#         editing_value  free_energy  sim_nor_score  probability_active_conf  \
# rna_id
# 1                0.58       -41.29         0.9930                 0.137610
# 2                0.46       -39.30         0.9125                 0.131799
# 3                0.49       -40.32         0.9301                 0.065449
# 4                0.48       -44.78         1.0000                 0.321958
# 5                0.59       -41.45         0.7448                 0.169233
#
#         num_mutations  mut_exist  mut_pos  mut_site_dist  mut_same_as_site  \
# rna_id
# 1                   1          1     41.0           -6.0               0.0
# 2                   1          1     42.0           -5.0               0.0
# 3                   1          1     43.0           -4.0               0.0
# 4                   1          1     44.0           -3.0               0.0
# 5                   1          1     45.0           -2.0               0.0
#
#         all_stem_length  ...  u2_5prm_cp_internal  u2_3prm_cp_internal  \
# rna_id                   ...
# 1                    29  ...                  NaN                  NaN
# 2                    30  ...                  NaN                  NaN
# 3                    30  ...                  NaN                  NaN
# 4                    30  ...                  NaN                  NaN
# 5                    26  ...                  NaN                  NaN
#
#         u3_struct  d1_struct  d2_struct  d2_5prm_cp_bulge  d2_3prm_cp_bulge  \
# rna_id
# 1             NaN          S          I               NaN               NaN
# 2               S          S          I               NaN               NaN
# 3               S          S          I               NaN               NaN
# 4             NaN          S          I               NaN               NaN
# 5             NaN          S          I               NaN               NaN
#
#         d2_5prm_cp_internal  d2_3prm_cp_internal  d3_struct
# rna_id
# 1                       U:A                  G:C          S
# 2                       U:A                  G:C          S
# 3                       U:A                  G:C          S
# 4                       U:A                  G:C          S
# 5                       U:G                  C:G          S
#
# [5 rows x 83 columns]

# %%
#remove any null editing level values 
data=data[~data["editing_value"].isnull().values]

# %%
data=format_for_xgboost(data)
train_split,eval_split,test_split=split_train_test_eval_by_mut_pos(data)
# Out:
# (460, 158)
# {-0.0632850493916375: 1, 0.20360732390633102: 1, 0.728370255368246: 1, 0.860450808762366: 1, 0.8695218068149521: 1, 0.871797278995544: 1, 0.919814095623327: 1, 0.9298686496387529: 1, 0.9574117859672471: 1, 0.9964567407004051: 1, 1.02331239586858: 1, 1.0443148129309199: 1, 1.0676575736099: 1, 1.09896677613689: 1, 1.19994864844643: 1, 1.2193843872360601: 1, 1.34030712556689: 1, 1.41473007488058: 1, 1.42049779340065: 1, 1.4456310293972299: 1, 1.4534068395766202: 1, 20.0: 4, 21.0: 4, 22.0: 4, 23.0: 4, 24.0: 4, 25.0: 4, 26.0: 3, 27.0: 4, 28.0: 4, 29.0: 4, 30.0: 3, 31.0: 4, 32.0: 4, 33.0: 4, 34.0: 4, 35.0: 4, 36.0: 4, 41.0: 21, 42.0: 21, 43.0: 21, 44.0: 21, 45.0: 21, 46.0: 20, 48.0: 20, 49.0: 21, 50.0: 21, 51.0: 20, 52.0: 20, 53.0: 21, 54.0: 21, 55.0: 21, 56.0: 21, 57.0: 21, 58.0: 41}

# %%
#Remove any non-varying features 
train_novar=get_singleval_features(train_split)
eval_novar=get_singleval_features(eval_split)
test_novar=get_singleval_features(test_split)
uniform_features_to_drop=list(set(train_novar+eval_novar+test_novar))

# %%
#Remove any null features 
train_null=get_all_null_features(train_split)
eval_null=get_all_null_features(eval_split)
test_null=get_all_null_features(test_split)
null_features_to_drop=list(set(train_null+eval_null+test_null))

# %%
to_drop=list(set(uniform_features_to_drop+null_features_to_drop))
print("\n".join(to_drop))
# Out:
# site_prev_struct:S
# site_5prm_cp_bulge:C:G
# d2_5prm_cp_bulge:A:U
# d3_struct:S
# d2_3prm_cp_bulge:U:A
# d2_exist
# u2_3prm_cp_bulge:A:U
# d2_5prm_cp_internal:A:U
# site_5prm_cp_hairpin:U:A
# u2_5prm_cp_bulge:G:U
# site_5prm_cp_internal:G:C
# mut_type:wt
# site_5prm_cp_internal:A:U
# d1_distance
# d2_5prm_cp_bulge:U:A
# mut_prev_struct:B
# u2_5prm_cp_hairpin:U:G
# mut_ref_struct:I
# site_next_struct:S
# d3_exist
# mut_prev_struct:M
# u2_5prm_cp_internal:U:G
# d2_5prm_cp_internal:G:U
# site_prev_nt:C
# d1_struct:S
# site_5prm_cp_bulge:G:U
# d2_5prm_cp_bulge:U:G
# d2_5prm_cp_bulge:G:U
# d2_3prm_cp_bulge:G:U
# site_3prm_cp_bulge:G:C
# site_1_1:A:U
# d1_exist
# mut_ref_nt:G
# site_struct:M
# d2_3prm_cp_bulge:U:G
# site_5prm_cp_internal:U:G
# site_next_nt:C
# mut_ref_nt:A
# d2_3prm_cp_internal:G:U
# mut_exist
# site_struct:S
# u2_5prm_cp_hairpin:U:A
# site_5prm_cp_hairpin:G:C
# site_1_1:A:G
# mut_ref_struct:B
# site_5prm_cp_bulge:A:U
# u2_5prm_cp_internal:C:G
# d2_3prm_cp_internal:U:A
# mut_ref_nt:U
# site_3prm_cp_internal:U:A
# site_5prm_cp_hairpin:C:G
# u2_5prm_cp_bulge:A:U

# %%
train_split=train_split.drop(to_drop,axis=1)
eval_split=eval_split.drop(to_drop,axis=1)
test_split=test_split.drop(to_drop,axis=1)

# %%
train_y=train_split['editing_value']
train_X=train_split.drop(['editing_value'],axis=1)

eval_y=eval_split['editing_value']
eval_X=eval_split.drop(['editing_value'],axis=1)

test_y=test_split['editing_value']
test_X=test_split.drop(['editing_value'],axis=1)

# %%
print(train_X.shape)
print(train_y.shape)
print(eval_X.shape)
print(eval_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (295, 105)
# (295,)
# (70, 105)
# (70,)
# (74, 105)
# (74,)

# %%
## format matrixes for xgboost 
dtrain=xgboost.DMatrix(train_X,train_y)
deval=xgboost.DMatrix(eval_X,eval_y)
dtest=xgboost.DMatrix(test_X,test_y)

# %%
## set model training parameters 
param=dict() 
param['nthread'] = 20
#rmse -- root mean square error 
# mae -- mean absolute error 
# map -- mean average precision 
# auc -- area under ROC curve 
# aucpr -- area under precision recall curve 
param['eval_metric'] = ['auc','mae','map','aucpr','rmse']

# %%
evallist = [(deval, 'eval'), (dtrain, 'train')]

# %%
num_round = 1000
bst = xgboost.train(param, dtrain, num_round, evallist,early_stopping_rounds=10)
# Out:
# [0]	eval-auc:0.73566	eval-mae:0.23612	eval-map:1.00000	eval-aucpr:0.39749	eval-rmse:0.26743	train-auc:0.79663	train-mae:0.18945	train-map:1.00000	train-aucpr:0.56461	train-rmse:0.22686
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 10 rounds.
# [1]	eval-auc:0.76436	eval-mae:0.18186	eval-map:1.00000	eval-aucpr:0.43000	eval-rmse:0.20601	train-auc:0.80529	train-mae:0.14039	train-map:1.00000	train-aucpr:0.57878	train-rmse:0.16791
# [2]	eval-auc:0.77299	eval-mae:0.13936	eval-map:1.00000	eval-aucpr:0.44881	eval-rmse:0.16280	train-auc:0.80888	train-mae:0.10584	train-map:1.00000	train-aucpr:0.58480	train-rmse:0.12661
# [3]	eval-auc:0.77421	eval-mae:0.11450	eval-map:1.00000	eval-aucpr:0.44733	eval-rmse:0.13978	train-auc:0.81090	train-mae:0.08176	train-map:1.00000	train-aucpr:0.58908	train-rmse:0.09831
# [4]	eval-auc:0.77719	eval-mae:0.09963	eval-map:1.00000	eval-aucpr:0.44483	eval-rmse:0.12748	train-auc:0.81296	train-mae:0.06424	train-map:1.00000	train-aucpr:0.58927	train-rmse:0.07789
# [5]	eval-auc:0.78067	eval-mae:0.08968	eval-map:1.00000	eval-aucpr:0.44005	eval-rmse:0.12093	train-auc:0.81425	train-mae:0.05193	train-map:1.00000	train-aucpr:0.59208	train-rmse:0.06359
# [6]	eval-auc:0.78194	eval-mae:0.08001	eval-map:1.00000	eval-aucpr:0.44469	eval-rmse:0.11483	train-auc:0.81561	train-mae:0.04207	train-map:1.00000	train-aucpr:0.59371	train-rmse:0.05233
# [7]	eval-auc:0.78199	eval-mae:0.07697	eval-map:1.00000	eval-aucpr:0.44568	eval-rmse:0.11459	train-auc:0.81632	train-mae:0.03495	train-map:1.00000	train-aucpr:0.59614	train-rmse:0.04430
# [8]	eval-auc:0.78215	eval-mae:0.07221	eval-map:1.00000	eval-aucpr:0.44532	eval-rmse:0.11172	train-auc:0.81703	train-mae:0.02937	train-map:1.00000	train-aucpr:0.59726	train-rmse:0.03811
# [9]	eval-auc:0.78354	eval-mae:0.07021	eval-map:1.00000	eval-aucpr:0.44424	eval-rmse:0.11017	train-auc:0.81753	train-mae:0.02517	train-map:1.00000	train-aucpr:0.59829	train-rmse:0.03299
# [10]	eval-auc:0.78295	eval-mae:0.06979	eval-map:1.00000	eval-aucpr:0.44233	eval-rmse:0.11080	train-auc:0.81778	train-mae:0.02253	train-map:1.00000	train-aucpr:0.59882	train-rmse:0.02983
# [11]	eval-auc:0.78329	eval-mae:0.06965	eval-map:1.00000	eval-aucpr:0.44220	eval-rmse:0.11115	train-auc:0.81808	train-mae:0.02055	train-map:1.00000	train-aucpr:0.59928	train-rmse:0.02755
# [12]	eval-auc:0.78265	eval-mae:0.06930	eval-map:1.00000	eval-aucpr:0.44061	eval-rmse:0.11108	train-auc:0.81826	train-mae:0.01846	train-map:1.00000	train-aucpr:0.59970	train-rmse:0.02498
# [13]	eval-auc:0.78313	eval-mae:0.06963	eval-map:1.00000	eval-aucpr:0.44093	eval-rmse:0.11142	train-auc:0.81841	train-mae:0.01738	train-map:1.00000	train-aucpr:0.59986	train-rmse:0.02366
# [14]	eval-auc:0.78496	eval-mae:0.06920	eval-map:1.00000	eval-aucpr:0.44568	eval-rmse:0.11053	train-auc:0.81861	train-mae:0.01603	train-map:1.00000	train-aucpr:0.60008	train-rmse:0.02181
# [15]	eval-auc:0.78531	eval-mae:0.06856	eval-map:1.00000	eval-aucpr:0.44667	eval-rmse:0.10997	train-auc:0.81876	train-mae:0.01520	train-map:1.00000	train-aucpr:0.60027	train-rmse:0.02081
# [16]	eval-auc:0.78564	eval-mae:0.06828	eval-map:1.00000	eval-aucpr:0.44774	eval-rmse:0.10953	train-auc:0.81886	train-mae:0.01439	train-map:1.00000	train-aucpr:0.60032	train-rmse:0.01986
# [17]	eval-auc:0.78464	eval-mae:0.06850	eval-map:1.00000	eval-aucpr:0.44535	eval-rmse:0.11012	train-auc:0.81900	train-mae:0.01331	train-map:1.00000	train-aucpr:0.60052	train-rmse:0.01854
# [18]	eval-auc:0.78424	eval-mae:0.06833	eval-map:1.00000	eval-aucpr:0.44424	eval-rmse:0.10985	train-auc:0.81905	train-mae:0.01278	train-map:1.00000	train-aucpr:0.60058	train-rmse:0.01789
# [19]	eval-auc:0.78590	eval-mae:0.06773	eval-map:1.00000	eval-aucpr:0.44671	eval-rmse:0.10928	train-auc:0.81916	train-mae:0.01177	train-map:1.00000	train-aucpr:0.60069	train-rmse:0.01681
# [20]	eval-auc:0.78539	eval-mae:0.06794	eval-map:1.00000	eval-aucpr:0.44653	eval-rmse:0.10986	train-auc:0.81920	train-mae:0.01124	train-map:1.00000	train-aucpr:0.60071	train-rmse:0.01622
# [21]	eval-auc:0.78601	eval-mae:0.06789	eval-map:1.00000	eval-aucpr:0.44697	eval-rmse:0.10978	train-auc:0.81923	train-mae:0.01088	train-map:1.00000	train-aucpr:0.60073	train-rmse:0.01578
# [22]	eval-auc:0.78635	eval-mae:0.06781	eval-map:1.00000	eval-aucpr:0.44776	eval-rmse:0.10969	train-auc:0.81930	train-mae:0.01027	train-map:1.00000	train-aucpr:0.60085	train-rmse:0.01479
# [23]	eval-auc:0.78531	eval-mae:0.06753	eval-map:1.00000	eval-aucpr:0.44643	eval-rmse:0.10958	train-auc:0.81933	train-mae:0.00977	train-map:1.00000	train-aucpr:0.60088	train-rmse:0.01430
# [24]	eval-auc:0.78483	eval-mae:0.06735	eval-map:1.00000	eval-aucpr:0.44630	eval-rmse:0.10931	train-auc:0.81943	train-mae:0.00888	train-map:1.00000	train-aucpr:0.60105	train-rmse:0.01308
# [25]	eval-auc:0.78505	eval-mae:0.06730	eval-map:1.00000	eval-aucpr:0.44637	eval-rmse:0.10931	train-auc:0.81947	train-mae:0.00860	train-map:1.00000	train-aucpr:0.60110	train-rmse:0.01267
# [26]	eval-auc:0.78495	eval-mae:0.06760	eval-map:1.00000	eval-aucpr:0.44632	eval-rmse:0.10961	train-auc:0.81952	train-mae:0.00826	train-map:1.00000	train-aucpr:0.60118	train-rmse:0.01219
# [27]	eval-auc:0.78560	eval-mae:0.06773	eval-map:1.00000	eval-aucpr:0.44741	eval-rmse:0.10980	train-auc:0.81953	train-mae:0.00800	train-map:1.00000	train-aucpr:0.60122	train-rmse:0.01184
# [28]	eval-auc:0.78546	eval-mae:0.06791	eval-map:1.00000	eval-aucpr:0.44699	eval-rmse:0.10984	train-auc:0.81959	train-mae:0.00749	train-map:1.00000	train-aucpr:0.60125	train-rmse:0.01114
# [29]	eval-auc:0.78600	eval-mae:0.06768	eval-map:1.00000	eval-aucpr:0.44716	eval-rmse:0.10982	train-auc:0.81963	train-mae:0.00721	train-map:1.00000	train-aucpr:0.60129	train-rmse:0.01078
# [30]	eval-auc:0.78554	eval-mae:0.06808	eval-map:1.00000	eval-aucpr:0.44739	eval-rmse:0.11025	train-auc:0.81966	train-mae:0.00673	train-map:1.00000	train-aucpr:0.60133	train-rmse:0.01017
# [31]	eval-auc:0.78497	eval-mae:0.06790	eval-map:1.00000	eval-aucpr:0.44434	eval-rmse:0.11043	train-auc:0.81971	train-mae:0.00609	train-map:1.00000	train-aucpr:0.60141	train-rmse:0.00919
# [32]	eval-auc:0.78486	eval-mae:0.06766	eval-map:1.00000	eval-aucpr:0.44432	eval-rmse:0.10999	train-auc:0.81976	train-mae:0.00555	train-map:1.00000	train-aucpr:0.60143	train-rmse:0.00829
# [33]	eval-auc:0.78478	eval-mae:0.06775	eval-map:1.00000	eval-aucpr:0.44429	eval-rmse:0.11004	train-auc:0.81977	train-mae:0.00538	train-map:1.00000	train-aucpr:0.60144	train-rmse:0.00809
# [34]	eval-auc:0.78489	eval-mae:0.06772	eval-map:1.00000	eval-aucpr:0.44434	eval-rmse:0.10998	train-auc:0.81978	train-mae:0.00510	train-map:1.00000	train-aucpr:0.60146	train-rmse:0.00769
# [35]	eval-auc:0.78489	eval-mae:0.06776	eval-map:1.00000	eval-aucpr:0.44434	eval-rmse:0.11001	train-auc:0.81979	train-mae:0.00494	train-map:1.00000	train-aucpr:0.60147	train-rmse:0.00751
# [36]	eval-auc:0.78611	eval-mae:0.06769	eval-map:1.00000	eval-aucpr:0.44740	eval-rmse:0.10973	train-auc:0.81981	train-mae:0.00467	train-map:1.00000	train-aucpr:0.60149	train-rmse:0.00697
# [37]	eval-auc:0.78611	eval-mae:0.06774	eval-map:1.00000	eval-aucpr:0.44740	eval-rmse:0.10978	train-auc:0.81982	train-mae:0.00458	train-map:1.00000	train-aucpr:0.60151	train-rmse:0.00685
# [38]	eval-auc:0.78637	eval-mae:0.06765	eval-map:1.00000	eval-aucpr:0.44747	eval-rmse:0.10959	train-auc:0.81984	train-mae:0.00413	train-map:1.00000	train-aucpr:0.60154	train-rmse:0.00620
# [39]	eval-auc:0.78615	eval-mae:0.06775	eval-map:1.00000	eval-aucpr:0.44726	eval-rmse:0.10963	train-auc:0.81985	train-mae:0.00398	train-map:1.00000	train-aucpr:0.60156	train-rmse:0.00602
# [40]	eval-auc:0.78602	eval-mae:0.06780	eval-map:1.00000	eval-aucpr:0.44750	eval-rmse:0.10962	train-auc:0.81986	train-mae:0.00387	train-map:1.00000	train-aucpr:0.60156	train-rmse:0.00586
# [41]	eval-auc:0.78602	eval-mae:0.06782	eval-map:1.00000	eval-aucpr:0.44750	eval-rmse:0.10964	train-auc:0.81987	train-mae:0.00374	train-map:1.00000	train-aucpr:0.60157	train-rmse:0.00562
# [42]	eval-auc:0.78672	eval-mae:0.06777	eval-map:1.00000	eval-aucpr:0.44812	eval-rmse:0.10948	train-auc:0.81988	train-mae:0.00355	train-map:1.00000	train-aucpr:0.60156	train-rmse:0.00540
# [43]	eval-auc:0.78668	eval-mae:0.06771	eval-map:1.00000	eval-aucpr:0.44812	eval-rmse:0.10949	train-auc:0.81988	train-mae:0.00341	train-map:1.00000	train-aucpr:0.60158	train-rmse:0.00515
# [44]	eval-auc:0.78668	eval-mae:0.06771	eval-map:1.00000	eval-aucpr:0.44812	eval-rmse:0.10948	train-auc:0.81989	train-mae:0.00327	train-map:1.00000	train-aucpr:0.60159	train-rmse:0.00494
# [45]	eval-auc:0.78675	eval-mae:0.06777	eval-map:1.00000	eval-aucpr:0.44823	eval-rmse:0.10956	train-auc:0.81989	train-mae:0.00309	train-map:1.00000	train-aucpr:0.60160	train-rmse:0.00469
# [46]	eval-auc:0.78683	eval-mae:0.06782	eval-map:1.00000	eval-aucpr:0.44826	eval-rmse:0.10962	train-auc:0.81990	train-mae:0.00301	train-map:1.00000	train-aucpr:0.60160	train-rmse:0.00460
# [47]	eval-auc:0.78620	eval-mae:0.06795	eval-map:1.00000	eval-aucpr:0.44753	eval-rmse:0.10969	train-auc:0.81990	train-mae:0.00283	train-map:1.00000	train-aucpr:0.60164	train-rmse:0.00425
# [48]	eval-auc:0.78620	eval-mae:0.06793	eval-map:1.00000	eval-aucpr:0.44753	eval-rmse:0.10966	train-auc:0.81990	train-mae:0.00274	train-map:1.00000	train-aucpr:0.60164	train-rmse:0.00415
# [49]	eval-auc:0.78621	eval-mae:0.06786	eval-map:1.00000	eval-aucpr:0.44754	eval-rmse:0.10965	train-auc:0.81990	train-mae:0.00264	train-map:1.00000	train-aucpr:0.60164	train-rmse:0.00404
# [50]	eval-auc:0.78621	eval-mae:0.06781	eval-map:1.00000	eval-aucpr:0.44754	eval-rmse:0.10972	train-auc:0.81990	train-mae:0.00248	train-map:1.00000	train-aucpr:0.60162	train-rmse:0.00378
# [51]	eval-auc:0.78621	eval-mae:0.06786	eval-map:1.00000	eval-aucpr:0.44754	eval-rmse:0.10977	train-auc:0.81991	train-mae:0.00235	train-map:1.00000	train-aucpr:0.60163	train-rmse:0.00359
# [52]	eval-auc:0.78620	eval-mae:0.06787	eval-map:1.00000	eval-aucpr:0.44753	eval-rmse:0.10977	train-auc:0.81991	train-mae:0.00224	train-map:1.00000	train-aucpr:0.60165	train-rmse:0.00344
# [53]	eval-auc:0.78620	eval-mae:0.06793	eval-map:1.00000	eval-aucpr:0.44753	eval-rmse:0.10977	train-auc:0.81991	train-mae:0.00213	train-map:1.00000	train-aucpr:0.60165	train-rmse:0.00324
# [54]	eval-auc:0.78620	eval-mae:0.06793	eval-map:1.00000	eval-aucpr:0.44753	eval-rmse:0.10987	train-auc:0.81992	train-mae:0.00196	train-map:1.00000	train-aucpr:0.60165	train-rmse:0.00294
# [55]	eval-auc:0.78620	eval-mae:0.06791	eval-map:1.00000	eval-aucpr:0.44753	eval-rmse:0.10978	train-auc:0.81992	train-mae:0.00189	train-map:1.00000	train-aucpr:0.60165	train-rmse:0.00282
# [56]	eval-auc:0.78615	eval-mae:0.06785	eval-map:1.00000	eval-aucpr:0.44735	eval-rmse:0.10971	train-auc:0.81992	train-mae:0.00177	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00264
# [57]	eval-auc:0.78615	eval-mae:0.06785	eval-map:1.00000	eval-aucpr:0.44735	eval-rmse:0.10970	train-auc:0.81992	train-mae:0.00173	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00257
# [58]	eval-auc:0.78615	eval-mae:0.06782	eval-map:1.00000	eval-aucpr:0.44735	eval-rmse:0.10969	train-auc:0.81992	train-mae:0.00163	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00242
# [59]	eval-auc:0.78615	eval-mae:0.06783	eval-map:1.00000	eval-aucpr:0.44735	eval-rmse:0.10971	train-auc:0.81992	train-mae:0.00154	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00227
# [60]	eval-auc:0.78615	eval-mae:0.06777	eval-map:1.00000	eval-aucpr:0.44735	eval-rmse:0.10970	train-auc:0.81993	train-mae:0.00141	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00208
# [61]	eval-auc:0.78615	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44735	eval-rmse:0.10971	train-auc:0.81993	train-mae:0.00139	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00205
# [62]	eval-auc:0.78601	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10973	train-auc:0.81993	train-mae:0.00135	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00199
# [63]	eval-auc:0.78601	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10975	train-auc:0.81993	train-mae:0.00132	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00196
# [64]	eval-auc:0.78601	eval-mae:0.06779	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10974	train-auc:0.81993	train-mae:0.00129	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00191
# [65]	eval-auc:0.78601	eval-mae:0.06779	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00125	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00182
# [66]	eval-auc:0.78606	eval-mae:0.06782	eval-map:1.00000	eval-aucpr:0.44748	eval-rmse:0.10979	train-auc:0.81993	train-mae:0.00118	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00170
# [67]	eval-auc:0.78606	eval-mae:0.06785	eval-map:1.00000	eval-aucpr:0.44748	eval-rmse:0.10980	train-auc:0.81993	train-mae:0.00112	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00161
# [68]	eval-auc:0.78606	eval-mae:0.06784	eval-map:1.00000	eval-aucpr:0.44748	eval-rmse:0.10979	train-auc:0.81993	train-mae:0.00109	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00157
# [69]	eval-auc:0.78620	eval-mae:0.06785	eval-map:1.00000	eval-aucpr:0.44753	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00106	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00150
# [70]	eval-auc:0.78591	eval-mae:0.06783	eval-map:1.00000	eval-aucpr:0.44742	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00098	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00142
# [71]	eval-auc:0.78586	eval-mae:0.06779	eval-map:1.00000	eval-aucpr:0.44724	eval-rmse:0.10975	train-auc:0.81993	train-mae:0.00096	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00139
# [72]	eval-auc:0.78605	eval-mae:0.06780	eval-map:1.00000	eval-aucpr:0.44747	eval-rmse:0.10976	train-auc:0.81993	train-mae:0.00089	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00130
# [73]	eval-auc:0.78607	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44747	eval-rmse:0.10976	train-auc:0.81993	train-mae:0.00087	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00128
# [74]	eval-auc:0.78607	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44747	eval-rmse:0.10976	train-auc:0.81993	train-mae:0.00085	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00125
# [75]	eval-auc:0.78607	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44747	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00081	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00119
# [76]	eval-auc:0.78607	eval-mae:0.06779	eval-map:1.00000	eval-aucpr:0.44748	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00078	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00114
# [77]	eval-auc:0.78602	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00073	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00106
# [78]	eval-auc:0.78602	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00073	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00106
# [79]	eval-auc:0.78602	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00073	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00106
# [80]	eval-auc:0.78602	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00073	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00106
# [81]	eval-auc:0.78602	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00073	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00106
# [82]	eval-auc:0.78602	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00073	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00106
# [83]	eval-auc:0.78602	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00073	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00106
# [84]	eval-auc:0.78602	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00073	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00106
# [85]	eval-auc:0.78602	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00073	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00106
# [86]	eval-auc:0.78602	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00073	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00106
# [87]	eval-auc:0.78602	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00073	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00106
# Stopping. Best iteration:
# [77]	eval-auc:0.78602	eval-mae:0.06778	eval-map:1.00000	eval-aucpr:0.44730	eval-rmse:0.10977	train-auc:0.81993	train-mae:0.00073	train-map:1.00000	train-aucpr:0.60166	train-rmse:0.00106

# %%
# save to binary file for faster loading
bst.save_model('neil1.computational.model')
# save model to text file 
bst.dump_model('neil1.computational.raw.txt')

# %%
## get model predictions on the test, training, and eval splits 
test_pred = bst.predict(dtest)
train_pred=bst.predict(dtrain)
eval_pred=bst.predict(deval)

# %%
#calculate R^2, which is representative of variance explained 
# https://datascienceplus.com/extreme-gradient-boosting-with-r/
# https://arxiv.org/pdf/1706.06060.pdf

residuals = test_y - test_pred

y_test_mean = np.mean(test_pred)
print(y_test_mean)
#calculate total sum of squares 
tss=sum((test_y-y_test_mean)*(test_y-y_test_mean))
print(tss)
# Calculate residual sum of squares
rss =  sum(residuals*residuals)
print(rss)
# Calculate R-squared
rsq  =  1 - (rss/tss)
print('The R-square of the test data is ', round(rsq,3), '\n')
# Out:
# 0.22641836
# 4.563315849117006
# 1.1340527758099652
# The R-square of the test data is  0.751

# %%
## get performance metrics on full dataset 
from helpers import * 
print_aggregate_peformance_metrics(train_y,train_pred,
                                   eval_y,eval_pred,
                                   test_y,test_pred,
                                   positive_thresh=0.2)
# Out:
# Train
# 	Spearman corr : SpearmanrResult(correlation=0.9994569280884723, pvalue=0.0)
# 	Pearson corr : (0.9999901811474724, 0.0)
# 	MAE : 0.0007314922239028579
# 	MAPE : 0.006711161489275171
# 	RMSE : 0.0010612472116194938
# 	auPRC : 0.9999249538018358
# 	auROC : 1.0
# Eval
# 	Spearman corr : SpearmanrResult(correlation=0.8249885751953575, pvalue=1.6288385472424231e-18)
# 	Pearson corr : (0.8455947370594862, 3.2933226384858146e-20)
# 	MAE : 0.06778499121436708
# 	MAPE : 0.666022734389793
# 	RMSE : 0.10977239137621339
# 	auPRC : 0.9218629933206135
# 	auROC : 0.939625850340136
# Test
# 	Spearman corr : SpearmanrResult(correlation=0.8356076777554258, pvalue=2.0657240331698004e-20)
# 	Pearson corr : (0.8671999994031316, 1.6971996825033993e-23)
# 	MAE : 0.07548983291857819
# 	MAPE : 0.6397662743995498
# 	RMSE : 0.1237943355365886
# 	auPRC : 0.9139442370205307
# 	auROC : 0.927231807951988

# %%
## Correlation values 
from scipy.stats import spearmanr,pearsonr
spearman_train=spearmanr(train_y,train_pred)
spearman_eval=spearmanr(eval_y,eval_pred)
spearman_test=spearmanr(test_y,test_pred)

pearson_train=pearsonr(train_y,train_pred)
pearson_eval=pearsonr(eval_y,eval_pred)
pearson_test=pearsonr(test_y,test_pred)

print("Spearman correlation:")
print("Train:"+str(spearman_train))
print("Eval:"+str(spearman_eval))
print("Test:"+str(spearman_test))
print("\n")
print("Pearson correlation:")
print("Train:"+str(pearson_train))
print("Eval:"+str(pearson_eval))
print("Test:"+str(pearson_test))
# Out:
# Spearman correlation:
# Train:SpearmanrResult(correlation=0.9994569280884723, pvalue=0.0)
# Eval:SpearmanrResult(correlation=0.8249885751953575, pvalue=1.6288385472424231e-18)
# Test:SpearmanrResult(correlation=0.8356076777554258, pvalue=2.0657240331698004e-20)
#
#
# Pearson correlation:
# Train:(0.9999901811474724, 0.0)
# Eval:(0.8455947370594862, 3.2933226384858146e-20)
# Test:(0.8671999994031316, 1.6971996825033993e-23)

# %%
## MAE
from sklearn.metrics import mean_absolute_error
mae_train=mean_absolute_error(train_y,train_pred)
print("MAE Train:"+str(mae_train))

mae_eval=mean_absolute_error(eval_y,eval_pred)
print("MAE Eval:"+str(mae_eval))

mae_test=mean_absolute_error(test_y,test_pred)
print("MAE Test:"+str(mae_test))
# Out:
# MAE Train:0.0007314922239028579
# MAE Eval:0.06778499121436708
# MAE Test:0.07548983291857819

# %%
## MAPE
pseudocount=0.01
mape_train=np.mean(np.abs((train_y - train_pred) /(pseudocount+train_y))) * 100
print("MAPE Train:"+str(mape_train)+"%")

mape_eval=np.mean(np.abs((eval_y - eval_pred) /(pseudocount+eval_y))) * 100
print("MAPE Eval:"+str(mape_eval)+"%")

mape_test=np.mean(np.abs((test_y - test_pred) /(pseudocount+test_y))) * 100
print("MAPE Test:"+str(mape_test)+"%")
# Out:
# MAPE Train:0.6711161489275171%
# MAPE Eval:66.6022734389793%
# MAPE Test:63.97662743995498%

# %%
## RMSE
from sklearn.metrics import mean_squared_error
import math 
rmse_train=math.sqrt(mean_squared_error(train_y,train_pred))
print("RMSE Train:"+str(rmse_train))

rmse_eval=math.sqrt(mean_squared_error(eval_y,eval_pred))
print("RMSE Eval:"+str(rmse_eval))

rmse_test=math.sqrt(mean_squared_error(test_y,test_pred))
print("RMSE Test:"+str(rmse_test))
# Out:
# RMSE Train:0.0010612472116194938
# RMSE Eval:0.10977239137621339
# RMSE Test:0.1237943355365886

# %%
## PRC 
## PRC only valid for binary outcomes. 
## Editing levels < 0.5 are labeled as "0". 
## Editing levels >= 0.5 are labeled as "1". 

from sklearn.metrics import auc, precision_recall_curve

precision_train,recall_train,prc_thresholds_train=precision_recall_curve(train_y>=0.5,train_pred)
precision_eval,recall_eval,prc_thresholds_eval=precision_recall_curve(eval_y>=0.5,eval_pred)
precision_test,recall_test,prc_thresholds_test=precision_recall_curve(test_y>=0.5,test_pred)

auprc_train=auc(recall_train,precision_train)
auprc_eval=auc(recall_eval,precision_eval)
auprc_test=auc(recall_test,precision_test)

plt.plot(recall_train,precision_train,'r',label="Train:"+str(round(auprc_train,2)))
plt.plot(recall_eval,precision_eval,'g',label="Eval:"+str(round(auprc_eval,2)))
plt.plot(recall_test,precision_test,'b',label="Test:"+str(round(auprc_test,2)))
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("PRC")
plt.legend()

# %%
## ROC
from sklearn.metrics import roc_curve, roc_auc_score
fpr_train,tpr_train,roc_thresholds_train=roc_curve(train_y>=0.5,train_pred)
fpr_eval,tpr_eval,roc_thresholds_eval=roc_curve(eval_y>=0.5,eval_pred)
fpr_test,tpr_test,roc_thresholds_test=roc_curve(test_y>=0.5,test_pred)

auroc_train=roc_auc_score(train_y>=0.5,train_pred)
auroc_eval=roc_auc_score(eval_y>=0.5,eval_pred)
auroc_test=roc_auc_score(test_y>=0.5,test_pred)

plt.plot(fpr_train,tpr_train,'r',label="Train:"+str(round(auroc_train,2)))
plt.plot(fpr_eval,tpr_eval,'g',label="Eval:"+str(round(auroc_eval,2)))
plt.plot(fpr_test,tpr_test,'b',label="Test:"+str(round(auroc_test,2)))
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC")
plt.legend()

# %%
#plot the test set predictions 
matplotlib.rcParams['figure.figsize'] = [20, 8]
plt.subplot(1,3,1)
plt.plot(list(train_y),list(train_pred),'o')
plt.xlabel("Observed train set editing level, Neil 1 Degenerate")
plt.ylabel("Predicted train set editing level, Neil 1 Degenerate")
plt.subplot(1,3,2)
plt.plot(list(eval_y),list(eval_pred),'o')
plt.xlabel("Observed eval set editing level, Neil 1 Degenerate")
plt.ylabel("Predicted eval set editing level, Neil 1 Degenerate")
plt.subplot(1,3,3)
plt.plot(list(test_y),list(test_pred),'o')
plt.xlabel("Observed test set editing level, Neil 1 Degenerate")
plt.ylabel("Predicted test set editing level, Neil 1 Degenerate")

plt.show()

# %%
import plotnine
from plotnine import *
test_df=pd.DataFrame({'Observed':test_y,
                     'Predicted':test_pred,
                     'Dataset':'NEIL1_COMP'})

# %%
plotnine.options.figure_size = (4, 4)

p=(ggplot(test_df, aes('Observed', 'Predicted', color='factor(Dataset)'))
 + geom_point()
 + stat_smooth(method='lm')
 + scale_color_manual(values=['#d95f02'],name="Substrate")
 + ggtitle("NEIL1"))
print(p)
ggsave(plot=p, filename='NEIL1.comp.substrate.svg',width=4,height=4,units='in')
# Out:
# <ggplot: (8733826437573)>

# %%
matplotlib.rcParams['figure.figsize'] = [15, 15]
xgboost.plot_importance(bst)

# %%
xgboost.to_graphviz(bst, num_trees=2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/miniconda3/envs/adar/lib/python3.7/site-packages/xgboost/plotting.py in to_graphviz(booster, fmap, num_trees, rankdir, yes_color, no_color, condition_node_params, leaf_node_params, **kwargs)
#     165     try:
# --> 166         from graphviz import Source
#     167     except ImportError:
#
# ModuleNotFoundError: No module named 'graphviz'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-34-d79d9cbc4c4d> in <module>
# ----> 1 xgboost.to_graphviz(bst, num_trees=2)
#
# ~/miniconda3/envs/adar/lib/python3.7/site-packages/xgboost/plotting.py in to_graphviz(booster, fmap, num_trees, rankdir, yes_color, no_color, condition_node_params, leaf_node_params, **kwargs)
#     166         from graphviz import Source
#     167     except ImportError:
# --> 168         raise ImportError('You must install graphviz to plot tree')
#     169     if isinstance(booster, XGBModel):
#     170         booster = booster.get_booster()
#
# ImportError: You must install graphviz to plot tree

# %%
# explain the model's predictions using SHAP values
explainer = shap.TreeExplainer(bst)
shap_values = explainer.shap_values(test_X)
shap_values.shape
# Out:
# (74, 105)

# %%
shap.force_plot
# Out:
# <function shap.plots.force.force_plot(base_value, shap_values, features=None, feature_names=None, out_names=None, link='identity', plot_cmap='RdBu', matplotlib=False, show=True, figsize=(20, 3), ordering_keys=None, ordering_keys_time_format=None, text_rotation=0)>

# %%
test_X.iloc[6,:].shape
# Out:
# (105,)

# %%
test_y=pd.DataFrame(test_y)
max_index=test_y.index[test_y['editing_value'] == max(test_y['editing_value'])]
max_row=test_y.index.get_loc(max_index[0])
# visualize prediction for isoform with the highest editing level 
# visualize prediction for isoform with the highest editing level 
shap.initjs()
matplotlib=True
shap.force_plot(explainer.expected_value, shap_values[max_row,:], test_X.iloc[max_row,:],matplotlib=True,show=False)
plt.savefig("NEIL1.comp.visualize_prediction.highest.svg", format='svg', width=7, height=1, dpi=300, bbox_inches="tight")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
 max(test_y['editing_value'])
# Out:
# 0.92

# %%
# visualize prediction for isoform with the lowest editing level 
shap.initjs()
min_index=test_y.index[test_y['editing_value'] == min(test_y['editing_value'])]
min_row=test_y.index.get_loc(min_index[0])
matplotlib=True
shap.force_plot(explainer.expected_value, shap_values[min_row,:], test_X.iloc[min_row,:],matplotlib=True,show=False)
plt.savefig("NEIL1.comp.visualize_prediction.lowest.svg", format='svg', width=7, height=1, dpi=300, bbox_inches="tight")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
 min(test_y['editing_value'])
# Out:
# 0.01

# %%
# visualize the training set predictions
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values,train_X)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iJ4YKDE5KE9NJBWH7JT3C'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["model output value"], "baseValue": 0.2973458468914032, "link": "identity", "featureNames": ["free_energy", "sim_nor_score", "probability_active_conf", "num_mutations", "mut_pos", "mut_site_dist", "mut_same_as_site", "all_stem_length", "site_length", "site_length_stem", "site_length_hairpin", "site_length_bulge", "site_length_internal_es", "site_length_internal_ecs", "u_count", "u_all_stem_length", "u_hairpin_length", "u1_exist", "u1_distance", "u1_length", "u1_length_stem", "u2_exist", "u2_distance", "u2_length", "u2_length_hairpin", "u2_length_bulge", "u2_length_internal_es", "u2_length_internal_ecs", "u3_exist", "u3_distance", "u3_length", "u3_length_stem", "d_count", "d_all_stem_length", "d1_length", "d1_length_stem", "d2_distance", "d2_length", "d2_length_bulge", "d2_length_internal_es", "d2_length_internal_ecs", "d3_distance", "d3_length", "d3_length_stem", "mut_type:indel", "mut_type:mismatch", "mut_ref_nt:C", "mut_nt:A", "mut_nt:C", "mut_nt:G", "mut_nt:U", "mut_struct:B", "mut_struct:H", "mut_struct:I", "mut_struct:S", "mut_ref_struct:S", "mut_prev_struct:H", "mut_prev_struct:I", "mut_prev_struct:S", "mut_next_struct:B", "mut_next_struct:H", "mut_next_struct:I", "mut_next_struct:S", "site_struct:B", "site_struct:H", "site_struct:I", "site_prev_nt:A", "site_prev_nt:U", "site_next_nt:A", "site_next_nt:U", "site_1_1:A:C", "site_3prm_cp_bulge:A:U", "site_5prm_cp_internal:C:G", "site_5prm_cp_internal:U:A", "site_3prm_cp_internal:A:U", "site_3prm_cp_internal:C:G", "site_3prm_cp_internal:G:C", "site_3prm_cp_internal:G:U", "u1_struct:S", "u2_struct:B", "u2_struct:H", "u2_struct:I", "u2_5prm_cp_hairpin:C:G", "u2_5prm_cp_hairpin:G:C", "u2_5prm_cp_bulge:G:C", "u2_5prm_cp_bulge:U:G", "u2_3prm_cp_bulge:C:G", "u2_3prm_cp_bulge:G:C", "u2_3prm_cp_bulge:G:U", "u2_5prm_cp_internal:G:C", "u2_3prm_cp_internal:G:C", "u3_struct:S", "d2_struct:B", "d2_struct:I", "d2_5prm_cp_bulge:C:G", "d2_5prm_cp_bulge:G:C", "d2_3prm_cp_bulge:A:U", "d2_3prm_cp_bulge:C:G", "d2_5prm_cp_internal:C:G", "d2_5prm_cp_internal:G:C", "d2_5prm_cp_internal:U:A", "d2_5prm_cp_internal:U:G", "d2_3prm_cp_internal:C:G", "d2_3prm_cp_internal:G:C", "d2_3prm_cp_internal:U:G"], "explanations": [{"outValue": 0.4987215995788574, "simIndex": 71.0, "features": {"0": {"effect": 0.002238666173070669, "value": -41.29}, "1": {"effect": -0.0046324171125888824, "value": 0.993}, "2": {"effect": 0.08856204897165298, "value": 0.13760977300000002}, "3": {"effect": 0.1368904709815979, "value": 1.0}, "4": {"effect": -0.005927870981395245, "value": 41.0}, "5": {"effect": -0.01573960855603218, "value": -6.0}, "6": {"effect": 0.0005309475236572325, "value": 0.0}, "7": {"effect": -0.005887269042432308, "value": 29.0}, "8": {"effect": -0.006343302316963673, "value": 1.0}, "9": {"effect": -0.0033060128334909678, "value": 0.15131786351046}, "10": {"effect": -0.0036975659895688295, "value": 80.62270196157}, "11": {"effect": -0.01586107537150383, "value": -0.310221602099481}, "12": {"effect": 0.0, "value": 1.0}, "13": {"effect": 7.636065129190683e-05, "value": 1.0}, "14": {"effect": 0.0002974187955260277, "value": 2.0}, "15": {"effect": 0.002453060355037451, "value": 5.0}, "16": {"effect": -5.303086254571099e-07, "value": 6.0}, "17": {"effect": 0.0, "value": 1.0}, "18": {"effect": 0.0, "value": -1.0}, "19": {"effect": 0.00038589444011449814, "value": 5.0}, "20": {"effect": 0.0, "value": 5.0}, "21": {"effect": 0.0, "value": 1.0}, "22": {"effect": 0.0, "value": -6.0}, "23": {"effect": 0.0, "value": 6.0}, "24": {"effect": -6.587023563042749e-06, "value": 6.0}, "25": {"effect": -0.00530597660690546, "value": 0.996888102588836}, "26": {"effect": 0.011602128855884075, "value": -5.03097356750757}, "27": {"effect": 0.004358412232249975, "value": -3.5162779922022795}, "28": {"effect": 0.0, "value": 0.0}, "29": {"effect": -0.00013106002006679773, "value": 0.0}, "30": {"effect": 0.0038742185570299625, "value": -17.266890080832}, "31":  ...

# %%
# summarize the effect of all the features 
shap.summary_plot(shap_values, test_X,show=False)
plt.savefig("NEIL1.comp.shap.svg", format='svg',width=20,height=10,dpi=300,bbox_inches="tight")

# %%
# We can also just take the mean absolute value of the SHAP values for each feature 
# to get a standard bar plot (produces stacked bars for multi-class outputs):
shap.summary_plot(shap_values, test_X, plot_type="bar")

# %%
mean_abs_shap_vals=np.mean(abs(shap_values),axis=0)
features=test_X.columns
shap_dict=pd.DataFrame({'feature':features,
          'mean_abs_shap':mean_abs_shap_vals})
shap_dict.to_csv("NEIL1_comp_shap_mean_abs.txt",index=False,sep='\t')

# %%
shap_dict
# Out:
#                      feature  mean_abs_shap
# 0                free_energy       0.003489
# 1              sim_nor_score       0.006693
# 2    probability_active_conf       0.073307
# 3              num_mutations       0.053276
# 4                    mut_pos       0.003500
# ..                       ...            ...
# 100  d2_5prm_cp_internal:U:A       0.001032
# 101  d2_5prm_cp_internal:U:G       0.000039
# 102  d2_3prm_cp_internal:C:G       0.000000
# 103  d2_3prm_cp_internal:G:C       0.000000
# 104  d2_3prm_cp_internal:U:G       0.000000
#
# [105 rows x 2 columns]

# %%
## Compute pairwise interaction values from TreeShap
shap_interaction_values=explainer.shap_interaction_values(test_X)
shap_interaction_values.shape
# Out:
# (74, 105, 105)

# %%
##Average interaction values across the datapoints in the test set 
mean_interaction_values=np.mean(shap_interaction_values,axis=0)

# %%
Index=test_X.columns
Cols=test_X.columns
mean_interaction_values_df = pd.DataFrame(mean_interaction_values, index=Index, columns=Cols)

# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
configure_plotly_browser_state()

trace = Heatmap(z=mean_interaction_values_df.values,
                   x=Cols,
                   y=Index)
iplot([trace],show_link=False)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-ec648a4cffb3> in <module>
#       1 from plotly.offline import init_notebook_mode
#       2 init_notebook_mode(connected=True)
# ----> 3 configure_plotly_browser_state()
#       4
#       5 trace = Heatmap(z=mean_interaction_values_df.values,
#
# NameError: name 'configure_plotly_browser_state' is not defined

# %% [markdown]
# ## Computational Dataset: Feature Subsets<a name='4'>
# <a href=#outline>Home</a>

# %%
shap_values=pd.DataFrame(shap_values,columns=Cols)

# %%
from feature_subsets import * 
subset_names=["sub_site_seq","biophysical","u1_d1","mut","site","u","d","u_d","mut_site","no_up","no_down","site_struct","site_seq","mut_seq","mut_seq_site","no_mut","overall_structure"]
subset_contribs=[]
for subset in [sub_site_seq,biophysical, u1_d1,mut,site,u,d,u_d,mut_site,no_up,no_down,site_struct,site_seq,mut_seq,mut_seq_site,no_mut,overall_structure]: 
  print(subset)
  cur_features=filter_features(shap_values,subset)
  cur_feature_shap=shap_values[cur_features].values 
  cur_feature_data_X=test_X[cur_features]
  shap.summary_plot(cur_feature_shap, cur_feature_data_X)#,sort=False,max_display=50)
  contrib=shap_contribs_subgroup(shap_values,subset)
  subset_contribs.append(contrib)
  print("Contribution/Total:"+str(contrib))
# Out:
# ['site_prev_nt*', 'site_next_nt*']
# Contribution/Total:0.012877564
# ['free_energy*', 'sim_nor_score*', 'probability_active_conf*']
# Contribution/Total:0.22146995
# ['u1_exist*', 'u1_distance*', 'u1_struct*', 'u1_length*', 'u1_length_stem*', 'u1_length_hairpin*', 'u1_length_bulge*', 'u1_length_internal_es*', 'u1_length_internal_ecs*', 'u1_5prm_cp_hairpin*', 'u1_5prm_cp_bulge*', 'u1_3prm_cp_bulge*', 'u1_5prm_cp_internal*', 'u1_3prm_cp_internal*', 'd1_exist*', 'd1_distance*', 'd1_struct*', 'd1_length*', 'd1_length_stem*', 'd1_length_hairpin*', 'd1_length_bulge*', 'd1_length_internal_es*', 'd1_length_internal_ecs*', 'd1_5prm_cp_hairpin*', 'd1_5prm_cp_bulge*', 'd1_3prm_cp_bulge*', 'd1_5prm_cp_internal*', 'd1_3prm_cp_internal*']
# Contribution/Total:0.0056429384
# ['num_mutations*', 'mut_pos*', 'mut_site_dist*', 'mut_ref_nt*', 'mut_nt*', 'mut_struct*', 'mut_ref_struct*', 'mut_prev_struct*', 'mut_next_struct*', 'mut_same_as_site*']
# Contribution/Total:0.28683484
# ['site_prev_nt*', 'site_next_nt*', 'site_struct*', 'site_prev_struct*', 'site_next_struct*', 'site_1_1*', 'site_length*', 'site_length_stem*', 'site_length_hairpin*', 'site_length_bulge*', 'site_length_internal_es*', 'site_length_internal_ecs*', 'site_5prm_cp_hairpin*', 'site_5prm_cp_bulge*', 'site_3prm_cp_bulge*', 'site_5prm_cp_internal*', 'site_3prm_cp_internal*']
# Contribution/Total:0.42064607
# ['u_count*', 'u_all_stem_length*', 'u_hairpin_length*', 'u1_exist*', 'u1_distance*', 'u1_struct*', 'u1_length*', 'u1_length_stem*', 'u1_length_hairpin*', 'u1_length_bulge*', 'u1_length_internal_es*', 'u1_length_internal_ecs*', 'u1_5prm_cp_hairpin*', 'u1_5prm_cp_bulge*', 'u1_3prm_cp_bulge*', 'u1_5prm_cp_internal*', 'u1_3prm_cp_internal*', 'u2_exist*', 'u2_distance*', 'u2_struct*', 'u2_length*', 'u2_length_stem*', 'u2_length_hairpin*', 'u2_length_bulge*', 'u2_length_internal_es*', 'u2_length_internal_ecs*', 'u2_5prm_cp_hairpin*', 'u2_5prm_cp_bulge*', 'u2_3prm_cp_bulge*', 'u2_5prm_cp_internal*', 'u2_3prm_cp_internal*', 'u3_exist*', 'u3_distance*', 'u3_struct*', 'u3_length*', 'u3_length_stem*', 'u3_length_hairpin*', 'u3_length_bulge*', 'u3_length_internal_es*', 'u3_length_internal_ecs*', 'u3_5prm_cp_hairpin*', 'u3_5prm_cp_bulge*', 'u3_3prm_cp_bulge*', 'u3_5prm_cp_internal*', 'u3_3prm_cp_internal*']
# Contribution/Total:0.18520503
# ['d_count*', 'd_all_stem_length*', 'd1_exist*', 'd1_distance*', 'd1_struct*', 'd1_length*', 'd1_length_stem*', 'd1_length_hairpin*', 'd1_length_bulge*', 'd1_length_internal_es*', 'd1_length_internal_ecs*', 'd1_5prm_cp_hairpin*', 'd1_5prm_cp_bulge*', 'd1_3prm_cp_bulge*', 'd1_5prm_cp_internal*', 'd1_3prm_cp_internal*', 'd2_exist*', 'd2_distance*', 'd2_struct*', 'd2_length*', 'd2_length_stem*', 'd2_length_hairpin*', 'd2_length_bulge*', 'd2_length_internal_es*', 'd2_length_internal_ecs*', 'd2_5prm_cp_hairpin*', 'd2_5prm_cp_bulge*', 'd2_3prm_cp_bulge*', 'd2_5prm_cp_internal*', 'd2_3prm_cp_internal*', 'd3_exist*', 'd3_distance*', 'd3_struct*', 'd3_length*', 'd3_length_stem*', 'd3_length_hairpin*', 'd3_length_bulge*', 'd3_length_internal_es*', 'd3_length_internal_ecs*', 'd3_5prm_cp_hairpin*', 'd3_5prm_cp_bulge*', 'd3_3prm_cp_bulge*', 'd3_5prm_cp_internal*', 'd3_3prm_cp_internal*']
# Contribution/Total:0.107721694
# ['u_count*', 'u_all_stem_length*', 'u_hairpin_length*', 'u1_exist*', 'u1_distance*', 'u1_struct*', 'u1_length*', 'u1_length_stem*', 'u1_length_hairpin*', 'u1_length_bulge*', 'u1_length_internal_es*', 'u1_length_internal_ecs*', 'u1_5prm_cp_hairpin*', 'u1_5prm_cp_bulge*', 'u1_3prm_cp_bulge*', 'u1_5prm_cp_internal*', 'u1_3prm_cp_internal*', 'u2_exist*', 'u2_distance*', 'u2_struct*', 'u2_length*', 'u2_length_stem*', 'u2_length_hairpin*', 'u2_length_bulge*', 'u2_length_internal_es*', 'u2_length_internal_ecs*', 'u2_5prm_cp_hairpin*', 'u2_5prm_cp_bulge*', 'u2_3prm_cp_bulge*', 'u2_5prm_cp_internal*', 'u2_3prm_cp_internal*', 'u3_exist*', 'u3_distance*', 'u3_struct*', 'u3_length*', 'u3_length_stem*', 'u3_length_hairpin*', 'u3_length_bulge*', 'u3_length_internal_es*', 'u3_length_internal_ecs*', 'u3_5prm_cp_hairpin*', 'u3_5prm_cp_bulge*', 'u3_3prm_cp_bulge*', 'u3_5prm_cp_internal*', 'u3_3prm_cp_internal*', 'd_count*', 'd_all_stem_length*', 'd1_exist*', 'd1_distance*', 'd1_struct*', 'd1_length*', 'd1_length_stem*', 'd1_length_hairpin*', 'd1_length_bulge*', 'd1_length_internal_es*', 'd1_length_internal_ecs*', 'd1_5prm_cp_hairpin*', 'd1_5prm_cp_bulge*', 'd1_3prm_cp_bulge*', 'd1_5prm_cp_internal*', 'd1_3prm_cp_internal*', 'd2_exist*', 'd2_distance*', 'd2_struct*', 'd2_length*', 'd2_length_stem*', 'd2_length_hairpin*', 'd2_length_bulge*', 'd2_length_internal_es*', 'd2_length_internal_ecs*', 'd2_5prm_cp_hairpin*', 'd2_5prm_cp_bulge*', 'd2_3prm_cp_bulge*', 'd2_5prm_cp_internal*', 'd2_3prm_cp_internal*', 'd3_exist*', 'd3_distance*', 'd3_struct*', 'd3_length*', 'd3_length_stem*', 'd3_length_hairpin*', 'd3_length_bulge*', 'd3_length_internal_es*', 'd3_length_internal_ecs*', 'd3_5prm_cp_hairpin*', 'd3_5prm_cp_bulge*', 'd3_3prm_cp_bulge*', 'd3_5prm_cp_internal*', 'd3_3prm_cp_internal*']
# Contribution/Total:0.29292676
# ['num_mutations*', 'mut_pos*', 'mut_site_dist*', 'mut_ref_nt*', 'mut_nt*', 'mut_struct*', 'mut_ref_struct*', 'mut_prev_struct*', 'mut_next_struct*', 'mut_same_as_site*', 'site_prev_nt*', 'site_next_nt*', 'site_struct*', 'site_prev_struct*', 'site_next_struct*', 'site_1_1*', 'site_length*', 'site_length_stem*', 'site_length_hairpin*', 'site_length_bulge*', 'site_length_internal_es*', 'site_length_internal_ecs*', 'site_5prm_cp_hairpin*', 'site_5prm_cp_bulge*', 'site_3prm_cp_bulge*', 'site_5prm_cp_internal*', 'site_3prm_cp_internal*']
# Contribution/Total:0.70748085
# ['all_stem_length', 'free_energy*', 'sim_nor_score*', 'probability_active_conf*', 'num_mutations*', 'mut_pos*', 'mut_site_dist*', 'mut_ref_nt*', 'mut_nt*', 'mut_struct*', 'mut_ref_struct*', 'mut_prev_struct*', 'mut_next_struct*', 'mut_same_as_site*', 'site_prev_nt*', 'site_next_nt*', 'site_struct*', 'site_prev_struct*', 'site_next_struct*', 'site_1_1*', 'site_length*', 'site_length_stem*', 'site_length_hairpin*', 'site_length_bulge*', 'site_length_internal_es*', 'site_length_internal_ecs*', 'site_5prm_cp_hairpin*', 'site_5prm_cp_bulge*', 'site_3prm_cp_bulge*', 'site_5prm_cp_internal*', 'site_3prm_cp_internal*', 'd_count*', 'd_all_stem_length*', 'd1_exist*', 'd1_distance*', 'd1_struct*', 'd1_length*', 'd1_length_stem*', 'd1_length_hairpin*', 'd1_length_bulge*', 'd1_length_internal_es*', 'd1_length_internal_ecs*', 'd1_5prm_cp_hairpin*', 'd1_5prm_cp_bulge*', 'd1_3prm_cp_bulge*', 'd1_5prm_cp_internal*', 'd1_3prm_cp_internal*', 'd2_exist*', 'd2_distance*', 'd2_struct*', 'd2_length*', 'd2_length_stem*', 'd2_length_hairpin*', 'd2_length_bulge*', 'd2_length_internal_es*', 'd2_length_internal_ecs*', 'd2_5prm_cp_hairpin*', 'd2_5prm_cp_bulge*', 'd2_3prm_cp_bulge*', 'd2_5prm_cp_internal*', 'd2_3prm_cp_internal*', 'd3_exist*', 'd3_distance*', 'd3_struct*', 'd3_length*', 'd3_length_stem*', 'd3_length_hairpin*', 'd3_length_bulge*', 'd3_length_internal_es*', 'd3_length_internal_ecs*', 'd3_5prm_cp_hairpin*', 'd3_5prm_cp_bulge*', 'd3_3prm_cp_bulge*', 'd3_5prm_cp_internal*', 'd3_3prm_cp_internal*']
# Contribution/Total:1.0566913
# ['all_stem_length', 'free_energy*', 'sim_nor_score*', 'probability_active_conf*', 'num_mutations*', 'mut_pos*', 'mut_site_dist*', 'mut_ref_nt*', 'mut_nt*', 'mut_struct*', 'mut_ref_struct*', 'mut_prev_struct*', 'mut_next_struct*', 'mut_same_as_site*', 'site_prev_nt*', 'site_next_nt*', 'site_struct*', 'site_prev_struct*', 'site_next_struct*', 'site_1_1*', 'site_length*', 'site_length_stem*', 'site_length_hairpin*', 'site_length_bulge*', 'site_length_internal_es*', 'site_length_internal_ecs*', 'site_5prm_cp_hairpin*', 'site_5prm_cp_bulge*', 'site_3prm_cp_bulge*', 'site_5prm_cp_internal*', 'site_3prm_cp_internal*', 'u_count*', 'u_all_stem_length*', 'u_hairpin_length*', 'u1_exist*', 'u1_distance*', 'u1_struct*', 'u1_length*', 'u1_length_stem*', 'u1_length_hairpin*', 'u1_length_bulge*', 'u1_length_internal_es*', 'u1_length_internal_ecs*', 'u1_5prm_cp_hairpin*', 'u1_5prm_cp_bulge*', 'u1_3prm_cp_bulge*', 'u1_5prm_cp_internal*', 'u1_3prm_cp_internal*', 'u2_exist*', 'u2_distance*', 'u2_struct*', 'u2_length*', 'u2_length_stem*', 'u2_length_hairpin*', 'u2_length_bulge*', 'u2_length_internal_es*', 'u2_length_internal_ecs*', 'u2_5prm_cp_hairpin*', 'u2_5prm_cp_bulge*', 'u2_3prm_cp_bulge*', 'u2_5prm_cp_internal*', 'u2_3prm_cp_internal*', 'u3_exist*', 'u3_distance*', 'u3_struct*', 'u3_length*', 'u3_length_stem*', 'u3_length_hairpin*', 'u3_length_bulge*', 'u3_length_internal_es*', 'u3_length_internal_ecs*', 'u3_5prm_cp_hairpin*', 'u3_5prm_cp_bulge*', 'u3_3prm_cp_bulge*', 'u3_5prm_cp_internal*', 'u3_3prm_cp_internal*']
# Contribution/Total:1.1341746
# ['site_struct*', 'site_prev_struct*', 'site_next_struct*', 'site_1_1*', 'site_length*', 'site_length_stem*', 'site_length_hairpin*', 'site_length_bulge*', 'site_length_internal_es*', 'site_length_internal_ecs*', 'site_5prm_cp_hairpin*', 'site_5prm_cp_bulge*', 'site_3prm_cp_bulge*', 'site_5prm_cp_internal*', 'site_3prm_cp_internal*']
# Contribution/Total:0.40776852
# ['site_prev_nt*', 'site_next_nt*']
# Contribution/Total:0.012877564
# ['mut_pos*', 'mut_site_dist*', 'mut_ref_nt*', 'mut_nt*']
# Contribution/Total:0.12121517
# ['mut_pos*', 'mut_site_dist*', 'mut_ref_nt*', 'mut_nt*', 'site_prev_nt*', 'site_next_nt*']
# Contribution/Total:0.13409273
# ['all_stem_length', 'free_energy*', 'sim_nor_score*', 'probability_active_conf*', 'site_prev_nt*', 'site_next_nt*', 'site_struct*', 'site_prev_struct*', 'site_next_struct*', 'site_1_1*', 'site_length*', 'site_length_stem*', 'site_length_hairpin*', 'site_length_bulge*', 'site_length_internal_es*', 'site_length_internal_ecs*', 'site_5prm_cp_hairpin*', 'site_5prm_cp_bulge*', 'site_3prm_cp_bulge*', 'site_5prm_cp_internal*', 'site_3prm_cp_internal*', 'u_count*', 'u_all_stem_length*', 'u_hairpin_length*', 'u1_exist*', 'u1_distance*', 'u1_struct*', 'u1_length*', 'u1_length_stem*', 'u1_length_hairpin*', 'u1_length_bulge*', 'u1_length_internal_es*', 'u1_length_internal_ecs*', 'u1_5prm_cp_hairpin*', 'u1_5prm_cp_bulge*', 'u1_3prm_cp_bulge*', 'u1_5prm_cp_internal*', 'u1_3prm_cp_internal*', 'u2_exist*', 'u2_distance*', 'u2_struct*', 'u2_length*', 'u2_length_stem*', 'u2_length_hairpin*', 'u2_length_bulge*', 'u2_length_internal_es*', 'u2_length_internal_ecs*', 'u2_5prm_cp_hairpin*', 'u2_5prm_cp_bulge*', 'u2_3prm_cp_bulge*', 'u2_5prm_cp_internal*', 'u2_3prm_cp_internal*', 'u3_exist*', 'u3_distance*', 'u3_struct*', 'u3_length*', 'u3_length_stem*', 'u3_length_hairpin*', 'u3_length_bulge*', 'u3_length_internal_es*', 'u3_length_internal_ecs*', 'u3_5prm_cp_hairpin*', 'u3_5prm_cp_bulge*', 'u3_3prm_cp_bulge*', 'u3_5prm_cp_internal*', 'u3_3prm_cp_internal*', 'd_count*', 'd_all_stem_length*', 'd1_exist*', 'd1_distance*', 'd1_struct*', 'd1_length*', 'd1_length_stem*', 'd1_length_hairpin*', 'd1_length_bulge*', 'd1_length_internal_es*', 'd1_length_internal_ecs*', 'd1_5prm_cp_hairpin*', 'd1_5prm_cp_bulge*', 'd1_3prm_cp_bulge*', 'd1_5prm_cp_internal*', 'd1_3prm_cp_internal*', 'd2_exist*', 'd2_distance*', 'd2_struct*', 'd2_length*', 'd2_length_stem*', 'd2_length_hairpin*', 'd2_length_bulge*', 'd2_length_internal_es*', 'd2_length_internal_ecs*', 'd2_5prm_cp_hairpin*', 'd2_5prm_cp_bulge*', 'd2_3prm_cp_bulge*', 'd2_5prm_cp_internal*', 'd2_3prm_cp_internal*', 'd3_exist*', 'd3_distance*', 'd3_struct*', 'd3_length*', 'd3_length_stem*', 'd3_length_hairpin*', 'd3_length_bulge*', 'd3_length_internal_es*', 'd3_length_internal_ecs*', 'd3_5prm_cp_hairpin*', 'd3_5prm_cp_bulge*', 'd3_3prm_cp_bulge*', 'd3_5prm_cp_internal*', 'd3_3prm_cp_internal*']
# Contribution/Total:0.9550615
# ['all_stem_length', 'free_energy*', 'sim_nor_score*', 'probability_active_conf*']
# Contribution/Total:0.24148864

# %%
subset_contrib_df=pd.DataFrame({'Subset':subset_names,
                               'Contribution':[100*i for i in subset_contribs]})

# %%
subset_contrib_df=subset_contrib_df.sort_values(by=['Contribution'],ascending=False)
subset_contrib_df.reset_index(inplace=True, drop=True)

# %%
from pandas.api.types import CategoricalDtype

# %%
subset_cat = CategoricalDtype(categories=list(subset_contrib_df['Subset']), ordered=True)

# Cast the existing categories into the new category. Due to a bug in pandas
# we need to do this via a string.
subset_contrib_df['Subset_Cat'] = subset_contrib_df['Subset'].astype(str).astype(subset_cat)

# %%
subset_contrib_df

# %%
p=(ggplot(subset_contrib_df, aes('Subset_Cat', 'Contribution'))
 + geom_bar(stat='identity')
 + xlab("Feature Subset")
 + ylab("Percent Contribution to Predictions")
 + theme(axis_text_x=element_text(angle=90))
)
ggsave(plot=p, filename='NEIL1.comp.subset.importance.svg',width=5,height=4,units='in')
p

# %% [markdown]
# ## No "mut" features

# %%
## Read in the data 
import feature_subsets
import pandas as pd 
data=pd.read_csv("../xin_feature_matrices/neil1_computational.features.csv",header=0,sep=',',index_col=0)
#drop all mut features
cur_features=filter_features(data,feature_subsets.mut)
cur_features.remove('mut_pos')
data=data.drop(cur_features,axis=1)
data.head

# %%
#remove any null editing level values 
data=data[~data["editing_value"].isnull().values]

# %%
data=format_for_xgboost(data)
train_split,eval_split,test_split=split_train_test_eval_by_mut_pos(data)

# %%
#Remove any non-varying features 
train_novar=get_singleval_features(train_split)
eval_novar=get_singleval_features(eval_split)
test_novar=get_singleval_features(test_split)
uniform_features_to_drop=list(set(train_novar+eval_novar+test_novar))

# %%
#Remove any null features 
train_null=get_all_null_features(train_split)
eval_null=get_all_null_features(eval_split)
test_null=get_all_null_features(test_split)
null_features_to_drop=list(set(train_null+eval_null+test_null))

# %%
to_drop=list(set(uniform_features_to_drop+null_features_to_drop))
to_drop.append("mut_pos")
print("\n".join(to_drop))

# %%
train_split=train_split.drop(to_drop,axis=1)
eval_split=eval_split.drop(to_drop,axis=1)
test_split=test_split.drop(to_drop,axis=1)

# %%
train_y=train_split['editing_value']
train_X=train_split.drop(['editing_value'],axis=1)

eval_y=eval_split['editing_value']
eval_X=eval_split.drop(['editing_value'],axis=1)

test_y=test_split['editing_value']
test_X=test_split.drop(['editing_value'],axis=1)

# %%
print(train_X.shape)
print(train_y.shape)
print(eval_X.shape)
print(eval_y.shape)
print(test_X.shape)
print(test_y.shape)

# %%
## format matrixes for xgboost 
import xgboost
dtrain=xgboost.DMatrix(train_X,train_y)
deval=xgboost.DMatrix(eval_X,eval_y)
dtest=xgboost.DMatrix(test_X,test_y)

# %%
## set model training parameters 
param=dict() 
param['nthread'] = 20
#rmse -- root mean square error 
# mae -- mean absolute error 
# map -- mean average precision 
# auc -- area under ROC curve 
# aucpr -- area under precision recall curve 
param['eval_metric'] = ['auc','mae','map','aucpr','rmse']

# %%
evallist = [(deval, 'eval'), (dtrain, 'train')]

# %%
num_round = 1000
bst = xgboost.train(param, dtrain, num_round, evallist,early_stopping_rounds=10)

# %%
# save to binary file for faster loading
bst.save_model('neil1.computational.model')
# save model to text file 
bst.dump_model('neil1.computational.raw.txt')

# %%
## get model predictions on the test, training, and eval splits 
test_pred = bst.predict(dtest)
train_pred=bst.predict(dtrain)
eval_pred=bst.predict(deval)

# %%
## Correlation values 
from scipy.stats import spearmanr,pearsonr
spearman_train=spearmanr(train_y,train_pred)
spearman_eval=spearmanr(eval_y,eval_pred)
spearman_test=spearmanr(test_y,test_pred)

pearson_train=pearsonr(train_y,train_pred)
pearson_eval=pearsonr(eval_y,eval_pred)
pearson_test=pearsonr(test_y,test_pred)

print("Spearman correlation:")
print("Train:"+str(spearman_train))
print("Eval:"+str(spearman_eval))
print("Test:"+str(spearman_test))
print("\n")
print("Pearson correlation:")
print("Train:"+str(pearson_train))
print("Eval:"+str(pearson_eval))
print("Test:"+str(pearson_test))

# %%
## MAE
from sklearn.metrics import mean_absolute_error
mae_train=mean_absolute_error(train_y,train_pred)
print("MAE Train:"+str(mae_train))

mae_eval=mean_absolute_error(eval_y,eval_pred)
print("MAE Eval:"+str(mae_eval))

mae_test=mean_absolute_error(test_y,test_pred)
print("MAE Test:"+str(mae_test))

# %%
## MAPE
pseudocount=0.01
mape_train=np.mean(np.abs((train_y - train_pred) /(pseudocount+train_y))) * 100
print("MAPE Train:"+str(mape_train)+"%")

mape_eval=np.mean(np.abs((eval_y - eval_pred) /(pseudocount+eval_y))) * 100
print("MAPE Eval:"+str(mape_eval)+"%")

mape_test=np.mean(np.abs((test_y - test_pred) /(pseudocount+test_y))) * 100
print("MAPE Test:"+str(mape_test)+"%")

# %%
## RMSE
from sklearn.metrics import mean_squared_error
import math 
rmse_train=math.sqrt(mean_squared_error(train_y,train_pred))
print("RMSE Train:"+str(rmse_train))

rmse_eval=math.sqrt(mean_squared_error(eval_y,eval_pred))
print("RMSE Eval:"+str(rmse_eval))

rmse_test=math.sqrt(mean_squared_error(test_y,test_pred))
print("RMSE Test:"+str(rmse_test))

# %%
## PRC 
## PRC only valid for binary outcomes. 
## Editing levels < 0.5 are labeled as "0". 
## Editing levels >= 0.5 are labeled as "1". 

from sklearn.metrics import auc, precision_recall_curve

precision_train,recall_train,prc_thresholds_train=precision_recall_curve(train_y>=0.5,train_pred)
precision_eval,recall_eval,prc_thresholds_eval=precision_recall_curve(eval_y>=0.5,eval_pred)
precision_test,recall_test,prc_thresholds_test=precision_recall_curve(test_y>=0.5,test_pred)

auprc_train=auc(recall_train,precision_train)
auprc_eval=auc(recall_eval,precision_eval)
auprc_test=auc(recall_test,precision_test)

plt.plot(recall_train,precision_train,'r',label="Train:"+str(round(auprc_train,2)))
plt.plot(recall_eval,precision_eval,'g',label="Eval:"+str(round(auprc_eval,2)))
plt.plot(recall_test,precision_test,'b',label="Test:"+str(round(auprc_test,2)))
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("PRC")
plt.legend()

# %%
## ROC
from sklearn.metrics import roc_curve, roc_auc_score
fpr_train,tpr_train,roc_thresholds_train=roc_curve(train_y>=0.5,train_pred)
fpr_eval,tpr_eval,roc_thresholds_eval=roc_curve(eval_y>=0.5,eval_pred)
fpr_test,tpr_test,roc_thresholds_test=roc_curve(test_y>=0.5,test_pred)

auroc_train=roc_auc_score(train_y>=0.5,train_pred)
auroc_eval=roc_auc_score(eval_y>=0.5,eval_pred)
auroc_test=roc_auc_score(test_y>=0.5,test_pred)

plt.plot(fpr_train,tpr_train,'r',label="Train:"+str(round(auroc_train,2)))
plt.plot(fpr_eval,tpr_eval,'g',label="Eval:"+str(round(auroc_eval,2)))
plt.plot(fpr_test,tpr_test,'b',label="Test:"+str(round(auroc_test,2)))
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC")
plt.legend()

# %%
#plot the test set predictions 
matplotlib.rcParams['figure.figsize'] = [20, 8]
plt.subplot(1,3,1)
plt.plot(list(train_y),list(train_pred),'o')
plt.xlabel("Observed train set editing level, Neil 1 Degenerate")
plt.ylabel("Predicted train set editing level, Neil 1 Degenerate")
plt.subplot(1,3,2)
plt.plot(list(eval_y),list(eval_pred),'o')
plt.xlabel("Observed eval set editing level, Neil 1 Degenerate")
plt.ylabel("Predicted eval set editing level, Neil 1 Degenerate")
plt.subplot(1,3,3)
plt.plot(list(test_y),list(test_pred),'o')
plt.xlabel("Observed test set editing level, Neil 1 Degenerate")
plt.ylabel("Predicted test set editing level, Neil 1 Degenerate")

plt.show()

# %%
matplotlib.rcParams['figure.figsize'] = [15, 15]
xgboost.plot_importance(bst)

# %%
xgboost.to_graphviz(bst, num_trees=2)

# %%
# explain the model's predictions using SHAP values
explainer = shap.TreeExplainer(bst)
shap_values = explainer.shap_values(test_X)
shap_values.shape

# %%
test_y=pd.DataFrame(test_y)
max_index=test_y.index[test_y['editing_value'] == max(test_y['editing_value'])]
max_row=test_y.index.get_loc(max_index[0])
# visualize prediction for isoform with the highest editing level 
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[max_row,:], test_X.iloc[max_row,:])

# %%
# visualize prediction for isoform with the lowest editing level 
shap.initjs()
min_index=test_y.index[test_y['editing_value'] == min(test_y['editing_value'])]
min_row=test_y.index.get_loc(min_index[0])
shap.force_plot(explainer.expected_value, shap_values[min_row,:], test_X.iloc[min_row,:])

# %%
# visualize the training set predictions
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values,train_X)

# %%
# summarize the effect of all the features 
shap.summary_plot(shap_values, test_X)

# %%
# We can also just take the mean absolute value of the SHAP values for each feature 
# to get a standard bar plot (produces stacked bars for multi-class outputs):
shap.summary_plot(shap_values, test_X, plot_type="bar")

# %%
## Compute pairwise interaction values from TreeShap
shap_interaction_values=explainer.shap_interaction_values(test_X)
shap_interaction_values.shape

# %%
##Average interaction values across the datapoints in the test set 
mean_interaction_values=np.mean(shap_interaction_values,axis=0)

# %%
Index=test_X.columns
Cols=test_X.columns
mean_interaction_values_df = pd.DataFrame(mean_interaction_values, index=Index, columns=Cols)

# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
configure_plotly_browser_state()

trace = Heatmap(z=mean_interaction_values_df.values,
                   x=Cols,
                   y=Index)
iplot([trace],show_link=False)
