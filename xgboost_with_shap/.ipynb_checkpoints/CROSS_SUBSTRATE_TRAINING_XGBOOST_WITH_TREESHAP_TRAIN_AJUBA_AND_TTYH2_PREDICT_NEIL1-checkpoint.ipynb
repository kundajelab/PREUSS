# %% [markdown]
# <a href="https://colab.research.google.com/github/kundajelab/adar_editing/blob/master/xgboost_with_shap/ALLSUBSTRATES_XGBOOST_WITH_TREESHAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Uncomment these lines if running as a google colab notebook: 
#!pip install numpy==1.15
#! git clone https://github.com/kundajelab/adar_editing
#import os
#os.chdir("adar_editing/xgboost_with_shap/")
#!pip install shap
#!pip install --upgrade xgboost
#!pip install cufflinks

# %%
# %load_ext autoreload
# %autoreload 2

# %%
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

# %%
#helper utilities for model training and interpretation 
import shap
from helpers import * 

#set a random seed so code is reproducible 
random.seed(1234)

# load JS visualization code to notebook
shap.initjs()
import warnings
warnings.filterwarnings('ignore')

#visualization utilities 
import matplotlib
import matplotlib.pyplot as plt 
# %matplotlib inline
import plotly.plotly as py
import numpy as np
from plotly.offline import iplot
from plotly.graph_objs import Heatmap
# Out:
# /users/annashch/miniconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /users/annashch/miniconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...

# %% [markdown]
# ## Train AJUBA & TTYH2, Predict NEIL1 <a name='outline'>

# %%
data_neil_comp=pd.read_csv("../xin_feature_matrices/neil1_computational.features.csv",header=0,sep=',',index_col=0)
#remove any null editing level values 
data_neil_comp=data_neil_comp[~data_neil_comp["editing_value"].isnull().values]
## prepare data for training with xgboost 
data_neil_comp=format_for_xgboost(data_neil_comp)
test_split=data_neil_comp
# Out:
# (428, 219)

# %%
data_ajuba_comp=pd.read_csv("../xin_feature_matrices/ajuba_bc_computational.features.csv",header=0,sep=',',index_col=0)
#remove any null editing level values 
data_ajuba_comp=data_ajuba_comp[~data_ajuba_comp["editing_value"].isnull().values]
## prepare data for training with xgboost 
data_ajuba_comp=format_for_xgboost(data_ajuba_comp)
train_split1,eval_split1=split_train_eval_by_mut_pos(data_ajuba_comp[~data_ajuba_comp['mut_pos'].isna()])
null_mut_pos=data_ajuba_comp[data_ajuba_comp['mut_pos'].isna()]
train_split1=pd.concat((train_split1,null_mut_pos),axis=0)
# Out:
# (482, 186)
# {64.0: 22, 65.0: 21, 66.0: 22, 67.0: 22, 68.0: 22, 69.0: 23, 70.0: 23, 71.0: 24, 72.0: 23, 73.0: 33, 75.0: 33, 76.0: 24, 77.0: 24, 78.0: 23, 79.0: 23, 80.0: 22, 81.0: 22, 82.0: 22, 83.0: 44}

# %%
data_ttyh2_comp=pd.read_csv("../xin_feature_matrices/ttyh2_computational.features.csv",header=0,sep=',',index_col=0)
#remove any null editing level values 
data_ttyh2_comp=data_ttyh2_comp[~data_ttyh2_comp["editing_value"].isnull().values]
## prepare data for training with xgboost 
data_ttyh2_comp=format_for_xgboost(data_ttyh2_comp)
train_split2,eval_split2=split_train_eval_by_mut_pos(data_ttyh2_comp[~data_ttyh2_comp['mut_pos'].isna()])
null_mut_pos=data_ttyh2_comp[data_ttyh2_comp['mut_pos'].isna()]
train_split2=pd.concat((train_split2,null_mut_pos),axis=0)
# Out:
# (601, 216)
# {21.0: 18, 22.0: 18, 23.0: 18, 24.0: 20, 25.0: 17, 26.0: 20, 27.0: 20, 28.0: 20, 29.0: 18, 30.0: 18, 31.0: 17, 32.0: 17, 33.0: 17, 34.0: 18, 35.0: 18, 36.0: 18, 79.0: 17, 80.0: 17, 81.0: 18, 82.0: 18, 83.0: 19, 84.0: 19, 85.0: 20, 86.0: 29, 88.0: 27, 89.0: 18, 90.0: 17, 91.0: 17, 92.0: 17, 93.0: 14, 94.0: 36}

# %%
#concatenate train/eval splits from Neil1 & TTYH2 
train_split=pd.concat((train_split1,train_split2),axis=0)
eval_split=pd.concat((eval_split1,eval_split2),axis=0)

# %%
train_split.reset_index(inplace=True, drop=True) 
eval_split.reset_index(inplace=True,drop=True)
test_split.reset_index(inplace=True,drop=True)

# %%
#Remove any non-varying features 
train_novar=get_singleval_features(train_split)
eval_novar=get_singleval_features(eval_split)
test_novar=get_singleval_features(test_split)
uniform_features_to_drop=list(set(train_novar+eval_novar+test_novar))

# %%
#Remove any null features 
train_null=get_all_null_features(train_split)
eval_null=get_all_null_features(eval_split)
test_null=get_all_null_features(test_split)
null_features_to_drop=list(set(train_null+eval_null+test_null))

# %%
to_drop=list(set(uniform_features_to_drop+null_features_to_drop))
print("\n".join(to_drop))
# Out:
# mut_exist
# d2_5prm_cp_hairpin
# u1_length_internal_es
# u2_5prm_cp_internal
# u2_exist
# d3_exist
# d2_length_hairpin
# d1_5prm_cp_bulge:C:G
# u3_length_internal_ecs
# d1_length_bulge
# u1_5prm_cp_hairpin
# site_next_nt:A
# mut_ref_nt:A
# u3_5prm_cp_internal
# d3_length_hairpin
# d1_5prm_cp_hairpin
# d3_3prm_cp_bulge
# d3_5prm_cp_bulge
# site_5prm_cp_hairpin
# d3_5prm_cp_hairpin
# u1_length_hairpin
# u2_length_internal_ecs
# d2_exist
# d1_5prm_cp_bulge
# u2_3prm_cp_internal
# mut_type:mismatch
# mut_type:indel
# mut_same_as_site
# u2_length_internal_es
# d1_length_hairpin
# site_length_hairpin
# d1_3prm_cp_bulge
# u3_exist
# u3_length_internal_es
# u1_3prm_cp_internal
# u1_exist
# d3_length_bulge
# u1_length_internal_ecs
# mut_type:wt
# d1_exist
# d2_5prm_cp_bulge
# site_next_nt:U
# u1_5prm_cp_internal
# site_prev_nt:U
# u3_3prm_cp_internal
# d2_3prm_cp_bulge
# site_prev_nt:A

# %%
#remove teh features that don't change across isoforms , or are null for all isoforms
for cur_to_drop in to_drop: 
    try:
        train_split=train_split.drop(cur_to_drop,axis=1)
    except: 
        pass
    try:
        eval_split=eval_split.drop(cur_to_drop,axis=1)
    except: 
        pass 
    try:
        test_split=test_split.drop(to_drop,axis=1)
    except: 
        pass

# %%
train_y=train_split['editing_value']
train_X=train_split.drop(['editing_value'],axis=1)
eval_y=eval_split['editing_value']
eval_X=eval_split.drop(['editing_value'],axis=1)
test_y=test_split['editing_value']
test_X=test_split.drop(['editing_value'],axis=1)

# %%
print(train_X.shape)
print(train_y.shape)
print(eval_X.shape)
print(eval_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (863, 189)
# (863,)
# (180, 189)
# (180,)
# (428, 218)
# (428,)

# %%
train_cols=set(train_X.columns)
eval_cols=set(eval_X.columns)
test_cols=set(test_X.columns)

# %%
common=train_cols.intersection(eval_cols)
common=common.intersection(test_cols)
common=list(common)
#print(common)
train_X=train_X[common]
eval_X=eval_X[common]
test_X=test_X[common]
print(train_X.shape)
print(train_y.shape)
print(eval_X.shape)
print(eval_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (863, 143)
# (863,)
# (180, 143)
# (180,)
# (428, 143)
# (428,)

# %%
## format matrixes for xgboost 
import xgboost
dtrain=xgboost.DMatrix(train_X,train_y)
deval=xgboost.DMatrix(eval_X,eval_y)
dtest=xgboost.DMatrix(test_X,test_y)

# %%
## set model training parameters 
from __future__ import unicode_literals
param=dict() 
param['nthread'] = 20
#rmse -- root mean square error 
# mae -- mean absolute error 
# map -- mean average precision 
# auc -- area under ROC curve 
# aucpr -- area under precision recall curve 

#Note: the last metric in your 'eval_metric' list will get optimized 
param['eval_metric'] = ['aucpr','auc','mae','map','rmse']

# %%
evallist = [(deval, 'eval'), (dtrain, 'train')]

# %%
num_round = 1000
bst = xgboost.train(param, dtrain, num_round, evallist,early_stopping_rounds=10)
# Out:
# [0]	eval-aucpr:0.25576	eval-auc:0.79156	eval-mae:0.295619	eval-map:1	eval-rmse:0.306298	train-aucpr:0.294275	train-auc:0.781527	train-mae:0.27842	train-map:1	train-rmse:0.292277
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 10 rounds.
# [1]	eval-aucpr:0.267381	eval-auc:0.804176	eval-mae:0.212813	eval-map:1	eval-rmse:0.221409	train-aucpr:0.309297	train-auc:0.798313	train-mae:0.196976	train-map:1	train-rmse:0.208408
# [2]	eval-aucpr:0.268474	eval-auc:0.805277	eval-mae:0.154142	eval-map:1	eval-rmse:0.16177	train-aucpr:0.316726	train-auc:0.803558	train-mae:0.139942	train-map:1	train-rmse:0.14949
# [3]	eval-aucpr:0.270512	eval-auc:0.808033	eval-mae:0.114939	eval-map:1	eval-rmse:0.122402	train-aucpr:0.322078	train-auc:0.806943	train-mae:0.100155	train-map:1	train-rmse:0.108529
# [4]	eval-aucpr:0.270674	eval-auc:0.810845	eval-mae:0.087134	eval-map:1	eval-rmse:0.094327	train-aucpr:0.323777	train-auc:0.812027	train-mae:0.072799	train-map:1	train-rmse:0.080278
# [5]	eval-aucpr:0.269347	eval-auc:0.810494	eval-mae:0.069182	eval-map:1	eval-rmse:0.076308	train-aucpr:0.324575	train-auc:0.814156	train-mae:0.054427	train-map:1	train-rmse:0.061291
# [6]	eval-aucpr:0.269662	eval-auc:0.81172	eval-mae:0.056332	eval-map:1	eval-rmse:0.064075	train-aucpr:0.324855	train-auc:0.816686	train-mae:0.041489	train-map:1	train-rmse:0.048056
# [7]	eval-aucpr:0.270068	eval-auc:0.812279	eval-mae:0.047018	eval-map:1	eval-rmse:0.055886	train-aucpr:0.325719	train-auc:0.818301	train-mae:0.032659	train-map:1	train-rmse:0.03938
# [8]	eval-aucpr:0.274645	eval-auc:0.813284	eval-mae:0.040642	eval-map:1	eval-rmse:0.050413	train-aucpr:0.327178	train-auc:0.819087	train-mae:0.026997	train-map:1	train-rmse:0.034018
# [9]	eval-aucpr:0.272661	eval-auc:0.81452	eval-mae:0.035851	eval-map:1	eval-rmse:0.046289	train-aucpr:0.328452	train-auc:0.820319	train-mae:0.022616	train-map:1	train-rmse:0.029399
# [10]	eval-aucpr:0.273761	eval-auc:0.815533	eval-mae:0.032904	eval-map:1	eval-rmse:0.044093	train-aucpr:0.328695	train-auc:0.821157	train-mae:0.019897	train-map:1	train-rmse:0.027078
# [11]	eval-aucpr:0.273344	eval-auc:0.816412	eval-mae:0.030603	eval-map:1	eval-rmse:0.042055	train-aucpr:0.32963	train-auc:0.82192	train-mae:0.017849	train-map:1	train-rmse:0.025046
# [12]	eval-aucpr:0.275725	eval-auc:0.815289	eval-mae:0.030644	eval-map:1	eval-rmse:0.042238	train-aucpr:0.33009	train-auc:0.822331	train-mae:0.016561	train-map:1	train-rmse:0.023409
# [13]	eval-aucpr:0.275809	eval-auc:0.815414	eval-mae:0.030005	eval-map:1	eval-rmse:0.042048	train-aucpr:0.330439	train-auc:0.822735	train-mae:0.015544	train-map:1	train-rmse:0.022512
# [14]	eval-aucpr:0.275898	eval-auc:0.815303	eval-mae:0.029411	eval-map:1	eval-rmse:0.041585	train-aucpr:0.330658	train-auc:0.822905	train-mae:0.014987	train-map:1	train-rmse:0.021878
# [15]	eval-aucpr:0.274143	eval-auc:0.815193	eval-mae:0.028586	eval-map:1	eval-rmse:0.040913	train-aucpr:0.331029	train-auc:0.82338	train-mae:0.014261	train-map:1	train-rmse:0.020937
# [16]	eval-aucpr:0.274426	eval-auc:0.814945	eval-mae:0.02813	eval-map:1	eval-rmse:0.040528	train-aucpr:0.331246	train-auc:0.823704	train-mae:0.01351	train-map:1	train-rmse:0.019917
# [17]	eval-aucpr:0.274828	eval-auc:0.815003	eval-mae:0.02758	eval-map:1	eval-rmse:0.040208	train-aucpr:0.331885	train-auc:0.824353	train-mae:0.012575	train-map:1	train-rmse:0.018452
# [18]	eval-aucpr:0.274277	eval-auc:0.814968	eval-mae:0.027558	eval-map:1	eval-rmse:0.040216	train-aucpr:0.331957	train-auc:0.824508	train-mae:0.012192	train-map:1	train-rmse:0.018028
# [19]	eval-aucpr:0.274635	eval-auc:0.815473	eval-mae:0.027236	eval-map:1	eval-rmse:0.039841	train-aucpr:0.332307	train-auc:0.82477	train-mae:0.011747	train-map:1	train-rmse:0.017451
# [20]	eval-aucpr:0.274723	eval-auc:0.815937	eval-mae:0.026884	eval-map:1	eval-rmse:0.03969	train-aucpr:0.332414	train-auc:0.825114	train-mae:0.011423	train-map:1	train-rmse:0.017028
# [21]	eval-aucpr:0.27514	eval-auc:0.81615	eval-mae:0.026568	eval-map:1	eval-rmse:0.039349	train-aucpr:0.332497	train-auc:0.825332	train-mae:0.01099	train-map:1	train-rmse:0.016426
# [22]	eval-aucpr:0.274588	eval-auc:0.815724	eval-mae:0.026679	eval-map:1	eval-rmse:0.039667	train-aucpr:0.332932	train-auc:0.825545	train-mae:0.010488	train-map:1	train-rmse:0.015643
# [23]	eval-aucpr:0.274972	eval-auc:0.81627	eval-mae:0.026095	eval-map:1	eval-rmse:0.038891	train-aucpr:0.333172	train-auc:0.825788	train-mae:0.010045	train-map:1	train-rmse:0.014872
# [24]	eval-aucpr:0.274194	eval-auc:0.815122	eval-mae:0.02707	eval-map:1	eval-rmse:0.039468	train-aucpr:0.333261	train-auc:0.826017	train-mae:0.009723	train-map:1	train-rmse:0.014404
# [25]	eval-aucpr:0.274405	eval-auc:0.815294	eval-mae:0.027031	eval-map:1	eval-rmse:0.039476	train-aucpr:0.333261	train-auc:0.826146	train-mae:0.009454	train-map:1	train-rmse:0.014061
# [26]	eval-aucpr:0.274763	eval-auc:0.815457	eval-mae:0.026832	eval-map:1	eval-rmse:0.039319	train-aucpr:0.333404	train-auc:0.826349	train-mae:0.009148	train-map:1	train-rmse:0.013663
# [27]	eval-aucpr:0.275033	eval-auc:0.81551	eval-mae:0.026695	eval-map:1	eval-rmse:0.039221	train-aucpr:0.333573	train-auc:0.826416	train-mae:0.008885	train-map:1	train-rmse:0.013291
# [28]	eval-aucpr:0.275046	eval-auc:0.81563	eval-mae:0.026583	eval-map:1	eval-rmse:0.039145	train-aucpr:0.3338	train-auc:0.826629	train-mae:0.008415	train-map:1	train-rmse:0.012478
# [29]	eval-aucpr:0.274965	eval-auc:0.815672	eval-mae:0.026511	eval-map:1	eval-rmse:0.039132	train-aucpr:0.333878	train-auc:0.826795	train-mae:0.008168	train-map:1	train-rmse:0.012257
# [30]	eval-aucpr:0.27509	eval-auc:0.815925	eval-mae:0.026275	eval-map:1	eval-rmse:0.038916	train-aucpr:0.333978	train-auc:0.826915	train-mae:0.007804	train-map:1	train-rmse:0.011823
# [31]	eval-aucpr:0.275331	eval-auc:0.815977	eval-mae:0.026211	eval-map:1	eval-rmse:0.038902	train-aucpr:0.334134	train-auc:0.826984	train-mae:0.007571	train-map:1	train-rmse:0.011398
# [32]	eval-aucpr:0.275669	eval-auc:0.816357	eval-mae:0.025932	eval-map:1	eval-rmse:0.038652	train-aucpr:0.334181	train-auc:0.827128	train-mae:0.007288	train-map:1	train-rmse:0.011038
# [33]	eval-aucpr:0.276019	eval-auc:0.816233	eval-mae:0.026131	eval-map:1	eval-rmse:0.038798	train-aucpr:0.334318	train-auc:0.827195	train-mae:0.007109	train-map:1	train-rmse:0.01072
# [34]	eval-aucpr:0.27602	eval-auc:0.816161	eval-mae:0.026072	eval-map:1	eval-rmse:0.038752	train-aucpr:0.334344	train-auc:0.827255	train-mae:0.006997	train-map:1	train-rmse:0.010597
# [35]	eval-aucpr:0.275911	eval-auc:0.816106	eval-mae:0.026141	eval-map:1	eval-rmse:0.038808	train-aucpr:0.334366	train-auc:0.827309	train-mae:0.006895	train-map:1	train-rmse:0.010465
# [36]	eval-aucpr:0.276224	eval-auc:0.815735	eval-mae:0.026305	eval-map:1	eval-rmse:0.039133	train-aucpr:0.334534	train-auc:0.827446	train-mae:0.006477	train-map:1	train-rmse:0.009664
# [37]	eval-aucpr:0.276051	eval-auc:0.815516	eval-mae:0.026421	eval-map:1	eval-rmse:0.039333	train-aucpr:0.334598	train-auc:0.827498	train-mae:0.006316	train-map:1	train-rmse:0.009425
# [38]	eval-aucpr:0.275995	eval-auc:0.815515	eval-mae:0.026386	eval-map:1	eval-rmse:0.03931	train-aucpr:0.33463	train-auc:0.82753	train-mae:0.006189	train-map:1	train-rmse:0.009218
# [39]	eval-aucpr:0.276167	eval-auc:0.815604	eval-mae:0.026244	eval-map:1	eval-rmse:0.039186	train-aucpr:0.334669	train-auc:0.827547	train-mae:0.0061	train-map:1	train-rmse:0.009104
# [40]	eval-aucpr:0.276207	eval-auc:0.815837	eval-mae:0.026011	eval-map:1	eval-rmse:0.03902	train-aucpr:0.334733	train-auc:0.827622	train-mae:0.005917	train-map:1	train-rmse:0.008845
# [41]	eval-aucpr:0.276228	eval-auc:0.815909	eval-mae:0.025972	eval-map:1	eval-rmse:0.039014	train-aucpr:0.334736	train-auc:0.827642	train-mae:0.005857	train-map:1	train-rmse:0.008798
# [42]	eval-aucpr:0.276436	eval-auc:0.816079	eval-mae:0.025976	eval-map:1	eval-rmse:0.039005	train-aucpr:0.33476	train-auc:0.8277	train-mae:0.005712	train-map:1	train-rmse:0.00857
# [43]	eval-aucpr:0.276366	eval-auc:0.815906	eval-mae:0.025987	eval-map:1	eval-rmse:0.03903	train-aucpr:0.334829	train-auc:0.827733	train-mae:0.00558	train-map:1	train-rmse:0.008377
# [44]	eval-aucpr:0.275888	eval-auc:0.81581	eval-mae:0.025924	eval-map:1	eval-rmse:0.038984	train-aucpr:0.334852	train-auc:0.827765	train-mae:0.005444	train-map:1	train-rmse:0.008186
# [45]	eval-aucpr:0.275898	eval-auc:0.815845	eval-mae:0.025934	eval-map:1	eval-rmse:0.03898	train-aucpr:0.33488	train-auc:0.827792	train-mae:0.005331	train-map:1	train-rmse:0.008002
# [46]	eval-aucpr:0.275903	eval-auc:0.815843	eval-mae:0.02591	eval-map:1	eval-rmse:0.038976	train-aucpr:0.334895	train-auc:0.827823	train-mae:0.005203	train-map:1	train-rmse:0.007885
# [47]	eval-aucpr:0.276375	eval-auc:0.815934	eval-mae:0.025867	eval-map:1	eval-rmse:0.038932	train-aucpr:0.334926	train-auc:0.827832	train-mae:0.005155	train-map:1	train-rmse:0.007775
# [48]	eval-aucpr:0.276613	eval-auc:0.816124	eval-mae:0.02583	eval-map:1	eval-rmse:0.038934	train-aucpr:0.334959	train-auc:0.827884	train-mae:0.005009	train-map:1	train-rmse:0.007551
# [49]	eval-aucpr:0.276366	eval-auc:0.815977	eval-mae:0.025844	eval-map:1	eval-rmse:0.038961	train-aucpr:0.335005	train-auc:0.827939	train-mae:0.004849	train-map:1	train-rmse:0.007304
# [50]	eval-aucpr:0.276214	eval-auc:0.816014	eval-mae:0.025812	eval-map:1	eval-rmse:0.038933	train-aucpr:0.335032	train-auc:0.82798	train-mae:0.00469	train-map:1	train-rmse:0.007159
# [51]	eval-aucpr:0.276224	eval-auc:0.816074	eval-mae:0.025788	eval-map:1	eval-rmse:0.038905	train-aucpr:0.335036	train-auc:0.827995	train-mae:0.004635	train-map:1	train-rmse:0.007111
# [52]	eval-aucpr:0.276528	eval-auc:0.81613	eval-mae:0.025688	eval-map:1	eval-rmse:0.038814	train-aucpr:0.335048	train-auc:0.828	train-mae:0.004596	train-map:1	train-rmse:0.007049
# [53]	eval-aucpr:0.276147	eval-auc:0.815855	eval-mae:0.02568	eval-map:1	eval-rmse:0.038833	train-aucpr:0.335078	train-auc:0.828035	train-mae:0.004466	train-map:1	train-rmse:0.006859
# [54]	eval-aucpr:0.275552	eval-auc:0.815577	eval-mae:0.025741	eval-map:1	eval-rmse:0.038886	train-aucpr:0.335109	train-auc:0.828072	train-mae:0.004302	train-map:1	train-rmse:0.006546
# [55]	eval-aucpr:0.275892	eval-auc:0.815643	eval-mae:0.025726	eval-map:1	eval-rmse:0.038881	train-aucpr:0.335148	train-auc:0.828122	train-mae:0.004186	train-map:1	train-rmse:0.006348
# [56]	eval-aucpr:0.275951	eval-auc:0.815691	eval-mae:0.02573	eval-map:1	eval-rmse:0.038884	train-aucpr:0.335148	train-auc:0.828141	train-mae:0.004105	train-map:1	train-rmse:0.006233
# [57]	eval-aucpr:0.275824	eval-auc:0.815568	eval-mae:0.02572	eval-map:1	eval-rmse:0.038855	train-aucpr:0.335148	train-auc:0.82815	train-mae:0.004037	train-map:1	train-rmse:0.006122
# [58]	eval-aucpr:0.275516	eval-auc:0.81561	eval-mae:0.025657	eval-map:1	eval-rmse:0.038801	train-aucpr:0.335161	train-auc:0.828172	train-mae:0.003948	train-map:1	train-rmse:0.006027
# [59]	eval-aucpr:0.275506	eval-auc:0.815628	eval-mae:0.025593	eval-map:1	eval-rmse:0.038757	train-aucpr:0.33519	train-auc:0.828199	train-mae:0.003826	train-map:1	train-rmse:0.005871
# [60]	eval-aucpr:0.275556	eval-auc:0.815598	eval-mae:0.025594	eval-map:1	eval-rmse:0.038802	train-aucpr:0.335199	train-auc:0.828213	train-mae:0.003729	train-map:1	train-rmse:0.005731
# [61]	eval-aucpr:0.275927	eval-auc:0.815759	eval-mae:0.025511	eval-map:1	eval-rmse:0.038741	train-aucpr:0.335222	train-auc:0.828227	train-mae:0.003641	train-map:1	train-rmse:0.005574
# [62]	eval-aucpr:0.276024	eval-auc:0.815817	eval-mae:0.025513	eval-map:1	eval-rmse:0.038779	train-aucpr:0.335283	train-auc:0.828244	train-mae:0.003541	train-map:1	train-rmse:0.005363
# [63]	eval-aucpr:0.276032	eval-auc:0.815851	eval-mae:0.025448	eval-map:1	eval-rmse:0.038762	train-aucpr:0.335287	train-auc:0.828263	train-mae:0.003488	train-map:1	train-rmse:0.005322
# [64]	eval-aucpr:0.27604	eval-auc:0.815868	eval-mae:0.025431	eval-map:1	eval-rmse:0.038783	train-aucpr:0.335329	train-auc:0.828275	train-mae:0.003395	train-map:1	train-rmse:0.005144
# [65]	eval-aucpr:0.275651	eval-auc:0.815582	eval-mae:0.025449	eval-map:1	eval-rmse:0.038813	train-aucpr:0.335356	train-auc:0.828308	train-mae:0.003283	train-map:1	train-rmse:0.004937
# [66]	eval-aucpr:0.275895	eval-auc:0.815684	eval-mae:0.025436	eval-map:1	eval-rmse:0.038816	train-aucpr:0.335368	train-auc:0.828317	train-mae:0.003221	train-map:1	train-rmse:0.004817
# [67]	eval-aucpr:0.275881	eval-auc:0.815614	eval-mae:0.025521	eval-map:1	eval-rmse:0.038898	train-aucpr:0.335389	train-auc:0.828341	train-mae:0.003102	train-map:1	train-rmse:0.004666
# [68]	eval-aucpr:0.275843	eval-auc:0.815667	eval-mae:0.025458	eval-map:1	eval-rmse:0.038813	train-aucpr:0.335412	train-auc:0.828354	train-mae:0.003009	train-map:1	train-rmse:0.004534
# [69]	eval-aucpr:0.275854	eval-auc:0.815721	eval-mae:0.025418	eval-map:1	eval-rmse:0.038763	train-aucpr:0.335425	train-auc:0.828369	train-mae:0.002898	train-map:1	train-rmse:0.004333
# [70]	eval-aucpr:0.275756	eval-auc:0.815638	eval-mae:0.02534	eval-map:1	eval-rmse:0.038681	train-aucpr:0.335444	train-auc:0.828383	train-mae:0.002837	train-map:1	train-rmse:0.004224
# [71]	eval-aucpr:0.27576	eval-auc:0.815656	eval-mae:0.025322	eval-map:1	eval-rmse:0.038676	train-aucpr:0.335447	train-auc:0.828391	train-mae:0.002806	train-map:1	train-rmse:0.004198
# [72]	eval-aucpr:0.275888	eval-auc:0.815729	eval-mae:0.025303	eval-map:1	eval-rmse:0.038651	train-aucpr:0.335442	train-auc:0.828393	train-mae:0.002776	train-map:1	train-rmse:0.004166
# [73]	eval-aucpr:0.275788	eval-auc:0.815668	eval-mae:0.025365	eval-map:1	eval-rmse:0.0388	train-aucpr:0.335457	train-auc:0.82841	train-mae:0.002699	train-map:1	train-rmse:0.00404
# [74]	eval-aucpr:0.275837	eval-auc:0.815701	eval-mae:0.025291	eval-map:1	eval-rmse:0.038761	train-aucpr:0.335461	train-auc:0.828416	train-mae:0.002659	train-map:1	train-rmse:0.003982
# [75]	eval-aucpr:0.275832	eval-auc:0.815744	eval-mae:0.025272	eval-map:1	eval-rmse:0.038755	train-aucpr:0.335463	train-auc:0.828426	train-mae:0.002616	train-map:1	train-rmse:0.003932
# [76]	eval-aucpr:0.275871	eval-auc:0.815854	eval-mae:0.025265	eval-map:1	eval-rmse:0.038762	train-aucpr:0.335469	train-auc:0.828434	train-mae:0.002575	train-map:1	train-rmse:0.003888
# [77]	eval-aucpr:0.275873	eval-auc:0.815857	eval-mae:0.025251	eval-map:1	eval-rmse:0.038739	train-aucpr:0.335484	train-auc:0.828447	train-mae:0.002504	train-map:1	train-rmse:0.003741
# [78]	eval-aucpr:0.276757	eval-auc:0.81593	eval-mae:0.025255	eval-map:1	eval-rmse:0.038743	train-aucpr:0.335492	train-auc:0.828458	train-mae:0.00244	train-map:1	train-rmse:0.003654
# [79]	eval-aucpr:0.276773	eval-auc:0.815954	eval-mae:0.025255	eval-map:1	eval-rmse:0.038794	train-aucpr:0.335501	train-auc:0.828473	train-mae:0.002351	train-map:1	train-rmse:0.003523
# [80]	eval-aucpr:0.275726	eval-auc:0.815774	eval-mae:0.025259	eval-map:1	eval-rmse:0.0388	train-aucpr:0.33551	train-auc:0.828478	train-mae:0.002295	train-map:1	train-rmse:0.00346
# [81]	eval-aucpr:0.275768	eval-auc:0.815788	eval-mae:0.025225	eval-map:1	eval-rmse:0.038792	train-aucpr:0.335512	train-auc:0.828484	train-mae:0.002257	train-map:1	train-rmse:0.003426
# [82]	eval-aucpr:0.275726	eval-auc:0.815748	eval-mae:0.025222	eval-map:1	eval-rmse:0.038895	train-aucpr:0.335523	train-auc:0.828499	train-mae:0.002186	train-map:1	train-rmse:0.003274
# [83]	eval-aucpr:0.275679	eval-auc:0.815765	eval-mae:0.025208	eval-map:1	eval-rmse:0.038875	train-aucpr:0.335525	train-auc:0.828503	train-mae:0.002154	train-map:1	train-rmse:0.003233
# [84]	eval-aucpr:0.275678	eval-auc:0.815757	eval-mae:0.025213	eval-map:1	eval-rmse:0.038876	train-aucpr:0.335525	train-auc:0.828504	train-mae:0.002144	train-map:1	train-rmse:0.003227
# [85]	eval-aucpr:0.275548	eval-auc:0.815661	eval-mae:0.025177	eval-map:1	eval-rmse:0.038839	train-aucpr:0.335532	train-auc:0.828512	train-mae:0.002085	train-map:1	train-rmse:0.00314
# [86]	eval-aucpr:0.275563	eval-auc:0.815716	eval-mae:0.025161	eval-map:1	eval-rmse:0.038814	train-aucpr:0.335533	train-auc:0.828516	train-mae:0.002067	train-map:1	train-rmse:0.003118
# [87]	eval-aucpr:0.275567	eval-auc:0.815732	eval-mae:0.025181	eval-map:1	eval-rmse:0.038921	train-aucpr:0.335537	train-auc:0.828522	train-mae:0.002025	train-map:1	train-rmse:0.003005
# [88]	eval-aucpr:0.275511	eval-auc:0.81574	eval-mae:0.025143	eval-map:1	eval-rmse:0.038897	train-aucpr:0.335543	train-auc:0.828531	train-mae:0.001957	train-map:1	train-rmse:0.002899
# [89]	eval-aucpr:0.275593	eval-auc:0.815751	eval-mae:0.02514	eval-map:1	eval-rmse:0.038878	train-aucpr:0.335566	train-auc:0.828541	train-mae:0.001889	train-map:1	train-rmse:0.002779
# [90]	eval-aucpr:0.275591	eval-auc:0.815755	eval-mae:0.025136	eval-map:1	eval-rmse:0.038883	train-aucpr:0.335568	train-auc:0.828548	train-mae:0.001849	train-map:1	train-rmse:0.002728
# [91]	eval-aucpr:0.275565	eval-auc:0.815769	eval-mae:0.02512	eval-map:1	eval-rmse:0.038884	train-aucpr:0.335568	train-auc:0.82855	train-mae:0.001836	train-map:1	train-rmse:0.002716
# [92]	eval-aucpr:0.275037	eval-auc:0.815729	eval-mae:0.025086	eval-map:1	eval-rmse:0.038868	train-aucpr:0.33557	train-auc:0.828554	train-mae:0.001814	train-map:1	train-rmse:0.002671
# [93]	eval-aucpr:0.275136	eval-auc:0.815779	eval-mae:0.025083	eval-map:1	eval-rmse:0.038849	train-aucpr:0.335573	train-auc:0.828558	train-mae:0.001767	train-map:1	train-rmse:0.002612
# [94]	eval-aucpr:0.275482	eval-auc:0.81585	eval-mae:0.025103	eval-map:1	eval-rmse:0.038859	train-aucpr:0.335561	train-auc:0.82856	train-mae:0.00174	train-map:1	train-rmse:0.002571
# [95]	eval-aucpr:0.27548	eval-auc:0.815835	eval-mae:0.025111	eval-map:1	eval-rmse:0.038866	train-aucpr:0.335562	train-auc:0.828562	train-mae:0.001715	train-map:1	train-rmse:0.002547
# [96]	eval-aucpr:0.275471	eval-auc:0.815814	eval-mae:0.025097	eval-map:1	eval-rmse:0.038874	train-aucpr:0.335567	train-auc:0.828564	train-mae:0.001698	train-map:1	train-rmse:0.00252
# [97]	eval-aucpr:0.27547	eval-auc:0.815806	eval-mae:0.025085	eval-map:1	eval-rmse:0.038869	train-aucpr:0.335571	train-auc:0.828568	train-mae:0.001668	train-map:1	train-rmse:0.002492
# [98]	eval-aucpr:0.275474	eval-auc:0.81583	eval-mae:0.025072	eval-map:1	eval-rmse:0.038867	train-aucpr:0.335571	train-auc:0.828572	train-mae:0.001644	train-map:1	train-rmse:0.002472
# [99]	eval-aucpr:0.275162	eval-auc:0.815773	eval-mae:0.025086	eval-map:1	eval-rmse:0.038876	train-aucpr:0.335575	train-auc:0.828574	train-mae:0.00162	train-map:1	train-rmse:0.002437
# [100]	eval-aucpr:0.275447	eval-auc:0.815797	eval-mae:0.025089	eval-map:1	eval-rmse:0.038885	train-aucpr:0.335578	train-auc:0.828575	train-mae:0.001597	train-map:1	train-rmse:0.002405
# [101]	eval-aucpr:0.276152	eval-auc:0.815796	eval-mae:0.025058	eval-map:1	eval-rmse:0.038907	train-aucpr:0.335584	train-auc:0.828581	train-mae:0.001536	train-map:1	train-rmse:0.002256
# [102]	eval-aucpr:0.276152	eval-auc:0.815803	eval-mae:0.02505	eval-map:1	eval-rmse:0.0389	train-aucpr:0.335584	train-auc:0.828584	train-mae:0.00152	train-map:1	train-rmse:0.002241
# [103]	eval-aucpr:0.276199	eval-auc:0.815806	eval-mae:0.02506	eval-map:1	eval-rmse:0.038904	train-aucpr:0.335588	train-auc:0.828589	train-mae:0.001482	train-map:1	train-rmse:0.002179
# [104]	eval-aucpr:0.276206	eval-auc:0.815845	eval-mae:0.025022	eval-map:1	eval-rmse:0.038876	train-aucpr:0.335589	train-auc:0.828591	train-mae:0.001465	train-map:1	train-rmse:0.002164
# [105]	eval-aucpr:0.276201	eval-auc:0.815824	eval-mae:0.025071	eval-map:1	eval-rmse:0.03891	train-aucpr:0.33559	train-auc:0.828593	train-mae:0.001448	train-map:1	train-rmse:0.002146
# [106]	eval-aucpr:0.276242	eval-auc:0.815904	eval-mae:0.02506	eval-map:1	eval-rmse:0.038893	train-aucpr:0.335591	train-auc:0.828595	train-mae:0.00142	train-map:1	train-rmse:0.002117
# [107]	eval-aucpr:0.276242	eval-auc:0.815908	eval-mae:0.025061	eval-map:1	eval-rmse:0.038901	train-aucpr:0.335591	train-auc:0.828596	train-mae:0.001405	train-map:1	train-rmse:0.002098
# [108]	eval-aucpr:0.276263	eval-auc:0.815957	eval-mae:0.025037	eval-map:1	eval-rmse:0.038891	train-aucpr:0.335598	train-auc:0.828598	train-mae:0.001368	train-map:1	train-rmse:0.002051
# [109]	eval-aucpr:0.276255	eval-auc:0.81592	eval-mae:0.02504	eval-map:1	eval-rmse:0.038895	train-aucpr:0.335599	train-auc:0.828598	train-mae:0.001358	train-map:1	train-rmse:0.002039
# [110]	eval-aucpr:0.276284	eval-auc:0.815983	eval-mae:0.025041	eval-map:1	eval-rmse:0.038892	train-aucpr:0.3356	train-auc:0.8286	train-mae:0.001332	train-map:1	train-rmse:0.002003
# [111]	eval-aucpr:0.276262	eval-auc:0.815958	eval-mae:0.025006	eval-map:1	eval-rmse:0.038883	train-aucpr:0.335602	train-auc:0.828603	train-mae:0.001304	train-map:1	train-rmse:0.00196
# [112]	eval-aucpr:0.276259	eval-auc:0.815953	eval-mae:0.024994	eval-map:1	eval-rmse:0.038881	train-aucpr:0.335604	train-auc:0.828605	train-mae:0.00128	train-map:1	train-rmse:0.001926
# [113]	eval-aucpr:0.276261	eval-auc:0.815967	eval-mae:0.024991	eval-map:1	eval-rmse:0.038878	train-aucpr:0.335606	train-auc:0.828608	train-mae:0.001259	train-map:1	train-rmse:0.001886
# [114]	eval-aucpr:0.276261	eval-auc:0.815966	eval-mae:0.024976	eval-map:1	eval-rmse:0.038868	train-aucpr:0.335607	train-auc:0.828609	train-mae:0.001245	train-map:1	train-rmse:0.001872
# [115]	eval-aucpr:0.276261	eval-auc:0.815965	eval-mae:0.024975	eval-map:1	eval-rmse:0.038868	train-aucpr:0.335607	train-auc:0.828609	train-mae:0.001244	train-map:1	train-rmse:0.001871
# [116]	eval-aucpr:0.276261	eval-auc:0.815965	eval-mae:0.024975	eval-map:1	eval-rmse:0.038868	train-aucpr:0.335607	train-auc:0.828609	train-mae:0.001244	train-map:1	train-rmse:0.001871
# [117]	eval-aucpr:0.276261	eval-auc:0.815965	eval-mae:0.024975	eval-map:1	eval-rmse:0.038868	train-aucpr:0.335607	train-auc:0.828609	train-mae:0.001244	train-map:1	train-rmse:0.001871
# [118]	eval-aucpr:0.276261	eval-auc:0.815965	eval-mae:0.024975	eval-map:1	eval-rmse:0.038868	train-aucpr:0.335607	train-auc:0.828609	train-mae:0.001244	train-map:1	train-rmse:0.001871
# [119]	eval-aucpr:0.276261	eval-auc:0.815965	eval-mae:0.024975	eval-map:1	eval-rmse:0.038868	train-aucpr:0.335607	train-auc:0.828609	train-mae:0.001244	train-map:1	train-rmse:0.001871
# [120]	eval-aucpr:0.276261	eval-auc:0.815965	eval-mae:0.024975	eval-map:1	eval-rmse:0.038868	train-aucpr:0.335607	train-auc:0.828609	train-mae:0.001244	train-map:1	train-rmse:0.001871
# [121]	eval-aucpr:0.276261	eval-auc:0.815965	eval-mae:0.024975	eval-map:1	eval-rmse:0.038868	train-aucpr:0.335607	train-auc:0.828609	train-mae:0.001244	train-map:1	train-rmse:0.001871
# [122]	eval-aucpr:0.276261	eval-auc:0.815965	eval-mae:0.024975	eval-map:1	eval-rmse:0.038868	train-aucpr:0.335607	train-auc:0.828609	train-mae:0.001244	train-map:1	train-rmse:0.001871
# [123]	eval-aucpr:0.276261	eval-auc:0.815965	eval-mae:0.024975	eval-map:1	eval-rmse:0.038868	train-aucpr:0.335607	train-auc:0.828609	train-mae:0.001244	train-map:1	train-rmse:0.001871
# [124]	eval-aucpr:0.276261	eval-auc:0.815965	eval-mae:0.024975	eval-map:1	eval-rmse:0.038868	train-aucpr:0.335607	train-auc:0.828609	train-mae:0.001244	train-map:1	train-rmse:0.001871
# [125]	eval-aucpr:0.276261	eval-auc:0.815965	eval-mae:0.024975	eval-map:1	eval-rmse:0.038868	train-aucpr:0.335607	train-auc:0.828609	train-mae:0.001244	train-map:1	train-rmse:0.001871
# Stopping. Best iteration:
# [115]	eval-aucpr:0.276261	eval-auc:0.815965	eval-mae:0.024975	eval-map:1	eval-rmse:0.038868	train-aucpr:0.335607	train-auc:0.828609	train-mae:0.001244	train-map:1	train-rmse:0.001871

# %%
# save to binary file for faster loading
bst.save_model('cross.substrate.train.neil1.and.ttyh2.substrates.model')
# save model to text file 
bst.dump_model('cross.substrate.train.neil1.and.ttyh2.substrates.txt')

# %%
## get model predictions on the test, training, and eval splits 
test_pred = bst.predict(dtest)
train_pred=bst.predict(dtrain)
eval_pred=bst.predict(deval)

# %%
## Get performance metrics on full dataset 
from helpers import * 
print_aggregate_peformance_metrics(train_y,train_pred,
                                   eval_y,eval_pred,
                                   test_y,test_pred,
                                   positive_thresh=0.5)
# Out:
# Train
# 	Spearman corr : SpearmanrResult(correlation=0.9990272992237627, pvalue=0.0)
# 	Pearson corr : (0.9998825332780172, 0.0)
# 	MAE : 0.0012443876049598708
# 	MAPE : 0.027294476962433794
# 	RMSE : 0.001871197918719419
# 	auPRC : 1.0
# 	auROC : 1.0
# Eval
# 	Spearman corr : SpearmanrResult(correlation=0.8478461187960931, pvalue=6.357858914936367e-51)
# 	Pearson corr : (0.9365046725604632, 6.207842569597163e-83)
# 	MAE : 0.024975057400907906
# 	MAPE : 0.5210657508274517
# 	RMSE : 0.03886787478831286
# 	auPRC : 0.14285714285714285
# 	auROC : 0.9664804469273743
# Test
# 	Spearman corr : SpearmanrResult(correlation=0.4767697700560376, pvalue=1.1232730512792487e-25)
# 	Pearson corr : (0.5633169237390745, 3.3229470610041864e-37)
# 	MAE : 0.1837919963286302
# 	MAPE : 1.0425301300145164
# 	RMSE : 0.24735582507591666
# 	auPRC : 0.6746521227077156
# 	auROC : 0.7765666445623343

# %%
## Correlation values 
from scipy.stats import spearmanr,pearsonr
spearman_train=spearmanr(train_y,train_pred)
spearman_eval=spearmanr(eval_y,eval_pred)
spearman_test=spearmanr(test_y,test_pred)

pearson_train=pearsonr(train_y,train_pred)
pearson_eval=pearsonr(eval_y,eval_pred)
pearson_test=pearsonr(test_y,test_pred)

print("Spearman correlation:")
print("Train:"+str(spearman_train))
print("Eval:"+str(spearman_eval))
print("Test:"+str(spearman_test))
print("\n")
print("Pearson correlation:")
print("Train:"+str(pearson_train))
print("Eval:"+str(pearson_eval))
print("Test:"+str(pearson_test))
# Out:
# Spearman correlation:
# Train:SpearmanrResult(correlation=0.9990272992237627, pvalue=0.0)
# Eval:SpearmanrResult(correlation=0.8478461187960931, pvalue=6.357858914936367e-51)
# Test:SpearmanrResult(correlation=0.4767697700560376, pvalue=1.1232730512792487e-25)
#
#
# Pearson correlation:
# Train:(0.9998825332780172, 0.0)
# Eval:(0.9365046725604632, 6.207842569597163e-83)
# Test:(0.5633169237390745, 3.3229470610041864e-37)

# %%
## MAE
from sklearn.metrics import mean_absolute_error
mae_train=mean_absolute_error(train_y,train_pred)
print("MAE Train:"+str(mae_train))

mae_eval=mean_absolute_error(eval_y,eval_pred)
print("MAE Eval:"+str(mae_eval))

mae_test=mean_absolute_error(test_y,test_pred)
print("MAE Test:"+str(mae_test))
# Out:
# MAE Train:0.0012443876049598708
# MAE Eval:0.024975057400907906
# MAE Test:0.1837919963286302

# %%
## MAPE
pseudocount=0.01
mape_train=np.mean(np.abs((train_y - train_pred) /(pseudocount+train_y))) * 100
print("MAPE Train:"+str(mape_train)+"%")

mape_eval=np.mean(np.abs((eval_y - eval_pred) /(pseudocount+eval_y))) * 100
print("MAPE Eval:"+str(mape_eval)+"%")

mape_test=np.mean(np.abs((test_y - test_pred) /(pseudocount+test_y))) * 100
print("MAPE Test:"+str(mape_test)+"%")
# Out:
# MAPE Train:2.7294476962433794%
# MAPE Eval:52.10657508274517%
# MAPE Test:104.25301300145165%

# %%
## RMSE
from sklearn.metrics import mean_squared_error
import math 
rmse_train=math.sqrt(mean_squared_error(train_y,train_pred))
print("RMSE Train:"+str(rmse_train))

rmse_eval=math.sqrt(mean_squared_error(eval_y,eval_pred))
print("RMSE Eval:"+str(rmse_eval))

rmse_test=math.sqrt(mean_squared_error(test_y,test_pred))
print("RMSE Test:"+str(rmse_test))
# Out:
# RMSE Train:0.001871197918719419
# RMSE Eval:0.03886787478831286
# RMSE Test:0.24735582507591666

# %%
## PRC 
## PRC only valid for binary outcomes. 
## Editing levels < 0.5 are labeled as "0". 
## Editing levels >= 0.5 are labeled as "1". 

from sklearn.metrics import auc, precision_recall_curve

precision_train,recall_train,prc_thresholds_train=precision_recall_curve(train_y>=0.4,train_pred)
precision_eval,recall_eval,prc_thresholds_eval=precision_recall_curve(eval_y>=0.4,eval_pred)
precision_test,recall_test,prc_thresholds_test=precision_recall_curve(test_y>=0.4,test_pred)

auprc_train=auc(recall_train,precision_train)
auprc_eval=auc(recall_eval,precision_eval)
auprc_test=auc(recall_test,precision_test)

plt.plot(recall_train,precision_train,'r',label="Train:"+str(round(auprc_train,2)))
plt.plot(recall_eval,precision_eval,'g',label="Eval:"+str(round(auprc_eval,2)))
plt.plot(recall_test,precision_test,'b',label="Test:"+str(round(auprc_test,2)))
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("PRC")
plt.legend()

# %%
## ROC
from sklearn.metrics import roc_curve, roc_auc_score
fpr_train,tpr_train,roc_thresholds_train=roc_curve(train_y>=0.4,train_pred)
fpr_eval,tpr_eval,roc_thresholds_eval=roc_curve(eval_y>=0.4,eval_pred)
fpr_test,tpr_test,roc_thresholds_test=roc_curve(test_y>=0.4,test_pred)

auroc_train=roc_auc_score(train_y>=0.4,train_pred)
auroc_eval=roc_auc_score(eval_y>=0.4,eval_pred)
auroc_test=roc_auc_score(test_y>=0.4,test_pred)

plt.plot(fpr_train,tpr_train,'r',label="Train:"+str(round(auroc_train,2)))
plt.plot(fpr_eval,tpr_eval,'g',label="Eval:"+str(round(auroc_eval,2)))
plt.plot(fpr_test,tpr_test,'b',label="Test:"+str(round(auroc_test,2)))
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC")
plt.legend()

# %%
#calculate R^2, which is representative of variance explained 
# https://datascienceplus.com/extreme-gradient-boosting-with-r/
# https://arxiv.org/pdf/1706.06060.pdf

residuals = test_y - test_pred

y_test_mean = np.mean(test_pred)
print(y_test_mean)
#calculate total sum of squares 
tss=sum((test_y-y_test_mean)*(test_y-y_test_mean))
print(tss)
# Calculate residual sum of squares
rss =  sum(residuals*residuals)
print(rss)
# Calculate R-squared
rsq  =  1 - (rss/tss)
print('The R-square of the test data is ', round(rsq,3), '\n')
# Out:
# 0.121503904
# 32.7380456350621
# 26.187138997166628
# The R-square of the test data is  0.2

# %%
#plot the test set predictions 
matplotlib.rcParams['figure.figsize'] = [20, 8]
plt.subplot(1,3,1)
plt.plot(list(train_y),list(train_pred),'o')
plt.xlabel("Observed train set editing level, AJUBA Comp + TTYH2 Comp")
plt.ylabel("Predicted train set editing level, AJUBA Comp + TTYH2 Comp")
plt.subplot(1,3,2)
plt.plot(list(eval_y),list(eval_pred),'o')
plt.xlabel("Observed eval set editing level, AJUBA Comp + TTYH2 Comp")
plt.ylabel("Predicted eval set editing level, AJUBA Comp + TTYH2 Comp")
plt.subplot(1,3,3)
plt.plot(list(test_y),list(test_pred),'o')
plt.xlabel("Observed test set editing level, NEIL1 Comp")
plt.ylabel("Predicted test set editing level, NEIL1 Comp")

plt.show()

# %%
matplotlib.rcParams['figure.figsize'] = [20, 30]
xgboost.plot_importance(bst)

# %%
#xgboost.to_graphviz(bst, num_trees=2)

# %%
# explain the model's predictions using SHAP values
explainer = shap.TreeExplainer(bst)
shap_values = explainer.shap_values(test_X)
shap_values.shape

# %%
test_y=pd.DataFrame(test_y)
max_index=test_y.index[test_y['editing_value'] == max(test_y['editing_value'])]
max_row=test_y.index.get_loc(max_index[0])
# visualize prediction for isoform with the highest editing level 
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[max_row,:], test_X.iloc[max_row,:])

# %%
# visualize prediction for isoform with the lowest editing level 
shap.initjs()
min_index=test_y.index[test_y['editing_value'] == min(test_y['editing_value'])]
min_row=test_y.index.get_loc(min_index[0])
shap.force_plot(explainer.expected_value, shap_values[min_row,:], test_X.iloc[min_row,:])

# %%
# visualize the training set predictions
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values,train_X)

# %%
# summarize the effect of all the features 
shap.summary_plot(shap_values, test_X)

# %%
# We can also just take the mean absolute value of the SHAP values for each feature 
# to get a standard bar plot (produces stacked bars for multi-class outputs):
shap.summary_plot(shap_values, test_X, plot_type="bar")

# %%
## Compute pairwise interaction values from TreeShap
shap_interaction_values=explainer.shap_interaction_values(test_X)
shap_interaction_values.shape

# %%
##Average interaction values across the datapoints in the test set 
mean_interaction_values=np.mean(shap_interaction_values,axis=0)

# %%
Index=test_X.columns
Cols=test_X.columns
mean_interaction_values_df = pd.DataFrame(mean_interaction_values, index=Index, columns=Cols)

# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
configure_plotly_browser_state()

trace = Heatmap(z=mean_interaction_values_df.values,
                   x=Cols,
                   y=Index)
iplot([trace],show_link=False)
