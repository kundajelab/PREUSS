# %% [markdown]
# <a href="https://colab.research.google.com/github/kundajelab/adar_editing/blob/master/xgboost_with_shap/CROSS_SUBSTRATE_TRAINING_XGBOOST_WITH_TREESHAP_TRAIN_NEIL1_AND_AJUBA_PREDICT_TTYH2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Uncomment these lines if running as a google colab notebook: 
#!pip install numpy==1.15
#! git clone https://github.com/kundajelab/adar_editing
#import os
#os.chdir("adar_editing/xgboost_with_shap/")
#!pip install shap
#!pip install --upgrade xgboost
#!pip install cufflinks

# %%
# %load_ext autoreload
# %autoreload 2

# %%
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

# %%
#helper utilities for model training and interpretation 
import shap
from helpers import * 

#set a random seed so code is reproducible 
random.seed(1234)

# load JS visualization code to notebook
shap.initjs()
import warnings
warnings.filterwarnings('ignore')

#visualization utilities 
import matplotlib
import matplotlib.pyplot as plt 
# %matplotlib inline
import plotly.plotly as py
import numpy as np
from plotly.offline import iplot
from plotly.graph_objs import Heatmap
# Out:
# /users/annashch/miniconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /users/annashch/miniconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...

# %%
## Load all the datasets : TTYH2
ttyh2_comp=pd.read_csv("../xin_feature_matrices/ttyh2_computational.features.csv",header=0,sep=',',index_col=0)
#remove any null editing level values 
ttyh2_comp=ttyh2_comp[~ttyh2_comp["editing_value"].isnull().values]
ttyh2_comp=format_for_xgboost(ttyh2_comp)
# Out:
# (601, 216)

# %%
## Load all the datasets: NEIL1
neil1_comp=pd.read_csv("../xin_feature_matrices/neil1_computational.features.csv",header=0,sep=',',index_col=0)
#remove any null editing level values 
neil1_comp=neil1_comp[~neil1_comp["editing_value"].isnull().values]
neil1_comp=format_for_xgboost(neil1_comp)
# Out:
# (428, 219)

# %%
## Load all the dtasets: AJUBA
ajuba_comp=pd.read_csv("../xin_feature_matrices/ajuba_bc_computational.features.csv",header=0,sep=',',index_col=0)
#remove any null editing level values 
ajuba_comp=ajuba_comp[~ajuba_comp["editing_value"].isnull().values]
ajuba_comp=format_for_xgboost(ajuba_comp)
# Out:
# (482, 186)

# %%
train_split,eval_split=split_train_eval_by_mut_pos(ajuba_comp[~ajuba_comp['mut_pos'].isna()])
null_mut_pos=train_split[train_split['mut_pos'].isna()]
train_split=pd.concat((train_split,null_mut_pos),axis=0)
# Out:
# {64.0: 22, 65.0: 21, 66.0: 22, 67.0: 22, 68.0: 22, 69.0: 23, 70.0: 23, 71.0: 24, 72.0: 23, 73.0: 33, 75.0: 33, 76.0: 24, 77.0: 24, 78.0: 23, 79.0: 23, 80.0: 22, 81.0: 22, 82.0: 22, 83.0: 44}

# %% [markdown]
# ## Train AJUBA, predict NEIL1

# %%
test_split=neil1_comp

# %%
train_split.reset_index(inplace=True, drop=True) 
eval_split.reset_index(inplace=True,drop=True)
test_split.reset_index(inplace=True,drop=True)

# %%
#Remove any non-varying features 
train_novar=get_singleval_features(train_split)
eval_novar=get_singleval_features(eval_split)
test_novar=get_singleval_features(test_split)
uniform_features_to_drop=list(set(train_novar+eval_novar+test_novar))

# %%
#Remove any null features 
train_null=get_all_null_features(train_split)
eval_null=get_all_null_features(eval_split)
test_null=get_all_null_features(test_split)
null_features_to_drop=list(set(train_null+eval_null+test_null))

# %%
to_drop=list(set(uniform_features_to_drop+null_features_to_drop))
print("\n".join(to_drop))
# Out:
# u3_3prm_cp_internal
# d2_3prm_cp_internal:A:U
# d1_length_bulge
# mut_ref_nt:A
# site_3prm_cp_internal:C:G
# d2_exist
# mut_ref_nt:G
# d3_length_hairpin
# u3_5prm_cp_internal
# site_5prm_cp_hairpin
# u1_5prm_cp_bulge:U:A
# d1_struct:B
# u2_exist
# d2_3prm_cp_internal:C:G
# d1_exist
# u2_3prm_cp_internal
# d3_length_bulge
# u3_exist
# d1_5prm_cp_bulge
# site_next_struct:B
# d2_5prm_cp_bulge
# u1_5prm_cp_internal
# mut_exist
# u1_3prm_cp_bulge:C:G
# site_next_nt:A
# d3_5prm_cp_bulge
# d2_3prm_cp_bulge
# mut_same_as_site
# d3_3prm_cp_bulge
# u1_length_hairpin
# u2_5prm_cp_internal
# site_next_nt:U
# d1_5prm_cp_hairpin
# d3_5prm_cp_hairpin
# u1_length_internal_ecs
# u1_3prm_cp_bulge:U:A
# d2_5prm_cp_hairpin
# d1_3prm_cp_bulge
# site_prev_nt:U
# site_length_hairpin
# d3_exist
# d1_5prm_cp_bulge:C:G
# site_prev_nt:A
# mut_type:indel
# u1_3prm_cp_internal
# d2_length_hairpin
# u3_length_internal_es
# d1_3prm_cp_bulge:G:U
# d2_3prm_cp_internal:U:A
# mut_type:wt
# u2_length_internal_ecs
# d2_length_bulge
# mut_type:mismatch
# u3_length_internal_ecs
# u1_exist
# d1_5prm_cp_internal:A:U
# u1_5prm_cp_hairpin
# site_3prm_cp_bulge:A:U
# d1_length_hairpin
# u2_length_internal_es
# u1_length_internal_es
# d1_3prm_cp_internal:G:C
# site_5prm_cp_internal:A:U
# d2_3prm_cp_internal:G:C

# %%
#remove teh features that don't change across isoforms , or are null for all isoforms
for cur_to_drop in to_drop: 
    try:
        train_split=train_split.drop(cur_to_drop,axis=1)
    except: 
        pass
    try:
        eval_split=eval_split.drop(cur_to_drop,axis=1)
    except: 
        pass 
    try:
        test_split=test_split.drop(to_drop,axis=1)
    except: 
        pass

# %%
train_y=train_split['editing_value']
train_X=train_split.drop(['editing_value'],axis=1)
eval_y=eval_split['editing_value']
eval_X=eval_split.drop(['editing_value'],axis=1)
test_y=test_split['editing_value']
test_X=test_split.drop(['editing_value'],axis=1)

# %%
print(train_X.shape)
print(train_y.shape)
print(eval_X.shape)
print(eval_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (361, 123)
# (361,)
# (89, 123)
# (89,)
# (428, 218)
# (428,)

# %%
train_cols=set(train_X.columns)
eval_cols=set(eval_X.columns)
test_cols=set(test_X.columns)

# %%
common=train_cols.intersection(eval_cols)
common=list(common.intersection(test_cols))
print(common)
train_X=train_X[common]
eval_X=eval_X[common]
test_X=test_X[common]
print(train_X.shape)
print(train_y.shape)
print(eval_X.shape)
print(eval_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# ['d2_length', 'mut_pos', 'free_energy', 'u2_length_hairpin', 'u1_distance', 'u1_length_bulge', 'mut_next_struct:S', 'site_struct:S', 'site_length_bulge', 'd_all_stem_length', 'mut_nt:G', 'd2_3prm_cp_internal:G:U', 'u2_distance', 'mut_nt:A', 'site_5prm_cp_internal:U:G', 'd3_struct:S', 'd2_length_internal_es', 'mut_prev_struct:B', 'd3_distance', 'site_prev_nt:C', 'u3_5prm_cp_bulge:C:G', 'mut_ref_nt:C', 'u2_struct:H', 'mut_ref_nt:U', 'u3_struct:B', 'probability_active_conf', 'site_3prm_cp_internal:G:C', 'site_5prm_cp_internal:C:G', 'mut_next_struct:B', 'u1_3prm_cp_bulge:A:U', 'mut_prev_struct:I', 'u1_5prm_cp_bulge:C:G', 'd2_5prm_cp_internal:G:C', 'site_5prm_cp_bulge:A:U', 'mut_site_dist', 'sim_nor_score', 'u3_struct:S', 'd1_length_internal_ecs', 'site_struct:I', 'u3_3prm_cp_bulge:C:G', 'd3_length_internal_es', 'd2_struct:S', 'd3_struct:I', 'site_prev_struct:B', 'u2_3prm_cp_bulge:U:A', 'u2_length_bulge', 'd1_length_internal_es', 'u2_3prm_cp_bulge:C:G', 'site_1_1:A:U', 'd3_length_internal_ecs', 'mut_struct:I', 'site_length_internal_es', 'site_next_nt:C', 'u_hairpin_length', 'u1_struct:B', 'site_3prm_cp_internal:A:U', 'mut_struct:B', 'd1_struct:S', 'mut_nt:U', 'u1_length_stem', 'site_next_struct:I', 'u3_struct:H', 'site_3prm_cp_bulge:G:C', 'site_length', 'u3_length_bulge', 'd1_struct:I', 'site_5prm_cp_bulge:C:G', 'd1_length_stem', 'num_mutations', 'site_length_stem', 'u3_distance', 'd2_length_stem', 'mut_next_struct:I', 'mut_nt:C', 'u3_length', 'u1_length', 'mut_struct:S', 'u3_length_stem', 'u2_struct:S', 'u2_5prm_cp_bulge:C:G', 'site_1_1:A:G', 'mut_ref_struct:S', 'u_count', 'd1_distance', 'site_struct:B', 'u_all_stem_length', 'u3_length_hairpin', 'mut_prev_struct:H', 'd2_5prm_cp_internal:U:A', 'mut_ref_struct:I', 'd2_length_internal_ecs', 'u2_length', 'd2_5prm_cp_internal:A:U', 'd_count', 'site_1_1:A:C', 'site_length_internal_ecs', 'd2_5prm_cp_internal:U:G', 'u2_struct:B', 'u2_length_stem', 'site_next_struct:S', 'site_prev_struct:S', 'all_stem_length', 'u1_struct:S', 'd3_length', 'd3_length_stem', 'd2_distance', 'd1_length', 'mut_prev_struct:S', 'd2_struct:I', 'site_5prm_cp_internal:G:C']
# (361, 110)
# (361,)
# (89, 110)
# (89,)
# (428, 110)
# (428,)

# %%
## format matrixes for xgboost 
import xgboost
dtrain=xgboost.DMatrix(train_X,train_y)
deval=xgboost.DMatrix(eval_X,eval_y)
dtest=xgboost.DMatrix(test_X,test_y)

# %%
## set model training parameters 
from __future__ import unicode_literals
param=dict() 
param['nthread'] = 20
#rmse -- root mean square error 
# mae -- mean absolute error 
# map -- mean average precision 
# auc -- area under ROC curve 
# aucpr -- area under precision recall curve 

#Note: the last metric in your 'eval_metric' list will get optimized 
param['eval_metric'] = ['aucpr','auc','mae','map','rmse']

# %%
evallist = [(deval, 'eval'), (dtrain, 'train')]

# %%
num_round = 1000
bst = xgboost.train(param, dtrain, num_round, evallist,early_stopping_rounds=10)
# Out:
# [0]	eval-aucpr:0.110257	eval-auc:0.731023	eval-mae:0.332575	eval-map:1	eval-rmse:0.334534	train-aucpr:0.130503	train-auc:0.703176	train-mae:0.324431	train-map:1	train-rmse:0.327242
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 10 rounds.
# [1]	eval-aucpr:0.105995	eval-auc:0.730742	eval-mae:0.2397	eval-map:1	eval-rmse:0.242467	train-aucpr:0.148744	train-auc:0.705913	train-mae:0.227808	train-map:1	train-rmse:0.230293
# [2]	eval-aucpr:0.102184	eval-auc:0.7295	eval-mae:0.173382	eval-map:1	eval-rmse:0.178507	train-aucpr:0.155213	train-auc:0.707898	train-mae:0.160187	train-map:1	train-rmse:0.162469
# [3]	eval-aucpr:0.099814	eval-auc:0.728575	eval-mae:0.127654	eval-map:1	eval-rmse:0.136193	train-aucpr:0.15777	train-auc:0.708384	train-mae:0.112656	train-map:1	train-rmse:0.115014
# [4]	eval-aucpr:0.104423	eval-auc:0.763624	eval-mae:0.096533	eval-map:1	eval-rmse:0.109201	train-aucpr:0.16367	train-auc:0.750949	train-mae:0.079787	train-map:1	train-rmse:0.082037
# [5]	eval-aucpr:0.108788	eval-auc:0.766408	eval-mae:0.074051	eval-map:1	eval-rmse:0.089888	train-aucpr:0.169216	train-auc:0.769268	train-mae:0.05649	train-map:1	train-rmse:0.058793
# [6]	eval-aucpr:0.108734	eval-auc:0.770011	eval-mae:0.05727	eval-map:1	eval-rmse:0.076506	train-aucpr:0.172047	train-auc:0.781279	train-mae:0.04037	train-map:1	train-rmse:0.042826
# [7]	eval-aucpr:0.109632	eval-auc:0.77264	eval-mae:0.045574	eval-map:1	eval-rmse:0.067863	train-aucpr:0.173571	train-auc:0.784895	train-mae:0.029126	train-map:1	train-rmse:0.031836
# [8]	eval-aucpr:0.109938	eval-auc:0.773757	eval-mae:0.038103	eval-map:1	eval-rmse:0.063053	train-aucpr:0.175178	train-auc:0.788709	train-mae:0.021354	train-map:1	train-rmse:0.024175
# [9]	eval-aucpr:0.109081	eval-auc:0.76666	eval-mae:0.032323	eval-map:1	eval-rmse:0.059759	train-aucpr:0.177076	train-auc:0.792286	train-mae:0.015688	train-map:1	train-rmse:0.018484
# [10]	eval-aucpr:0.109035	eval-auc:0.766922	eval-mae:0.028403	eval-map:1	eval-rmse:0.057782	train-aucpr:0.17751	train-auc:0.79366	train-mae:0.012063	train-map:1	train-rmse:0.014865
# [11]	eval-aucpr:0.109214	eval-auc:0.768406	eval-mae:0.026312	eval-map:1	eval-rmse:0.056301	train-aucpr:0.177705	train-auc:0.794289	train-mae:0.009848	train-map:1	train-rmse:0.012505
# [12]	eval-aucpr:0.109901	eval-auc:0.772579	eval-mae:0.024663	eval-map:1	eval-rmse:0.055381	train-aucpr:0.178074	train-auc:0.796152	train-mae:0.008374	train-map:1	train-rmse:0.010971
# [13]	eval-aucpr:0.110099	eval-auc:0.772808	eval-mae:0.023469	eval-map:1	eval-rmse:0.054358	train-aucpr:0.178256	train-auc:0.796964	train-mae:0.007454	train-map:1	train-rmse:0.010063
# [14]	eval-aucpr:0.110389	eval-auc:0.775682	eval-mae:0.022615	eval-map:1	eval-rmse:0.053908	train-aucpr:0.178526	train-auc:0.799619	train-mae:0.006608	train-map:1	train-rmse:0.009276
# [15]	eval-aucpr:0.113187	eval-auc:0.781195	eval-mae:0.021961	eval-map:1	eval-rmse:0.053664	train-aucpr:0.17859	train-auc:0.800761	train-mae:0.005931	train-map:1	train-rmse:0.00856
# [16]	eval-aucpr:0.113307	eval-auc:0.782157	eval-mae:0.021461	eval-map:1	eval-rmse:0.053212	train-aucpr:0.178706	train-auc:0.801067	train-mae:0.005543	train-map:1	train-rmse:0.008172
# [17]	eval-aucpr:0.113505	eval-auc:0.783049	eval-mae:0.020937	eval-map:1	eval-rmse:0.05274	train-aucpr:0.179217	train-auc:0.801533	train-mae:0.005191	train-map:1	train-rmse:0.007611
# [18]	eval-aucpr:0.113686	eval-auc:0.784635	eval-mae:0.020486	eval-map:1	eval-rmse:0.052595	train-aucpr:0.179419	train-auc:0.80267	train-mae:0.004659	train-map:1	train-rmse:0.007134
# [19]	eval-aucpr:0.114597	eval-auc:0.785581	eval-mae:0.020412	eval-map:1	eval-rmse:0.05299	train-aucpr:0.179709	train-auc:0.80298	train-mae:0.004403	train-map:1	train-rmse:0.006579
# [20]	eval-aucpr:0.114785	eval-auc:0.786322	eval-mae:0.020016	eval-map:1	eval-rmse:0.052707	train-aucpr:0.180041	train-auc:0.803574	train-mae:0.004067	train-map:1	train-rmse:0.006057
# [21]	eval-aucpr:0.115117	eval-auc:0.787998	eval-mae:0.019658	eval-map:1	eval-rmse:0.052376	train-aucpr:0.180154	train-auc:0.803976	train-mae:0.003823	train-map:1	train-rmse:0.005795
# [22]	eval-aucpr:0.115178	eval-auc:0.788739	eval-mae:0.019478	eval-map:1	eval-rmse:0.052604	train-aucpr:0.180307	train-auc:0.804324	train-mae:0.003593	train-map:1	train-rmse:0.005353
# [23]	eval-aucpr:0.11516	eval-auc:0.788283	eval-mae:0.019385	eval-map:1	eval-rmse:0.052339	train-aucpr:0.180355	train-auc:0.804422	train-mae:0.003451	train-map:1	train-rmse:0.005175
# [24]	eval-aucpr:0.115201	eval-auc:0.788604	eval-mae:0.019349	eval-map:1	eval-rmse:0.052262	train-aucpr:0.180381	train-auc:0.804719	train-mae:0.003298	train-map:1	train-rmse:0.004973
# [25]	eval-aucpr:0.115219	eval-auc:0.788846	eval-mae:0.01927	eval-map:1	eval-rmse:0.052295	train-aucpr:0.180486	train-auc:0.804989	train-mae:0.003063	train-map:1	train-rmse:0.004703
# [26]	eval-aucpr:0.115309	eval-auc:0.78936	eval-mae:0.019166	eval-map:1	eval-rmse:0.052294	train-aucpr:0.180499	train-auc:0.805067	train-mae:0.002969	train-map:1	train-rmse:0.004601
# [27]	eval-aucpr:0.115405	eval-auc:0.790037	eval-mae:0.019073	eval-map:1	eval-rmse:0.052234	train-aucpr:0.180556	train-auc:0.805287	train-mae:0.002795	train-map:1	train-rmse:0.004418
# [28]	eval-aucpr:0.11542	eval-auc:0.790112	eval-mae:0.019055	eval-map:1	eval-rmse:0.05223	train-aucpr:0.180581	train-auc:0.805376	train-mae:0.002718	train-map:1	train-rmse:0.00436
# [29]	eval-aucpr:0.115435	eval-auc:0.790224	eval-mae:0.018994	eval-map:1	eval-rmse:0.052232	train-aucpr:0.18061	train-auc:0.805414	train-mae:0.002619	train-map:1	train-rmse:0.004293
# [30]	eval-aucpr:0.115477	eval-auc:0.790283	eval-mae:0.018851	eval-map:1	eval-rmse:0.05231	train-aucpr:0.180648	train-auc:0.805518	train-mae:0.002478	train-map:1	train-rmse:0.003938
# [31]	eval-aucpr:0.115522	eval-auc:0.790519	eval-mae:0.018798	eval-map:1	eval-rmse:0.052113	train-aucpr:0.180657	train-auc:0.805598	train-mae:0.002356	train-map:1	train-rmse:0.003778
# [32]	eval-aucpr:0.115622	eval-auc:0.791133	eval-mae:0.018674	eval-map:1	eval-rmse:0.052057	train-aucpr:0.180679	train-auc:0.805662	train-mae:0.002239	train-map:1	train-rmse:0.003612
# [33]	eval-aucpr:0.115632	eval-auc:0.791284	eval-mae:0.018616	eval-map:1	eval-rmse:0.05204	train-aucpr:0.180689	train-auc:0.805742	train-mae:0.002177	train-map:1	train-rmse:0.003564
# [34]	eval-aucpr:0.115699	eval-auc:0.791891	eval-mae:0.018531	eval-map:1	eval-rmse:0.051955	train-aucpr:0.180698	train-auc:0.805815	train-mae:0.002053	train-map:1	train-rmse:0.003443
# [35]	eval-aucpr:0.115719	eval-auc:0.792673	eval-mae:0.018676	eval-map:1	eval-rmse:0.052392	train-aucpr:0.180734	train-auc:0.805869	train-mae:0.001921	train-map:1	train-rmse:0.003189
# [36]	eval-aucpr:0.11574	eval-auc:0.792839	eval-mae:0.018616	eval-map:1	eval-rmse:0.052387	train-aucpr:0.180757	train-auc:0.805987	train-mae:0.001795	train-map:1	train-rmse:0.003035
# [37]	eval-aucpr:0.115748	eval-auc:0.792915	eval-mae:0.018649	eval-map:1	eval-rmse:0.052392	train-aucpr:0.180794	train-auc:0.80605	train-mae:0.001676	train-map:1	train-rmse:0.002752
# [38]	eval-aucpr:0.115777	eval-auc:0.793287	eval-mae:0.018554	eval-map:1	eval-rmse:0.052344	train-aucpr:0.180817	train-auc:0.806091	train-mae:0.001615	train-map:1	train-rmse:0.002649
# [39]	eval-aucpr:0.115744	eval-auc:0.793217	eval-mae:0.018555	eval-map:1	eval-rmse:0.052333	train-aucpr:0.180824	train-auc:0.806111	train-mae:0.001528	train-map:1	train-rmse:0.002502
# [40]	eval-aucpr:0.11585	eval-auc:0.793556	eval-mae:0.018576	eval-map:1	eval-rmse:0.052503	train-aucpr:0.180844	train-auc:0.806161	train-mae:0.001427	train-map:1	train-rmse:0.002286
# [41]	eval-aucpr:0.115845	eval-auc:0.793484	eval-mae:0.018537	eval-map:1	eval-rmse:0.052488	train-aucpr:0.180844	train-auc:0.806168	train-mae:0.001412	train-map:1	train-rmse:0.00227
# [42]	eval-aucpr:0.115847	eval-auc:0.793546	eval-mae:0.018523	eval-map:1	eval-rmse:0.052506	train-aucpr:0.180879	train-auc:0.806185	train-mae:0.001351	train-map:1	train-rmse:0.002119
# [43]	eval-aucpr:0.115848	eval-auc:0.793525	eval-mae:0.018507	eval-map:1	eval-rmse:0.052506	train-aucpr:0.180883	train-auc:0.806217	train-mae:0.001332	train-map:1	train-rmse:0.002099
# [44]	eval-aucpr:0.115853	eval-auc:0.793548	eval-mae:0.0185	eval-map:1	eval-rmse:0.052511	train-aucpr:0.180887	train-auc:0.806237	train-mae:0.001301	train-map:1	train-rmse:0.002072
# [45]	eval-aucpr:0.115854	eval-auc:0.793542	eval-mae:0.018513	eval-map:1	eval-rmse:0.052514	train-aucpr:0.181064	train-auc:0.80627	train-mae:0.001221	train-map:1	train-rmse:0.001874
# [46]	eval-aucpr:0.115862	eval-auc:0.793571	eval-mae:0.01851	eval-map:1	eval-rmse:0.052518	train-aucpr:0.181065	train-auc:0.806285	train-mae:0.001194	train-map:1	train-rmse:0.001851
# [47]	eval-aucpr:0.11585	eval-auc:0.793522	eval-mae:0.018506	eval-map:1	eval-rmse:0.052507	train-aucpr:0.181068	train-auc:0.806302	train-mae:0.00114	train-map:1	train-rmse:0.001742
# [48]	eval-aucpr:0.115851	eval-auc:0.793414	eval-mae:0.018958	eval-map:1	eval-rmse:0.052589	train-aucpr:0.181213	train-auc:0.806341	train-mae:0.001052	train-map:1	train-rmse:0.001584
# [49]	eval-aucpr:0.115859	eval-auc:0.793491	eval-mae:0.018965	eval-map:1	eval-rmse:0.05261	train-aucpr:0.181215	train-auc:0.806346	train-mae:0.001017	train-map:1	train-rmse:0.001517
# [50]	eval-aucpr:0.115864	eval-auc:0.793597	eval-mae:0.018957	eval-map:1	eval-rmse:0.052613	train-aucpr:0.181215	train-auc:0.806349	train-mae:0.001002	train-map:1	train-rmse:0.0015
# [51]	eval-aucpr:0.115861	eval-auc:0.793552	eval-mae:0.018943	eval-map:1	eval-rmse:0.05262	train-aucpr:0.181221	train-auc:0.806374	train-mae:0.000938	train-map:1	train-rmse:0.001412
# [52]	eval-aucpr:0.115849	eval-auc:0.793461	eval-mae:0.018972	eval-map:1	eval-rmse:0.05264	train-aucpr:0.181251	train-auc:0.80641	train-mae:0.00088	train-map:1	train-rmse:0.001305
# [53]	eval-aucpr:0.115854	eval-auc:0.793491	eval-mae:0.018947	eval-map:1	eval-rmse:0.052633	train-aucpr:0.181254	train-auc:0.806426	train-mae:0.000832	train-map:1	train-rmse:0.001244
# [54]	eval-aucpr:0.115846	eval-auc:0.793493	eval-mae:0.018954	eval-map:1	eval-rmse:0.052654	train-aucpr:0.181254	train-auc:0.806433	train-mae:0.000814	train-map:1	train-rmse:0.001222
# [55]	eval-aucpr:0.115846	eval-auc:0.793493	eval-mae:0.018953	eval-map:1	eval-rmse:0.052654	train-aucpr:0.181254	train-auc:0.806433	train-mae:0.000814	train-map:1	train-rmse:0.001222
# [56]	eval-aucpr:0.115846	eval-auc:0.793493	eval-mae:0.018953	eval-map:1	eval-rmse:0.052654	train-aucpr:0.181254	train-auc:0.806433	train-mae:0.000814	train-map:1	train-rmse:0.001222
# [57]	eval-aucpr:0.115846	eval-auc:0.793493	eval-mae:0.018953	eval-map:1	eval-rmse:0.052654	train-aucpr:0.181254	train-auc:0.806433	train-mae:0.000814	train-map:1	train-rmse:0.001222
# [58]	eval-aucpr:0.115846	eval-auc:0.793493	eval-mae:0.018953	eval-map:1	eval-rmse:0.052654	train-aucpr:0.181254	train-auc:0.806433	train-mae:0.000814	train-map:1	train-rmse:0.001222
# [59]	eval-aucpr:0.115846	eval-auc:0.793493	eval-mae:0.018953	eval-map:1	eval-rmse:0.052654	train-aucpr:0.181254	train-auc:0.806433	train-mae:0.000814	train-map:1	train-rmse:0.001222
# [60]	eval-aucpr:0.115846	eval-auc:0.793493	eval-mae:0.018953	eval-map:1	eval-rmse:0.052654	train-aucpr:0.181254	train-auc:0.806433	train-mae:0.000814	train-map:1	train-rmse:0.001222
# [61]	eval-aucpr:0.115846	eval-auc:0.793493	eval-mae:0.018953	eval-map:1	eval-rmse:0.052653	train-aucpr:0.181254	train-auc:0.806433	train-mae:0.000814	train-map:1	train-rmse:0.001222
# [62]	eval-aucpr:0.115846	eval-auc:0.793493	eval-mae:0.018953	eval-map:1	eval-rmse:0.052653	train-aucpr:0.181254	train-auc:0.806433	train-mae:0.000814	train-map:1	train-rmse:0.001222
# [63]	eval-aucpr:0.115846	eval-auc:0.793493	eval-mae:0.018953	eval-map:1	eval-rmse:0.052653	train-aucpr:0.181254	train-auc:0.806433	train-mae:0.000814	train-map:1	train-rmse:0.001222
# [64]	eval-aucpr:0.115846	eval-auc:0.793493	eval-mae:0.018953	eval-map:1	eval-rmse:0.052653	train-aucpr:0.181254	train-auc:0.806433	train-mae:0.000814	train-map:1	train-rmse:0.001222
# Stopping. Best iteration:
# [54]	eval-aucpr:0.115846	eval-auc:0.793493	eval-mae:0.018954	eval-map:1	eval-rmse:0.052654	train-aucpr:0.181254	train-auc:0.806433	train-mae:0.000814	train-map:1	train-rmse:0.001222

# %%
## get model predictions on the test, training, and eval splits 
test_pred = bst.predict(dtest)
train_pred=bst.predict(dtrain)
eval_pred=bst.predict(deval)

# %%
## Get performance metrics on full dataset 
from helpers import * 
print_aggregate_peformance_metrics(train_y,train_pred,
                                   eval_y,eval_pred,
                                   test_y,test_pred,
                                   positive_thresh=0.2)
# Out:
# Train
# 	Spearman corr : SpearmanrResult(correlation=0.9970276163868073, pvalue=0.0)
# 	Pearson corr : (0.9997626397304094, 0.0)
# 	MAE : 0.000813949352162864
# 	MAPE : 0.026630324311601197
# 	RMSE : 0.0012216824049627417
# 	auPRC : 0.9999999999999998
# 	auROC : 1.0
# Eval
# 	Spearman corr : SpearmanrResult(correlation=0.9399414477148964, pvalue=2.2080144983717112e-42)
# 	Pearson corr : (0.7831256126165698, 1.217725312861608e-19)
# 	MAE : 0.01895264183121911
# 	MAPE : 0.29326985495093344
# 	RMSE : 0.05265345763402968
# 	auPRC : 0.41875
# 	auROC : 0.9558823529411765
# Test
# 	Spearman corr : SpearmanrResult(correlation=0.4588481998977968, pvalue=1.1290367810671124e-23)
# 	Pearson corr : (0.5767995823701041, 2.5389478123124266e-39)
# 	MAE : 0.1764969421786683
# 	MAPE : 0.836125592107497
# 	RMSE : 0.24586366040452673
# 	auPRC : 0.7692801227243179
# 	auROC : 0.7472853990518014

# %%
## Correlation values 
from scipy.stats import spearmanr,pearsonr
spearman_train=spearmanr(train_y,train_pred)
spearman_eval=spearmanr(eval_y,eval_pred)
spearman_test=spearmanr(test_y,test_pred)

pearson_train=pearsonr(train_y,train_pred)
pearson_eval=pearsonr(eval_y,eval_pred)
pearson_test=pearsonr(test_y,test_pred)

print("Spearman correlation:")
print("Train:"+str(spearman_train))
print("Eval:"+str(spearman_eval))
print("Test:"+str(spearman_test))
print("\n")
print("Pearson correlation:")
print("Train:"+str(pearson_train))
print("Eval:"+str(pearson_eval))
print("Test:"+str(pearson_test))
# Out:
# Spearman correlation:
# Train:SpearmanrResult(correlation=0.9970276163868073, pvalue=0.0)
# Eval:SpearmanrResult(correlation=0.9399414477148964, pvalue=2.2080144983717112e-42)
# Test:SpearmanrResult(correlation=0.4588481998977968, pvalue=1.1290367810671124e-23)
#
#
# Pearson correlation:
# Train:(0.9997626397304094, 0.0)
# Eval:(0.7831256126165698, 1.217725312861608e-19)
# Test:(0.5767995823701041, 2.5389478123124266e-39)

# %%
## MAE
from sklearn.metrics import mean_absolute_error
mae_train=mean_absolute_error(train_y,train_pred)
print("MAE Train:"+str(mae_train))

mae_eval=mean_absolute_error(eval_y,eval_pred)
print("MAE Eval:"+str(mae_eval))

mae_test=mean_absolute_error(test_y,test_pred)
print("MAE Test:"+str(mae_test))
# Out:
# MAE Train:0.000813949352162864
# MAE Eval:0.01895264183121911
# MAE Test:0.1764969421786683

# %%
## MAPE
pseudocount=0.01
mape_train=np.mean(np.abs((train_y - train_pred) /(pseudocount+train_y))) * 100
print("MAPE Train:"+str(mape_train)+"%")

mape_eval=np.mean(np.abs((eval_y - eval_pred) /(pseudocount+eval_y))) * 100
print("MAPE Eval:"+str(mape_eval)+"%")

mape_test=np.mean(np.abs((test_y - test_pred) /(pseudocount+test_y))) * 100
print("MAPE Test:"+str(mape_test)+"%")
# Out:
# MAPE Train:2.6630324311601195%
# MAPE Eval:29.326985495093343%
# MAPE Test:83.61255921074971%

# %%
## RMSE
from sklearn.metrics import mean_squared_error
import math 
rmse_train=math.sqrt(mean_squared_error(train_y,train_pred))
print("RMSE Train:"+str(rmse_train))

rmse_eval=math.sqrt(mean_squared_error(eval_y,eval_pred))
print("RMSE Eval:"+str(rmse_eval))

rmse_test=math.sqrt(mean_squared_error(test_y,test_pred))
print("RMSE Test:"+str(rmse_test))
# Out:
# RMSE Train:0.0012216824049627417
# RMSE Eval:0.05265345763402968
# RMSE Test:0.24586366040452673

# %%
## PRC 
## PRC only valid for binary outcomes. 
## Editing levels < 0.5 are labeled as "0". 
## Editing levels >= 0.5 are labeled as "1". 

from sklearn.metrics import auc, precision_recall_curve

precision_train,recall_train,prc_thresholds_train=precision_recall_curve(train_y>=0.2,train_pred)
precision_eval,recall_eval,prc_thresholds_eval=precision_recall_curve(eval_y>=0.2,eval_pred)
precision_test,recall_test,prc_thresholds_test=precision_recall_curve(test_y>=0.5,test_pred)

auprc_train=auc(recall_train,precision_train)
auprc_eval=auc(recall_eval,precision_eval)
auprc_test=auc(recall_test,precision_test)

plt.plot(recall_train,precision_train,'r',label="Train:"+str(round(auprc_train,2)))
plt.plot(recall_eval,precision_eval,'g',label="Eval:"+str(round(auprc_eval,2)))
plt.plot(recall_test,precision_test,'b',label="Test:"+str(round(auprc_test,2)))
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("PRC")
plt.legend()

# %%
## ROC
from sklearn.metrics import roc_curve, roc_auc_score
fpr_train,tpr_train,roc_thresholds_train=roc_curve(train_y>=0.2,train_pred)
fpr_eval,tpr_eval,roc_thresholds_eval=roc_curve(eval_y>=0.2,eval_pred)
fpr_test,tpr_test,roc_thresholds_test=roc_curve(test_y>=0.5,test_pred)

auroc_train=roc_auc_score(train_y>=0.2,train_pred)
auroc_eval=roc_auc_score(eval_y>=0.2,eval_pred)
auroc_test=roc_auc_score(test_y>=0.5,test_pred)

plt.plot(fpr_train,tpr_train,'r',label="Train:"+str(round(auroc_train,2)))
plt.plot(fpr_eval,tpr_eval,'g',label="Eval:"+str(round(auroc_eval,2)))
plt.plot(fpr_test,tpr_test,'b',label="Test:"+str(round(auroc_test,2)))
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC")
plt.legend()

# %%
#plot the test set predictions 
matplotlib.rcParams['figure.figsize'] = [20, 8]
plt.subplot(1,3,1)
plt.plot(list(train_y),list(train_pred),'o')
plt.xlabel("Observed train set editing level, AJUBA Comp")
plt.ylabel("Predicted train set editing level, AJUBA Comp")
plt.subplot(1,3,2)
plt.plot(list(eval_y),list(eval_pred),'o')
plt.xlabel("Observed eval set editing level, AJUBA Comp")
plt.ylabel("Predicted eval set editing level, AJUBA Comp")
plt.subplot(1,3,3)
plt.plot(list(test_y),list(test_pred),'o')
plt.xlabel("Observed test set editing level, NEIL1 Comp")
plt.ylabel("Predicted test set editing level, NEIL1 Comp")

plt.show()

# %%
#calculate R^2, which is representative of variance explained 
# https://datascienceplus.com/extreme-gradient-boosting-with-r/
# https://arxiv.org/pdf/1706.06060.pdf

residuals = test_y - test_pred

y_test_mean = np.mean(test_pred)
print(y_test_mean)
#calculate total sum of squares 
tss=sum((test_y-y_test_mean)*(test_y-y_test_mean))
print(tss)
# Calculate residual sum of squares
rss =  sum(residuals*residuals)
print(rss)
# Calculate R-squared
rsq  =  1 - (rss/tss)
print('The R-square of the test data is ', round(rsq,3), '\n')
# Out:
# 0.11378396
# 33.723208921471105
# 25.87214610921532
# The R-square of the test data is  0.233

# %% [markdown]
# ## Train AJUBA, predict TTYH2

# %%
test_split=ttyh2_comp

# %%
train_split.reset_index(inplace=True, drop=True) 
eval_split.reset_index(inplace=True,drop=True)
test_split.reset_index(inplace=True,drop=True)

# %%
#Remove any non-varying features 
train_novar=get_singleval_features(train_split)
eval_novar=get_singleval_features(eval_split)
test_novar=get_singleval_features(test_split)
uniform_features_to_drop=list(set(train_novar+eval_novar+test_novar))

# %%
#Remove any null features 
train_null=get_all_null_features(train_split)
eval_null=get_all_null_features(eval_split)
test_null=get_all_null_features(test_split)
null_features_to_drop=list(set(train_null+eval_null+test_null))

# %%
to_drop=list(set(uniform_features_to_drop+null_features_to_drop))
print("\n".join(to_drop))
# Out:
# u3_3prm_cp_internal
# d3_length_hairpin
# d2_exist
# u3_5prm_cp_internal
# site_5prm_cp_hairpin
# u_hairpin_length
# u2_exist
# u2_3prm_cp_internal
# d1_exist
# u1_5prm_cp_internal
# u2_5prm_cp_internal
# d1_5prm_cp_hairpin
# d3_5prm_cp_hairpin
# u1_length_internal_ecs
# d2_5prm_cp_hairpin
# site_length_hairpin
# u1_3prm_cp_internal
# d2_length_hairpin
# u3_length_internal_es
# u2_length_internal_ecs
# u3_length_internal_ecs
# u1_exist
# d1_length_hairpin
# u2_length_internal_es
# u1_length_internal_es

# %%
#remove teh features that don't change across isoforms , or are null for all isoforms
for cur_to_drop in to_drop: 
    try:
        train_split=train_split.drop(cur_to_drop,axis=1)
    except: 
        pass
    try:
        eval_split=eval_split.drop(cur_to_drop,axis=1)
    except: 
        pass 
    try:
        test_split=test_split.drop(to_drop,axis=1)
    except: 
        pass

# %%
train_y=train_split['editing_value']
train_X=train_split.drop(['editing_value'],axis=1)
eval_y=eval_split['editing_value']
eval_X=eval_split.drop(['editing_value'],axis=1)
test_y=test_split['editing_value']
test_X=test_split.drop(['editing_value'],axis=1)

# %%
print(train_X.shape)
print(train_y.shape)
print(eval_X.shape)
print(eval_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (361, 122)
# (361,)
# (89, 122)
# (89,)
# (601, 190)
# (601,)

# %%
train_cols=set(train_X.columns)
eval_cols=set(eval_X.columns)
test_cols=set(test_X.columns)

# %%
common=train_cols.intersection(eval_cols)
common=list(common.intersection(test_cols))
print(common)
train_X=train_X[common]
eval_X=eval_X[common]
test_X=test_X[common]
print(train_X.shape)
print(train_y.shape)
print(eval_X.shape)
print(eval_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# ['site_3prm_cp_bulge:G:U', 'd2_length', 'mut_pos', 'free_energy', 'u2_length_hairpin', 'u1_distance', 'u1_length_bulge', 'mut_next_struct:S', 'site_struct:S', 'site_length_bulge', 'd_all_stem_length', 'mut_nt:G', 'u2_distance', 'mut_nt:A', 'site_5prm_cp_internal:U:G', 'd3_struct:S', 'd2_length_internal_es', 'mut_prev_struct:B', 'd3_distance', 'site_prev_nt:C', 'u3_5prm_cp_bulge:C:G', 'mut_ref_nt:C', 'site_next_nt:G', 'u2_struct:H', 'mut_ref_nt:U', 'u3_struct:B', 'probability_active_conf', 'site_3prm_cp_internal:G:C', 'site_5prm_cp_internal:C:G', 'mut_next_struct:B', 'u1_3prm_cp_bulge:A:U', 'site_prev_nt:G', 'mut_prev_struct:I', 'd2_5prm_cp_internal:G:C', 'mut_site_dist', 'sim_nor_score', 'u3_struct:S', 'd1_length_internal_ecs', 'site_struct:I', 'u3_3prm_cp_bulge:C:G', 'd3_length_internal_es', 'd2_struct:S', 'd3_struct:I', 'site_prev_struct:B', 'u2_length_bulge', 'd1_length_internal_es', 'u2_3prm_cp_bulge:C:G', 'u3_5prm_cp_bulge:G:C', 'site_1_1:A:U', 'd3_length_internal_ecs', 'mut_struct:I', 'site_length_internal_es', 'site_next_nt:C', 'u1_struct:B', 'site_3prm_cp_internal:A:U', 'mut_struct:B', 'd1_struct:S', 'mut_nt:U', 'u2_5prm_cp_hairpin:A:U', 'u1_length_stem', 'site_next_struct:I', 'u3_struct:H', 'site_3prm_cp_bulge:G:C', 'site_length', 'u3_length_bulge', 'd1_struct:I', 'site_prev_struct:I', 'site_5prm_cp_bulge:C:G', 'd1_length_stem', 'num_mutations', 'site_length_stem', 'u3_distance', 'd2_length_stem', 'mut_next_struct:I', 'mut_nt:C', 'u3_length', 'u1_length', 'mut_struct:S', 'u3_length_stem', 'u2_struct:S', 'u2_5prm_cp_bulge:C:G', 'site_1_1:A:G', 'mut_ref_struct:S', 'u_count', 'd1_5prm_cp_internal:G:C', 'site_struct:B', 'd1_distance', 'u_all_stem_length', 'u3_5prm_cp_hairpin:A:U', 'u3_length_hairpin', 'mut_prev_struct:H', 'mut_ref_struct:I', 'd2_length_internal_ecs', 'u2_length', 'd2_5prm_cp_internal:A:U', 'd_count', 'site_1_1:A:C', 'site_length_internal_ecs', 'd2_5prm_cp_internal:U:G', 'u2_struct:B', 'u2_length_stem', 'site_5prm_cp_bulge:G:C', 'site_next_struct:S', 'site_prev_struct:S', 'all_stem_length', 'u1_struct:S', 'd3_length', 'd3_length_stem', 'd2_distance', 'd1_length', 'mut_prev_struct:S', 'd2_struct:I', 'site_5prm_cp_internal:G:C']
# (361, 113)
# (361,)
# (89, 113)
# (89,)
# (601, 113)
# (601,)

# %%
## format matrixes for xgboost 
import xgboost
dtrain=xgboost.DMatrix(train_X,train_y)
deval=xgboost.DMatrix(eval_X,eval_y)
dtest=xgboost.DMatrix(test_X,test_y)

# %%
## set model training parameters 
from __future__ import unicode_literals
param=dict() 
param['nthread'] = 20
#rmse -- root mean square error 
# mae -- mean absolute error 
# map -- mean average precision 
# auc -- area under ROC curve 
# aucpr -- area under precision recall curve 

#Note: the last metric in your 'eval_metric' list will get optimized 
param['eval_metric'] = ['aucpr','auc','mae','map','rmse']

# %%
evallist = [(deval, 'eval'), (dtrain, 'train')]

# %%
num_round = 1000
bst = xgboost.train(param, dtrain, num_round, evallist,early_stopping_rounds=10)
# Out:
# [0]	eval-aucpr:0.110257	eval-auc:0.731023	eval-mae:0.332575	eval-map:1	eval-rmse:0.334534	train-aucpr:0.130503	train-auc:0.703176	train-mae:0.324431	train-map:1	train-rmse:0.327242
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 10 rounds.
# [1]	eval-aucpr:0.105995	eval-auc:0.730742	eval-mae:0.2397	eval-map:1	eval-rmse:0.242467	train-aucpr:0.148744	train-auc:0.705913	train-mae:0.227808	train-map:1	train-rmse:0.230293
# [2]	eval-aucpr:0.102184	eval-auc:0.7295	eval-mae:0.173382	eval-map:1	eval-rmse:0.178507	train-aucpr:0.155213	train-auc:0.707898	train-mae:0.160187	train-map:1	train-rmse:0.162469
# [3]	eval-aucpr:0.099814	eval-auc:0.728575	eval-mae:0.127654	eval-map:1	eval-rmse:0.136193	train-aucpr:0.15777	train-auc:0.708384	train-mae:0.112656	train-map:1	train-rmse:0.115014
# [4]	eval-aucpr:0.104423	eval-auc:0.763624	eval-mae:0.096533	eval-map:1	eval-rmse:0.109201	train-aucpr:0.16367	train-auc:0.750949	train-mae:0.079787	train-map:1	train-rmse:0.082037
# [5]	eval-aucpr:0.108788	eval-auc:0.766408	eval-mae:0.074051	eval-map:1	eval-rmse:0.089888	train-aucpr:0.169216	train-auc:0.769268	train-mae:0.05649	train-map:1	train-rmse:0.058793
# [6]	eval-aucpr:0.108734	eval-auc:0.770011	eval-mae:0.057285	eval-map:1	eval-rmse:0.076515	train-aucpr:0.171974	train-auc:0.781253	train-mae:0.040331	train-map:1	train-rmse:0.042818
# [7]	eval-aucpr:0.109632	eval-auc:0.77264	eval-mae:0.0456	eval-map:1	eval-rmse:0.067882	train-aucpr:0.173567	train-auc:0.784877	train-mae:0.029091	train-map:1	train-rmse:0.031839
# [8]	eval-aucpr:0.10986	eval-auc:0.773341	eval-mae:0.038122	eval-map:1	eval-rmse:0.06307	train-aucpr:0.175056	train-auc:0.788564	train-mae:0.021349	train-map:1	train-rmse:0.024176
# [9]	eval-aucpr:0.107467	eval-auc:0.765408	eval-mae:0.032407	eval-map:1	eval-rmse:0.059805	train-aucpr:0.177029	train-auc:0.792175	train-mae:0.015718	train-map:1	train-rmse:0.018506
# [10]	eval-aucpr:0.107823	eval-auc:0.766813	eval-mae:0.028465	eval-map:1	eval-rmse:0.057944	train-aucpr:0.177408	train-auc:0.793595	train-mae:0.012101	train-map:1	train-rmse:0.014879
# [11]	eval-aucpr:0.107902	eval-auc:0.768631	eval-mae:0.026355	eval-map:1	eval-rmse:0.05646	train-aucpr:0.177639	train-auc:0.794298	train-mae:0.00989	train-map:1	train-rmse:0.012527
# [12]	eval-aucpr:0.109894	eval-auc:0.772687	eval-mae:0.024591	eval-map:1	eval-rmse:0.055458	train-aucpr:0.178083	train-auc:0.796973	train-mae:0.008312	train-map:1	train-rmse:0.010919
# [13]	eval-aucpr:0.110375	eval-auc:0.775684	eval-mae:0.02336	eval-map:1	eval-rmse:0.054195	train-aucpr:0.178612	train-auc:0.798445	train-mae:0.00712	train-map:1	train-rmse:0.009603
# [14]	eval-aucpr:0.113059	eval-auc:0.776039	eval-mae:0.022666	eval-map:1	eval-rmse:0.053395	train-aucpr:0.178855	train-auc:0.799765	train-mae:0.006324	train-map:1	train-rmse:0.008717
# [15]	eval-aucpr:0.113366	eval-auc:0.777439	eval-mae:0.02216	eval-map:1	eval-rmse:0.053031	train-aucpr:0.178983	train-auc:0.800299	train-mae:0.005882	train-map:1	train-rmse:0.008277
# [16]	eval-aucpr:0.113904	eval-auc:0.78017	eval-mae:0.021651	eval-map:1	eval-rmse:0.052608	train-aucpr:0.179063	train-auc:0.801008	train-mae:0.005512	train-map:1	train-rmse:0.007962
# [17]	eval-aucpr:0.114159	eval-auc:0.782108	eval-mae:0.021062	eval-map:1	eval-rmse:0.052166	train-aucpr:0.179211	train-auc:0.801701	train-mae:0.005119	train-map:1	train-rmse:0.007504
# [18]	eval-aucpr:0.114642	eval-auc:0.784593	eval-mae:0.020544	eval-map:1	eval-rmse:0.051864	train-aucpr:0.17941	train-auc:0.802838	train-mae:0.004649	train-map:1	train-rmse:0.007071
# [19]	eval-aucpr:0.114866	eval-auc:0.785713	eval-mae:0.020247	eval-map:1	eval-rmse:0.051913	train-aucpr:0.179799	train-auc:0.802947	train-mae:0.004432	train-map:1	train-rmse:0.006632
# [20]	eval-aucpr:0.114841	eval-auc:0.785711	eval-mae:0.019963	eval-map:1	eval-rmse:0.05159	train-aucpr:0.179911	train-auc:0.803438	train-mae:0.004127	train-map:1	train-rmse:0.006279
# [21]	eval-aucpr:0.114884	eval-auc:0.786309	eval-mae:0.01987	eval-map:1	eval-rmse:0.051465	train-aucpr:0.179824	train-auc:0.80389	train-mae:0.003826	train-map:1	train-rmse:0.005975
# [22]	eval-aucpr:0.114953	eval-auc:0.787284	eval-mae:0.01958	eval-map:1	eval-rmse:0.051279	train-aucpr:0.180212	train-auc:0.804191	train-mae:0.003592	train-map:1	train-rmse:0.005522
# [23]	eval-aucpr:0.114967	eval-auc:0.787329	eval-mae:0.019445	eval-map:1	eval-rmse:0.051155	train-aucpr:0.180257	train-auc:0.804416	train-mae:0.003453	train-map:1	train-rmse:0.005366
# [24]	eval-aucpr:0.115009	eval-auc:0.787764	eval-mae:0.019323	eval-map:1	eval-rmse:0.051102	train-aucpr:0.180317	train-auc:0.804567	train-mae:0.003341	train-map:1	train-rmse:0.005181
# [25]	eval-aucpr:0.114997	eval-auc:0.787769	eval-mae:0.019161	eval-map:1	eval-rmse:0.050971	train-aucpr:0.180376	train-auc:0.804691	train-mae:0.003213	train-map:1	train-rmse:0.004835
# [26]	eval-aucpr:0.115056	eval-auc:0.788121	eval-mae:0.0191	eval-map:1	eval-rmse:0.050945	train-aucpr:0.18041	train-auc:0.804968	train-mae:0.003056	train-map:1	train-rmse:0.004671
# [27]	eval-aucpr:0.115164	eval-auc:0.789151	eval-mae:0.018874	eval-map:1	eval-rmse:0.050846	train-aucpr:0.180475	train-auc:0.805202	train-mae:0.002884	train-map:1	train-rmse:0.004506
# [28]	eval-aucpr:0.115157	eval-auc:0.78923	eval-mae:0.018747	eval-map:1	eval-rmse:0.050847	train-aucpr:0.180508	train-auc:0.805365	train-mae:0.002753	train-map:1	train-rmse:0.004335
# [29]	eval-aucpr:0.115185	eval-auc:0.789667	eval-mae:0.018699	eval-map:1	eval-rmse:0.050747	train-aucpr:0.180519	train-auc:0.805468	train-mae:0.002645	train-map:1	train-rmse:0.00422
# [30]	eval-aucpr:0.115178	eval-auc:0.789684	eval-mae:0.018668	eval-map:1	eval-rmse:0.050764	train-aucpr:0.180541	train-auc:0.805528	train-mae:0.002551	train-map:1	train-rmse:0.004138
# [31]	eval-aucpr:0.115235	eval-auc:0.789941	eval-mae:0.018536	eval-map:1	eval-rmse:0.050653	train-aucpr:0.180583	train-auc:0.805603	train-mae:0.002437	train-map:1	train-rmse:0.003822
# [32]	eval-aucpr:0.11527	eval-auc:0.790028	eval-mae:0.018493	eval-map:1	eval-rmse:0.050682	train-aucpr:0.180601	train-auc:0.805643	train-mae:0.002335	train-map:1	train-rmse:0.003527
# [33]	eval-aucpr:0.115267	eval-auc:0.79033	eval-mae:0.018464	eval-map:1	eval-rmse:0.050645	train-aucpr:0.180612	train-auc:0.80573	train-mae:0.00225	train-map:1	train-rmse:0.003444
# [34]	eval-aucpr:0.115495	eval-auc:0.790158	eval-mae:0.018491	eval-map:1	eval-rmse:0.050575	train-aucpr:0.180648	train-auc:0.805781	train-mae:0.00216	train-map:1	train-rmse:0.003229
# [35]	eval-aucpr:0.115556	eval-auc:0.790392	eval-mae:0.018404	eval-map:1	eval-rmse:0.050527	train-aucpr:0.180654	train-auc:0.805819	train-mae:0.002109	train-map:1	train-rmse:0.003178
# [36]	eval-aucpr:0.115534	eval-auc:0.790358	eval-mae:0.018372	eval-map:1	eval-rmse:0.050567	train-aucpr:0.180668	train-auc:0.805892	train-mae:0.002035	train-map:1	train-rmse:0.003113
# [37]	eval-aucpr:0.115543	eval-auc:0.790424	eval-mae:0.018355	eval-map:1	eval-rmse:0.050565	train-aucpr:0.180685	train-auc:0.805949	train-mae:0.001973	train-map:1	train-rmse:0.003055
# [38]	eval-aucpr:0.115561	eval-auc:0.790693	eval-mae:0.018265	eval-map:1	eval-rmse:0.050531	train-aucpr:0.180722	train-auc:0.805997	train-mae:0.001907	train-map:1	train-rmse:0.002978
# [39]	eval-aucpr:0.115562	eval-auc:0.79063	eval-mae:0.018274	eval-map:1	eval-rmse:0.050507	train-aucpr:0.180765	train-auc:0.806025	train-mae:0.001818	train-map:1	train-rmse:0.002749
# [40]	eval-aucpr:0.115657	eval-auc:0.790844	eval-mae:0.018211	eval-map:1	eval-rmse:0.050511	train-aucpr:0.180799	train-auc:0.806113	train-mae:0.001667	train-map:1	train-rmse:0.002583
# [41]	eval-aucpr:0.115668	eval-auc:0.790929	eval-mae:0.018209	eval-map:1	eval-rmse:0.050525	train-aucpr:0.180798	train-auc:0.806137	train-mae:0.001617	train-map:1	train-rmse:0.002524
# [42]	eval-aucpr:0.115608	eval-auc:0.791088	eval-mae:0.018114	eval-map:1	eval-rmse:0.050496	train-aucpr:0.180847	train-auc:0.806167	train-mae:0.001557	train-map:1	train-rmse:0.002354
# [43]	eval-aucpr:0.115754	eval-auc:0.792082	eval-mae:0.018031	eval-map:1	eval-rmse:0.050565	train-aucpr:0.180921	train-auc:0.806235	train-mae:0.001428	train-map:1	train-rmse:0.002161
# [44]	eval-aucpr:0.115815	eval-auc:0.792097	eval-mae:0.018028	eval-map:1	eval-rmse:0.050577	train-aucpr:0.181138	train-auc:0.806237	train-mae:0.001405	train-map:1	train-rmse:0.00213
# [45]	eval-aucpr:0.115703	eval-auc:0.792204	eval-mae:0.018048	eval-map:1	eval-rmse:0.050619	train-aucpr:0.181256	train-auc:0.806284	train-mae:0.001314	train-map:1	train-rmse:0.002001
# [46]	eval-aucpr:0.115717	eval-auc:0.792238	eval-mae:0.018074	eval-map:1	eval-rmse:0.050764	train-aucpr:0.181277	train-auc:0.806309	train-mae:0.001252	train-map:1	train-rmse:0.00187
# [47]	eval-aucpr:0.115815	eval-auc:0.792325	eval-mae:0.018046	eval-map:1	eval-rmse:0.050722	train-aucpr:0.181288	train-auc:0.806344	train-mae:0.00116	train-map:1	train-rmse:0.0017
# [48]	eval-aucpr:0.115815	eval-auc:0.792316	eval-mae:0.01804	eval-map:1	eval-rmse:0.050673	train-aucpr:0.18129	train-auc:0.806351	train-mae:0.00112	train-map:1	train-rmse:0.001636
# [49]	eval-aucpr:0.115846	eval-auc:0.792643	eval-mae:0.018053	eval-map:1	eval-rmse:0.050805	train-aucpr:0.181295	train-auc:0.806378	train-mae:0.001058	train-map:1	train-rmse:0.001535
# [50]	eval-aucpr:0.11586	eval-auc:0.792792	eval-mae:0.018032	eval-map:1	eval-rmse:0.050807	train-aucpr:0.1813	train-auc:0.806398	train-mae:0.001004	train-map:1	train-rmse:0.001481
# [51]	eval-aucpr:0.115865	eval-auc:0.792822	eval-mae:0.018033	eval-map:1	eval-rmse:0.050805	train-aucpr:0.181303	train-auc:0.806414	train-mae:0.000973	train-map:1	train-rmse:0.001454
# [52]	eval-aucpr:0.11591	eval-auc:0.793087	eval-mae:0.018005	eval-map:1	eval-rmse:0.050706	train-aucpr:0.181306	train-auc:0.806425	train-mae:0.000932	train-map:1	train-rmse:0.001381
# [53]	eval-aucpr:0.115906	eval-auc:0.792994	eval-mae:0.017992	eval-map:1	eval-rmse:0.050671	train-aucpr:0.181309	train-auc:0.806437	train-mae:0.000882	train-map:1	train-rmse:0.001304
# [54]	eval-aucpr:0.115914	eval-auc:0.793059	eval-mae:0.017982	eval-map:1	eval-rmse:0.050635	train-aucpr:0.181309	train-auc:0.806436	train-mae:0.000859	train-map:1	train-rmse:0.001258
# [55]	eval-aucpr:0.115914	eval-auc:0.793059	eval-mae:0.017982	eval-map:1	eval-rmse:0.050635	train-aucpr:0.181309	train-auc:0.806436	train-mae:0.000859	train-map:1	train-rmse:0.001258
# [56]	eval-aucpr:0.115914	eval-auc:0.793059	eval-mae:0.017982	eval-map:1	eval-rmse:0.050635	train-aucpr:0.181309	train-auc:0.806436	train-mae:0.000859	train-map:1	train-rmse:0.001258
# [57]	eval-aucpr:0.115914	eval-auc:0.793059	eval-mae:0.017982	eval-map:1	eval-rmse:0.050634	train-aucpr:0.181309	train-auc:0.806436	train-mae:0.000859	train-map:1	train-rmse:0.001258
# [58]	eval-aucpr:0.115914	eval-auc:0.793059	eval-mae:0.017982	eval-map:1	eval-rmse:0.050634	train-aucpr:0.181309	train-auc:0.806436	train-mae:0.000859	train-map:1	train-rmse:0.001258
# [59]	eval-aucpr:0.115914	eval-auc:0.793059	eval-mae:0.017982	eval-map:1	eval-rmse:0.050634	train-aucpr:0.181309	train-auc:0.806436	train-mae:0.000858	train-map:1	train-rmse:0.001258
# [60]	eval-aucpr:0.115914	eval-auc:0.793059	eval-mae:0.017982	eval-map:1	eval-rmse:0.050634	train-aucpr:0.181309	train-auc:0.806436	train-mae:0.000858	train-map:1	train-rmse:0.001258
# [61]	eval-aucpr:0.115914	eval-auc:0.793059	eval-mae:0.017982	eval-map:1	eval-rmse:0.050634	train-aucpr:0.181309	train-auc:0.806436	train-mae:0.000858	train-map:1	train-rmse:0.001258
# [62]	eval-aucpr:0.115914	eval-auc:0.793059	eval-mae:0.017982	eval-map:1	eval-rmse:0.050634	train-aucpr:0.181309	train-auc:0.806436	train-mae:0.000858	train-map:1	train-rmse:0.001258
# [63]	eval-aucpr:0.115914	eval-auc:0.793059	eval-mae:0.017982	eval-map:1	eval-rmse:0.050634	train-aucpr:0.181309	train-auc:0.806436	train-mae:0.000858	train-map:1	train-rmse:0.001258
# [64]	eval-aucpr:0.115914	eval-auc:0.793059	eval-mae:0.017982	eval-map:1	eval-rmse:0.050634	train-aucpr:0.181309	train-auc:0.806436	train-mae:0.000858	train-map:1	train-rmse:0.001258
# Stopping. Best iteration:
# [54]	eval-aucpr:0.115914	eval-auc:0.793059	eval-mae:0.017982	eval-map:1	eval-rmse:0.050635	train-aucpr:0.181309	train-auc:0.806436	train-mae:0.000859	train-map:1	train-rmse:0.001258

# %%
## get model predictions on the test, training, and eval splits 
test_pred = bst.predict(dtest)
train_pred=bst.predict(dtrain)
eval_pred=bst.predict(deval)

# %%
## Get performance metrics on full dataset 
from helpers import * 
print_aggregate_peformance_metrics(train_y,train_pred,
                                   eval_y,eval_pred,
                                   test_y,test_pred,
                                   positive_thresh=0.2)
# Out:
# Train
# 	Spearman corr : SpearmanrResult(correlation=0.9973150165068658, pvalue=0.0)
# 	Pearson corr : (0.9997493479948458, 0.0)
# 	MAE : 0.0008584904713357882
# 	MAPE : 0.02926980045225843
# 	RMSE : 0.0012578162756836865
# 	auPRC : 0.9999999999999998
# 	auROC : 1.0
# Eval
# 	Spearman corr : SpearmanrResult(correlation=0.9358421746053747, pvalue=3.5747228499410647e-41)
# 	Pearson corr : (0.7854700226198363, 8.012851453367973e-20)
# 	MAE : 0.017981819804635858
# 	MAPE : 0.277518133548019
# 	RMSE : 0.05063428937453961
# 	auPRC : 0.42986111111111114
# 	auROC : 0.9588235294117647
# Test
# 	Spearman corr : SpearmanrResult(correlation=0.41926952183073435, pvalue=5.508793015324538e-27)
# 	Pearson corr : (0.3145283073821871, 2.8806864734435243e-15)
# 	MAE : 0.11776835965396162
# 	MAPE : 0.7405330365721461
# 	RMSE : 0.16342383258288323
# 	auPRC : 0.5719500326483073
# 	auROC : 0.7030089196301731

# %%
## Correlation values 
from scipy.stats import spearmanr,pearsonr
spearman_train=spearmanr(train_y,train_pred)
spearman_eval=spearmanr(eval_y,eval_pred)
spearman_test=spearmanr(test_y,test_pred)

pearson_train=pearsonr(train_y,train_pred)
pearson_eval=pearsonr(eval_y,eval_pred)
pearson_test=pearsonr(test_y,test_pred)

print("Spearman correlation:")
print("Train:"+str(spearman_train))
print("Eval:"+str(spearman_eval))
print("Test:"+str(spearman_test))
print("\n")
print("Pearson correlation:")
print("Train:"+str(pearson_train))
print("Eval:"+str(pearson_eval))
print("Test:"+str(pearson_test))
# Out:
# Spearman correlation:
# Train:SpearmanrResult(correlation=0.9973150165068658, pvalue=0.0)
# Eval:SpearmanrResult(correlation=0.9358421746053747, pvalue=3.5747228499410647e-41)
# Test:SpearmanrResult(correlation=0.41926952183073435, pvalue=5.508793015324538e-27)
#
#
# Pearson correlation:
# Train:(0.9997493479948458, 0.0)
# Eval:(0.7854700226198363, 8.012851453367973e-20)
# Test:(0.3145283073821871, 2.8806864734435243e-15)

# %%
## MAE
from sklearn.metrics import mean_absolute_error
mae_train=mean_absolute_error(train_y,train_pred)
print("MAE Train:"+str(mae_train))

mae_eval=mean_absolute_error(eval_y,eval_pred)
print("MAE Eval:"+str(mae_eval))

mae_test=mean_absolute_error(test_y,test_pred)
print("MAE Test:"+str(mae_test))
# Out:
# MAE Train:0.0008584904713357882
# MAE Eval:0.017981819804635858
# MAE Test:0.11776835965396162

# %%
## MAPE
pseudocount=0.01
mape_train=np.mean(np.abs((train_y - train_pred) /(pseudocount+train_y))) * 100
print("MAPE Train:"+str(mape_train)+"%")

mape_eval=np.mean(np.abs((eval_y - eval_pred) /(pseudocount+eval_y))) * 100
print("MAPE Eval:"+str(mape_eval)+"%")

mape_test=np.mean(np.abs((test_y - test_pred) /(pseudocount+test_y))) * 100
print("MAPE Test:"+str(mape_test)+"%")
# Out:
# MAPE Train:2.926980045225843%
# MAPE Eval:27.751813354801904%
# MAPE Test:74.05330365721461%

# %%
## RMSE
from sklearn.metrics import mean_squared_error
import math 
rmse_train=math.sqrt(mean_squared_error(train_y,train_pred))
print("RMSE Train:"+str(rmse_train))

rmse_eval=math.sqrt(mean_squared_error(eval_y,eval_pred))
print("RMSE Eval:"+str(rmse_eval))

rmse_test=math.sqrt(mean_squared_error(test_y,test_pred))
print("RMSE Test:"+str(rmse_test))
# Out:
# RMSE Train:0.0012578162756836865
# RMSE Eval:0.05063428937453961
# RMSE Test:0.16342383258288323

# %%
## PRC 
## PRC only valid for binary outcomes. 
## Editing levels < 0.5 are labeled as "0". 
## Editing levels >= 0.5 are labeled as "1". 

from sklearn.metrics import auc, precision_recall_curve

precision_train,recall_train,prc_thresholds_train=precision_recall_curve(train_y>=0.2,train_pred)
precision_eval,recall_eval,prc_thresholds_eval=precision_recall_curve(eval_y>=0.2,eval_pred)
precision_test,recall_test,prc_thresholds_test=precision_recall_curve(test_y>=0.4,test_pred)

auprc_train=auc(recall_train,precision_train)
auprc_eval=auc(recall_eval,precision_eval)
auprc_test=auc(recall_test,precision_test)

plt.plot(recall_train,precision_train,'r',label="Train:"+str(round(auprc_train,2)))
plt.plot(recall_eval,precision_eval,'g',label="Eval:"+str(round(auprc_eval,2)))
plt.plot(recall_test,precision_test,'b',label="Test:"+str(round(auprc_test,2)))
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("PRC")
plt.legend()

# %%
## ROC
from sklearn.metrics import roc_curve, roc_auc_score
fpr_train,tpr_train,roc_thresholds_train=roc_curve(train_y>=0.2,train_pred)
fpr_eval,tpr_eval,roc_thresholds_eval=roc_curve(eval_y>=0.2,eval_pred)
fpr_test,tpr_test,roc_thresholds_test=roc_curve(test_y>=0.4,test_pred)

auroc_train=roc_auc_score(train_y>=0.2,train_pred)
auroc_eval=roc_auc_score(eval_y>=0.2,eval_pred)
auroc_test=roc_auc_score(test_y>=0.4,test_pred)

plt.plot(fpr_train,tpr_train,'r',label="Train:"+str(round(auroc_train,2)))
plt.plot(fpr_eval,tpr_eval,'g',label="Eval:"+str(round(auroc_eval,2)))
plt.plot(fpr_test,tpr_test,'b',label="Test:"+str(round(auroc_test,2)))
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC")
plt.legend()

# %%
#plot the test set predictions 
matplotlib.rcParams['figure.figsize'] = [20, 8]
plt.subplot(1,3,1)
plt.plot(list(train_y),list(train_pred),'o')
plt.xlabel("Observed train set editing level, TTYH2 Comp")
plt.ylabel("Predicted train set editing level, TTYH2 Comp")
plt.subplot(1,3,2)
plt.plot(list(eval_y),list(eval_pred),'o')
plt.xlabel("Observed eval set editing level, TTYH2 Comp")
plt.ylabel("Predicted eval set editing level, TTYH2 Comp")
plt.subplot(1,3,3)
plt.plot(list(test_y),list(test_pred),'o')
plt.xlabel("Observed test set editing level, AJUBA Comp")
plt.ylabel("Predicted test set editing level, AJUBA Comp")

plt.show()

# %%
#calculate R^2, which is representative of variance explained 
# https://datascienceplus.com/extreme-gradient-boosting-with-r/
# https://arxiv.org/pdf/1706.06060.pdf

residuals = test_y - test_pred

y_test_mean = np.mean(test_pred)
print(y_test_mean)
#calculate total sum of squares 
tss=sum((test_y-y_test_mean)*(test_y-y_test_mean))
print(tss)
# Calculate residual sum of squares
rss =  sum(residuals*residuals)
print(rss)
# Calculate R-squared
rsq  =  1 - (rss/tss)
print('The R-square of the test data is ', round(rsq,3), '\n')
# Out:
# 0.05885654
# 16.089863065330462
# 16.05111678270302
# The R-square of the test data is  0.002
