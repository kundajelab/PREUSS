# %% [markdown]
# <a href="https://colab.research.google.com/github/kundajelab/adar_editing/blob/master/xgboost_with_shap/CROSS_SUBSTRATE_TRAINING_XGBOOST_WITH_TREESHAP_TRAIN_NEIL1_AND_AJUBA_PREDICT_TTYH2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Uncomment these lines if running as a google colab notebook: 
#!pip install numpy==1.15
#! git clone https://github.com/kundajelab/adar_editing
#import os
#os.chdir("adar_editing/xgboost_with_shap/")
#!pip install shap
#!pip install --upgrade xgboost
#!pip install cufflinks

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

# %%
#helper utilities for model training and interpretation 
import shap
from helpers import * 

#set a random seed so code is reproducible 
random.seed(1234)

# load JS visualization code to notebook
shap.initjs()
import warnings
warnings.filterwarnings('ignore')

#visualization utilities 
import matplotlib
import matplotlib.pyplot as plt 
# %matplotlib inline
import plotly.plotly as py
import numpy as np
from plotly.offline import iplot
from plotly.graph_objs import Heatmap
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...

# %% [markdown]
# ## Train NEIL 1 and AJUBA, Predict TTYH2

# %%
data_ajuba=pd.read_csv("../xin_feature_matrices/ajuba_bc_computational.features.csv",header=0,sep=',',index_col=0)
#remove any null editing level values 
data_ajuba=data_ajuba[~data_ajuba["editing_value"].isnull().values]
## prepare data for training with xgboost 
data_ajuba=format_for_xgboost(data_ajuba)
train_split1,eval_split1=split_train_eval_by_mut_pos(data_ajuba[~data_ajuba['mut_pos'].isna()])
null_mut_pos=data_ajuba[data_ajuba['mut_pos'].isna()]
train_split1=pd.concat((train_split1,null_mut_pos),axis=0)
# Out:
# (482, 186)
# {64.0: 22, 65.0: 21, 66.0: 22, 67.0: 22, 68.0: 22, 69.0: 23, 70.0: 23, 71.0: 24, 72.0: 23, 73.0: 33, 75.0: 33, 76.0: 24, 77.0: 24, 78.0: 23, 79.0: 23, 80.0: 22, 81.0: 22, 82.0: 22, 83.0: 44}

# %%
data_neil_comp=pd.read_csv("../xin_feature_matrices/neil1_computational.features.csv",header=0,sep=',',index_col=0)
#remove any null editing level values 
data_neil_comp=data_neil_comp[~data_neil_comp["editing_value"].isnull().values]
## prepare data for training with xgboost 
data_neil_comp=format_for_xgboost(data_neil_comp)
train_split2,eval_split2=split_train_eval_by_mut_pos(data_neil_comp[~data_neil_comp['mut_pos'].isna()])
null_mut_pos=data_neil_comp[data_neil_comp['mut_pos'].isna()]
train_split2=pd.concat((train_split2,null_mut_pos),axis=0)
# Out:
# (428, 219)
# {20.0: 3, 21.0: 3, 22.0: 3, 23.0: 4, 24.0: 3, 25.0: 4, 26.0: 3, 27.0: 4, 28.0: 4, 29.0: 4, 30.0: 3, 31.0: 4, 32.0: 4, 33.0: 4, 34.0: 4, 35.0: 4, 36.0: 4, 41.0: 20, 42.0: 21, 43.0: 18, 44.0: 18, 45.0: 20, 46.0: 19, 48.0: 20, 49.0: 21, 50.0: 21, 51.0: 20, 52.0: 20, 53.0: 21, 54.0: 19, 55.0: 21, 56.0: 20, 57.0: 15, 58.0: 31}

# %%
#concatenate train/eval splits from Neil1 & TTYH2 
train_split=pd.concat((train_split1,train_split2),axis=0)
eval_split=pd.concat((eval_split1,eval_split2),axis=0)

# %%
data_ttyh2_comp=pd.read_csv("../xin_feature_matrices/ttyh2_computational.features.csv",header=0,sep=',',index_col=0)
#remove any null editing level values 
data_ttyh2_comp=data_ttyh2_comp[~data_ttyh2_comp["editing_value"].isnull().values]
data_ttyh2_comp=format_for_xgboost(data_ttyh2_comp)
test_split=data_ttyh2_comp
# Out:
# (601, 216)

# %%
train_split.reset_index(inplace=True, drop=True) 
eval_split.reset_index(inplace=True,drop=True)
test_split.reset_index(inplace=True,drop=True)

# %%
#Remove any non-varying features 
train_novar=get_singleval_features(train_split)
eval_novar=get_singleval_features(eval_split)
test_novar=get_singleval_features(test_split)
uniform_features_to_drop=list(set(train_novar+eval_novar+test_novar))

# %%
#Remove any null features 
train_null=get_all_null_features(train_split)
eval_null=get_all_null_features(eval_split)
test_null=get_all_null_features(test_split)
null_features_to_drop=list(set(train_null+eval_null+test_null))

# %%
to_drop=list(set(uniform_features_to_drop+null_features_to_drop))
print("\n".join(to_drop))
# Out:
# d2_5prm_cp_hairpin
# u2_3prm_cp_internal
# u1_length_internal_es
# d3_5prm_cp_hairpin
# d1_3prm_cp_internal:G:C
# u_hairpin_length
# u1_3prm_cp_bulge:C:G
# site_length_hairpin
# mut_type:wt
# d1_3prm_cp_bulge
# d2_5prm_cp_bulge
# d3_length_hairpin
# u1_5prm_cp_internal
# mut_type:indel
# u2_5prm_cp_internal
# u1_5prm_cp_hairpin
# d3_3prm_cp_bulge
# u1_3prm_cp_internal
# d3_length_bulge
# mut_same_as_site
# d2_exist
# u2_exist
# d2_3prm_cp_internal:U:A
# d3_exist
# d1_5prm_cp_bulge
# d1_length_bulge
# d1_5prm_cp_hairpin
# u3_3prm_cp_internal
# u3_length_internal_es
# u2_length_internal_es
# u2_length_internal_ecs
# mut_type:mismatch
# d1_exist
# u3_5prm_cp_internal
# u1_3prm_cp_bulge:U:A
# d1_length_hairpin
# d2_length_hairpin
# d3_5prm_cp_bulge
# d2_3prm_cp_bulge
# site_5prm_cp_hairpin
# u3_length_internal_ecs
# u1_length_hairpin
# u1_length_internal_ecs
# mut_exist
# u1_exist

# %%
#remove teh features that don't change across isoforms , or are null for all isoforms
for cur_to_drop in to_drop: 
    try:
        train_split=train_split.drop(cur_to_drop,axis=1)
    except: 
        pass
    try:
        eval_split=eval_split.drop(cur_to_drop,axis=1)
    except: 
        pass 
    try:
        test_split=test_split.drop(to_drop,axis=1)
    except: 
        pass

# %%
train_y=train_split['editing_value']
train_X=train_split.drop(['editing_value'],axis=1)
eval_y=eval_split['editing_value']
eval_X=eval_split.drop(['editing_value'],axis=1)
test_y=test_split['editing_value']
test_X=test_split.drop(['editing_value'],axis=1)

# %%
print(train_X.shape)
print(train_y.shape)
print(eval_X.shape)
print(eval_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (717, 200)
# (717,)
# (155, 200)
# (155,)
# (601, 215)
# (601,)

# %%
train_cols=set(train_X.columns)
eval_cols=set(eval_X.columns)
test_cols=set(test_X.columns)

# %%
common=train_cols.intersection(eval_cols)
common=common.intersection(test_cols)
common=list(common)
#print(common)
train_X=train_X[common]
eval_X=eval_X[common]
test_X=test_X[common]
print(train_X.shape)
print(train_y.shape)
print(eval_X.shape)
print(eval_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (717, 151)
# (717,)
# (155, 151)
# (155,)
# (601, 151)
# (601,)

# %%
## format matrixes for xgboost 
import xgboost
dtrain=xgboost.DMatrix(train_X,train_y)
deval=xgboost.DMatrix(eval_X,eval_y)
dtest=xgboost.DMatrix(test_X,test_y)

# %%
## set model training parameters 
from __future__ import unicode_literals
param=dict() 
param['nthread'] = 20
#rmse -- root mean square error 
# mae -- mean absolute error 
# map -- mean average precision 
# auc -- area under ROC curve 
# aucpr -- area under precision recall curve 

#Note: the last metric in your 'eval_metric' list will get optimized 
param['eval_metric'] = ['aucpr','auc','mae','map','rmse']

# %%
evallist = [(deval, 'eval'), (dtrain, 'train')]

# %%
num_round = 1000
bst = xgboost.train(param, dtrain, num_round, evallist,early_stopping_rounds=10)
# Out:
# [0]	eval-aucpr:0.384054	eval-auc:0.831457	eval-mae:0.292312	eval-map:1	eval-rmse:0.308277	train-aucpr:0.511646	train-auc:0.857905	train-mae:0.267315	train-map:1	train-rmse:0.289296
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 10 rounds.
# [1]	eval-aucpr:0.410453	eval-auc:0.845619	eval-mae:0.212138	eval-map:1	eval-rmse:0.226217	train-aucpr:0.529271	train-auc:0.866178	train-mae:0.19307	train-map:1	train-rmse:0.208862
# [2]	eval-aucpr:0.415105	eval-auc:0.844707	eval-mae:0.157286	eval-map:1	eval-rmse:0.170661	train-aucpr:0.532743	train-auc:0.867912	train-mae:0.141394	train-map:1	train-rmse:0.153121
# [3]	eval-aucpr:0.422293	eval-auc:0.851494	eval-mae:0.118843	eval-map:1	eval-rmse:0.132384	train-aucpr:0.538369	train-auc:0.872713	train-mae:0.105206	train-map:1	train-rmse:0.114627
# [4]	eval-aucpr:0.418827	eval-auc:0.852779	eval-mae:0.094251	eval-map:1	eval-rmse:0.108775	train-aucpr:0.53923	train-auc:0.874521	train-mae:0.079599	train-map:1	train-rmse:0.088708
# [5]	eval-aucpr:0.410021	eval-auc:0.853433	eval-mae:0.076681	eval-map:1	eval-rmse:0.093729	train-aucpr:0.543803	train-auc:0.87577	train-mae:0.061798	train-map:1	train-rmse:0.071437
# [6]	eval-aucpr:0.412989	eval-auc:0.855532	eval-mae:0.064702	eval-map:1	eval-rmse:0.085125	train-aucpr:0.547149	train-auc:0.87705	train-mae:0.048347	train-map:1	train-rmse:0.058592
# [7]	eval-aucpr:0.406237	eval-auc:0.857815	eval-mae:0.055759	eval-map:1	eval-rmse:0.079284	train-aucpr:0.549316	train-auc:0.878693	train-mae:0.038829	train-map:1	train-rmse:0.0498
# [8]	eval-aucpr:0.406	eval-auc:0.858202	eval-mae:0.050815	eval-map:1	eval-rmse:0.077178	train-aucpr:0.554252	train-auc:0.879652	train-mae:0.032838	train-map:1	train-rmse:0.044068
# [9]	eval-aucpr:0.407116	eval-auc:0.858638	eval-mae:0.047074	eval-map:1	eval-rmse:0.075185	train-aucpr:0.55592	train-auc:0.880109	train-mae:0.028619	train-map:1	train-rmse:0.039432
# [10]	eval-aucpr:0.407834	eval-auc:0.858886	eval-mae:0.044426	eval-map:1	eval-rmse:0.073756	train-aucpr:0.556755	train-auc:0.880537	train-mae:0.025759	train-map:1	train-rmse:0.036545
# [11]	eval-aucpr:0.408259	eval-auc:0.86004	eval-mae:0.04222	eval-map:1	eval-rmse:0.073539	train-aucpr:0.558463	train-auc:0.882021	train-mae:0.023079	train-map:1	train-rmse:0.033777
# [12]	eval-aucpr:0.410935	eval-auc:0.86106	eval-mae:0.040785	eval-map:1	eval-rmse:0.072702	train-aucpr:0.559926	train-auc:0.882415	train-mae:0.02141	train-map:1	train-rmse:0.031891
# [13]	eval-aucpr:0.41051	eval-auc:0.86126	eval-mae:0.039858	eval-map:1	eval-rmse:0.072169	train-aucpr:0.560168	train-auc:0.88296	train-mae:0.020462	train-map:1	train-rmse:0.031168
# [14]	eval-aucpr:0.410791	eval-auc:0.861703	eval-mae:0.040147	eval-map:1	eval-rmse:0.072578	train-aucpr:0.560952	train-auc:0.883191	train-mae:0.019683	train-map:1	train-rmse:0.030134
# [15]	eval-aucpr:0.411363	eval-auc:0.862122	eval-mae:0.039649	eval-map:1	eval-rmse:0.072584	train-aucpr:0.561963	train-auc:0.883679	train-mae:0.018338	train-map:1	train-rmse:0.027989
# [16]	eval-aucpr:0.4109	eval-auc:0.86311	eval-mae:0.038238	eval-map:1	eval-rmse:0.072057	train-aucpr:0.562452	train-auc:0.883986	train-mae:0.017356	train-map:1	train-rmse:0.026823
# [17]	eval-aucpr:0.395282	eval-auc:0.862969	eval-mae:0.037733	eval-map:1	eval-rmse:0.071736	train-aucpr:0.562655	train-auc:0.8843	train-mae:0.016698	train-map:1	train-rmse:0.026016
# [18]	eval-aucpr:0.39775	eval-auc:0.863436	eval-mae:0.037391	eval-map:1	eval-rmse:0.071358	train-aucpr:0.563195	train-auc:0.884789	train-mae:0.015901	train-map:1	train-rmse:0.024808
# [19]	eval-aucpr:0.413269	eval-auc:0.863655	eval-mae:0.037149	eval-map:1	eval-rmse:0.071028	train-aucpr:0.563581	train-auc:0.884873	train-mae:0.015424	train-map:1	train-rmse:0.024181
# [20]	eval-aucpr:0.413551	eval-auc:0.864081	eval-mae:0.036939	eval-map:1	eval-rmse:0.070958	train-aucpr:0.563952	train-auc:0.885237	train-mae:0.01489	train-map:1	train-rmse:0.023311
# [21]	eval-aucpr:0.398257	eval-auc:0.864031	eval-mae:0.036834	eval-map:1	eval-rmse:0.071018	train-aucpr:0.564401	train-auc:0.885446	train-mae:0.014229	train-map:1	train-rmse:0.02233
# [22]	eval-aucpr:0.396725	eval-auc:0.864327	eval-mae:0.036465	eval-map:1	eval-rmse:0.071226	train-aucpr:0.564569	train-auc:0.885788	train-mae:0.013642	train-map:1	train-rmse:0.021687
# [23]	eval-aucpr:0.397283	eval-auc:0.864662	eval-mae:0.036117	eval-map:1	eval-rmse:0.070979	train-aucpr:0.564714	train-auc:0.886039	train-mae:0.013251	train-map:1	train-rmse:0.021267
# [24]	eval-aucpr:0.398052	eval-auc:0.864798	eval-mae:0.035937	eval-map:1	eval-rmse:0.070642	train-aucpr:0.565368	train-auc:0.886142	train-mae:0.012777	train-map:1	train-rmse:0.020494
# [25]	eval-aucpr:0.398062	eval-auc:0.864848	eval-mae:0.035756	eval-map:1	eval-rmse:0.070541	train-aucpr:0.565493	train-auc:0.886406	train-mae:0.012376	train-map:1	train-rmse:0.01996
# [26]	eval-aucpr:0.39837	eval-auc:0.865067	eval-mae:0.0355	eval-map:1	eval-rmse:0.07035	train-aucpr:0.565625	train-auc:0.886599	train-mae:0.011916	train-map:1	train-rmse:0.01947
# [27]	eval-aucpr:0.398052	eval-auc:0.864935	eval-mae:0.035345	eval-map:1	eval-rmse:0.07038	train-aucpr:0.565752	train-auc:0.886877	train-mae:0.011434	train-map:1	train-rmse:0.019073
# [28]	eval-aucpr:0.397574	eval-auc:0.86478	eval-mae:0.035386	eval-map:1	eval-rmse:0.070603	train-aucpr:0.566121	train-auc:0.886915	train-mae:0.011113	train-map:1	train-rmse:0.018443
# [29]	eval-aucpr:0.397567	eval-auc:0.864809	eval-mae:0.035217	eval-map:1	eval-rmse:0.0706	train-aucpr:0.566114	train-auc:0.886949	train-mae:0.010989	train-map:1	train-rmse:0.018338
# [30]	eval-aucpr:0.413187	eval-auc:0.864991	eval-mae:0.035215	eval-map:1	eval-rmse:0.070453	train-aucpr:0.566508	train-auc:0.887002	train-mae:0.010716	train-map:1	train-rmse:0.017874
# [31]	eval-aucpr:0.397241	eval-auc:0.864456	eval-mae:0.035439	eval-map:1	eval-rmse:0.070874	train-aucpr:0.566598	train-auc:0.887092	train-mae:0.010476	train-map:1	train-rmse:0.017494
# [32]	eval-aucpr:0.412944	eval-auc:0.864339	eval-mae:0.03525	eval-map:1	eval-rmse:0.070429	train-aucpr:0.566775	train-auc:0.887174	train-mae:0.010143	train-map:1	train-rmse:0.017045
# [33]	eval-aucpr:0.41301	eval-auc:0.864271	eval-mae:0.035222	eval-map:1	eval-rmse:0.070558	train-aucpr:0.566813	train-auc:0.887222	train-mae:0.009909	train-map:1	train-rmse:0.016797
# [34]	eval-aucpr:0.413019	eval-auc:0.864322	eval-mae:0.035163	eval-map:1	eval-rmse:0.070552	train-aucpr:0.56685	train-auc:0.887319	train-mae:0.009704	train-map:1	train-rmse:0.016623
# [35]	eval-aucpr:0.397363	eval-auc:0.864123	eval-mae:0.03521	eval-map:1	eval-rmse:0.070789	train-aucpr:0.566885	train-auc:0.887346	train-mae:0.009611	train-map:1	train-rmse:0.016456
# [36]	eval-aucpr:0.397168	eval-auc:0.864035	eval-mae:0.03495	eval-map:1	eval-rmse:0.070695	train-aucpr:0.566913	train-auc:0.887406	train-mae:0.009394	train-map:1	train-rmse:0.016247
# [37]	eval-aucpr:0.397224	eval-auc:0.864096	eval-mae:0.034961	eval-map:1	eval-rmse:0.070957	train-aucpr:0.567003	train-auc:0.887416	train-mae:0.00916	train-map:1	train-rmse:0.015875
# [38]	eval-aucpr:0.397418	eval-auc:0.864474	eval-mae:0.034712	eval-map:1	eval-rmse:0.07086	train-aucpr:0.567065	train-auc:0.887533	train-mae:0.008872	train-map:1	train-rmse:0.01563
# [39]	eval-aucpr:0.397432	eval-auc:0.864513	eval-mae:0.034736	eval-map:1	eval-rmse:0.070797	train-aucpr:0.567173	train-auc:0.887544	train-mae:0.008652	train-map:1	train-rmse:0.015354
# [40]	eval-aucpr:0.397625	eval-auc:0.864575	eval-mae:0.034538	eval-map:1	eval-rmse:0.070612	train-aucpr:0.567196	train-auc:0.887578	train-mae:0.008524	train-map:1	train-rmse:0.015233
# [41]	eval-aucpr:0.397636	eval-auc:0.86456	eval-mae:0.034564	eval-map:1	eval-rmse:0.070575	train-aucpr:0.567307	train-auc:0.88764	train-mae:0.008261	train-map:1	train-rmse:0.014754
# [42]	eval-aucpr:0.397761	eval-auc:0.864708	eval-mae:0.034442	eval-map:1	eval-rmse:0.070531	train-aucpr:0.567326	train-auc:0.887698	train-mae:0.008155	train-map:1	train-rmse:0.014697
# [43]	eval-aucpr:0.397781	eval-auc:0.864799	eval-mae:0.034312	eval-map:1	eval-rmse:0.070466	train-aucpr:0.567392	train-auc:0.887739	train-mae:0.008051	train-map:1	train-rmse:0.014586
# [44]	eval-aucpr:0.397803	eval-auc:0.864907	eval-mae:0.034279	eval-map:1	eval-rmse:0.070438	train-aucpr:0.567398	train-auc:0.887801	train-mae:0.007959	train-map:1	train-rmse:0.014514
# [45]	eval-aucpr:0.397812	eval-auc:0.864924	eval-mae:0.034272	eval-map:1	eval-rmse:0.070463	train-aucpr:0.567604	train-auc:0.887829	train-mae:0.007774	train-map:1	train-rmse:0.014172
# [46]	eval-aucpr:0.397944	eval-auc:0.865014	eval-mae:0.034047	eval-map:1	eval-rmse:0.070392	train-aucpr:0.567623	train-auc:0.887873	train-mae:0.007635	train-map:1	train-rmse:0.014075
# [47]	eval-aucpr:0.397978	eval-auc:0.865078	eval-mae:0.033934	eval-map:1	eval-rmse:0.070344	train-aucpr:0.567712	train-auc:0.887938	train-mae:0.007383	train-map:1	train-rmse:0.013516
# [48]	eval-aucpr:0.398052	eval-auc:0.865173	eval-mae:0.033848	eval-map:1	eval-rmse:0.070295	train-aucpr:0.567721	train-auc:0.887969	train-mae:0.007337	train-map:1	train-rmse:0.013484
# [49]	eval-aucpr:0.398053	eval-auc:0.865175	eval-mae:0.033865	eval-map:1	eval-rmse:0.070279	train-aucpr:0.567787	train-auc:0.887987	train-mae:0.007221	train-map:1	train-rmse:0.013363
# [50]	eval-aucpr:0.39807	eval-auc:0.865199	eval-mae:0.033724	eval-map:1	eval-rmse:0.070254	train-aucpr:0.567817	train-auc:0.888071	train-mae:0.006984	train-map:1	train-rmse:0.013216
# [51]	eval-aucpr:0.398066	eval-auc:0.865186	eval-mae:0.033688	eval-map:1	eval-rmse:0.070281	train-aucpr:0.567857	train-auc:0.888103	train-mae:0.006845	train-map:1	train-rmse:0.012858
# [52]	eval-aucpr:0.398072	eval-auc:0.865195	eval-mae:0.033689	eval-map:1	eval-rmse:0.070344	train-aucpr:0.567908	train-auc:0.888133	train-mae:0.00661	train-map:1	train-rmse:0.012503
# [53]	eval-aucpr:0.398027	eval-auc:0.865205	eval-mae:0.03362	eval-map:1	eval-rmse:0.070344	train-aucpr:0.567921	train-auc:0.888169	train-mae:0.006505	train-map:1	train-rmse:0.012429
# [54]	eval-aucpr:0.398007	eval-auc:0.865154	eval-mae:0.033534	eval-map:1	eval-rmse:0.070313	train-aucpr:0.567936	train-auc:0.88819	train-mae:0.006386	train-map:1	train-rmse:0.012366
# [55]	eval-aucpr:0.396458	eval-auc:0.864938	eval-mae:0.03357	eval-map:1	eval-rmse:0.070505	train-aucpr:0.567976	train-auc:0.888202	train-mae:0.006257	train-map:1	train-rmse:0.01222
# [56]	eval-aucpr:0.396457	eval-auc:0.864926	eval-mae:0.033491	eval-map:1	eval-rmse:0.070478	train-aucpr:0.567976	train-auc:0.888215	train-mae:0.006137	train-map:1	train-rmse:0.012083
# [57]	eval-aucpr:0.396461	eval-auc:0.865	eval-mae:0.033444	eval-map:1	eval-rmse:0.07047	train-aucpr:0.567977	train-auc:0.888228	train-mae:0.006047	train-map:1	train-rmse:0.012019
# [58]	eval-aucpr:0.396314	eval-auc:0.865079	eval-mae:0.033357	eval-map:1	eval-rmse:0.070493	train-aucpr:0.567992	train-auc:0.888241	train-mae:0.005921	train-map:1	train-rmse:0.011862
# [59]	eval-aucpr:0.396314	eval-auc:0.865079	eval-mae:0.033357	eval-map:1	eval-rmse:0.070489	train-aucpr:0.568065	train-auc:0.888253	train-mae:0.005807	train-map:1	train-rmse:0.011687
# [60]	eval-aucpr:0.396212	eval-auc:0.865029	eval-mae:0.033449	eval-map:1	eval-rmse:0.070508	train-aucpr:0.568151	train-auc:0.888281	train-mae:0.005569	train-map:1	train-rmse:0.011101
# [61]	eval-aucpr:0.396182	eval-auc:0.865006	eval-mae:0.033342	eval-map:1	eval-rmse:0.070371	train-aucpr:0.568165	train-auc:0.888302	train-mae:0.005416	train-map:1	train-rmse:0.010758
# [62]	eval-aucpr:0.396175	eval-auc:0.864989	eval-mae:0.033311	eval-map:1	eval-rmse:0.070399	train-aucpr:0.568181	train-auc:0.888325	train-mae:0.005294	train-map:1	train-rmse:0.010643
# [63]	eval-aucpr:0.396186	eval-auc:0.865033	eval-mae:0.033261	eval-map:1	eval-rmse:0.07041	train-aucpr:0.56822	train-auc:0.888342	train-mae:0.005208	train-map:1	train-rmse:0.010415
# [64]	eval-aucpr:0.396493	eval-auc:0.865066	eval-mae:0.033297	eval-map:1	eval-rmse:0.070377	train-aucpr:0.56828	train-auc:0.888359	train-mae:0.005057	train-map:1	train-rmse:0.010175
# [65]	eval-aucpr:0.396532	eval-auc:0.865135	eval-mae:0.033252	eval-map:1	eval-rmse:0.070355	train-aucpr:0.568301	train-auc:0.888391	train-mae:0.004936	train-map:1	train-rmse:0.010044
# [66]	eval-aucpr:0.396543	eval-auc:0.865182	eval-mae:0.033215	eval-map:1	eval-rmse:0.070328	train-aucpr:0.56832	train-auc:0.888403	train-mae:0.00484	train-map:1	train-rmse:0.009891
# [67]	eval-aucpr:0.396548	eval-auc:0.86521	eval-mae:0.033259	eval-map:1	eval-rmse:0.070396	train-aucpr:0.568334	train-auc:0.888418	train-mae:0.004707	train-map:1	train-rmse:0.009672
# [68]	eval-aucpr:0.396241	eval-auc:0.865167	eval-mae:0.033244	eval-map:1	eval-rmse:0.070422	train-aucpr:0.568347	train-auc:0.888427	train-mae:0.004641	train-map:1	train-rmse:0.009604
# [69]	eval-aucpr:0.396248	eval-auc:0.865198	eval-mae:0.033273	eval-map:1	eval-rmse:0.070468	train-aucpr:0.56834	train-auc:0.888438	train-mae:0.004569	train-map:1	train-rmse:0.009567
# [70]	eval-aucpr:0.396599	eval-auc:0.865429	eval-mae:0.03314	eval-map:1	eval-rmse:0.070411	train-aucpr:0.568351	train-auc:0.888467	train-mae:0.004451	train-map:1	train-rmse:0.009449
# [71]	eval-aucpr:0.396261	eval-auc:0.865298	eval-mae:0.033136	eval-map:1	eval-rmse:0.070395	train-aucpr:0.568403	train-auc:0.888489	train-mae:0.004297	train-map:1	train-rmse:0.009227
# [72]	eval-aucpr:0.396271	eval-auc:0.865344	eval-mae:0.033134	eval-map:1	eval-rmse:0.070391	train-aucpr:0.568421	train-auc:0.888495	train-mae:0.00423	train-map:1	train-rmse:0.009164
# [73]	eval-aucpr:0.396155	eval-auc:0.865315	eval-mae:0.033145	eval-map:1	eval-rmse:0.070365	train-aucpr:0.568433	train-auc:0.888501	train-mae:0.004154	train-map:1	train-rmse:0.009068
# [74]	eval-aucpr:0.396157	eval-auc:0.865351	eval-mae:0.033188	eval-map:1	eval-rmse:0.070525	train-aucpr:0.568444	train-auc:0.888504	train-mae:0.004083	train-map:1	train-rmse:0.009005
# [75]	eval-aucpr:0.396005	eval-auc:0.865401	eval-mae:0.033135	eval-map:1	eval-rmse:0.070523	train-aucpr:0.568454	train-auc:0.888525	train-mae:0.004	train-map:1	train-rmse:0.008936
# [76]	eval-aucpr:0.39602	eval-auc:0.865441	eval-mae:0.033077	eval-map:1	eval-rmse:0.070486	train-aucpr:0.56846	train-auc:0.888537	train-mae:0.003926	train-map:1	train-rmse:0.008903
# [77]	eval-aucpr:0.396011	eval-auc:0.865433	eval-mae:0.033071	eval-map:1	eval-rmse:0.070503	train-aucpr:0.568459	train-auc:0.888543	train-mae:0.003889	train-map:1	train-rmse:0.008878
# [78]	eval-aucpr:0.396105	eval-auc:0.8655	eval-mae:0.033081	eval-map:1	eval-rmse:0.070514	train-aucpr:0.568464	train-auc:0.888552	train-mae:0.003849	train-map:1	train-rmse:0.008844
# [79]	eval-aucpr:0.396704	eval-auc:0.865753	eval-mae:0.032968	eval-map:1	eval-rmse:0.070475	train-aucpr:0.568483	train-auc:0.888562	train-mae:0.00374	train-map:1	train-rmse:0.008706
# [80]	eval-aucpr:0.396539	eval-auc:0.865511	eval-mae:0.03298	eval-map:1	eval-rmse:0.070537	train-aucpr:0.568509	train-auc:0.888568	train-mae:0.003656	train-map:1	train-rmse:0.008585
# [81]	eval-aucpr:0.396532	eval-auc:0.865468	eval-mae:0.032968	eval-map:1	eval-rmse:0.070534	train-aucpr:0.568509	train-auc:0.888581	train-mae:0.003575	train-map:1	train-rmse:0.008499
# [82]	eval-aucpr:0.39654	eval-auc:0.865497	eval-mae:0.032915	eval-map:1	eval-rmse:0.070535	train-aucpr:0.568525	train-auc:0.888595	train-mae:0.003487	train-map:1	train-rmse:0.008373
# [83]	eval-aucpr:0.396554	eval-auc:0.865525	eval-mae:0.03288	eval-map:1	eval-rmse:0.070526	train-aucpr:0.56853	train-auc:0.888601	train-mae:0.003462	train-map:1	train-rmse:0.008352
# [84]	eval-aucpr:0.396288	eval-auc:0.865444	eval-mae:0.032895	eval-map:1	eval-rmse:0.070536	train-aucpr:0.568531	train-auc:0.888602	train-mae:0.003426	train-map:1	train-rmse:0.008327
# [85]	eval-aucpr:0.396287	eval-auc:0.865437	eval-mae:0.032878	eval-map:1	eval-rmse:0.070555	train-aucpr:0.568538	train-auc:0.888609	train-mae:0.003375	train-map:1	train-rmse:0.008277
# [86]	eval-aucpr:0.396287	eval-auc:0.865436	eval-mae:0.032883	eval-map:1	eval-rmse:0.070563	train-aucpr:0.568552	train-auc:0.888612	train-mae:0.003332	train-map:1	train-rmse:0.00823
# [87]	eval-aucpr:0.396288	eval-auc:0.865442	eval-mae:0.032892	eval-map:1	eval-rmse:0.070565	train-aucpr:0.568554	train-auc:0.888618	train-mae:0.003291	train-map:1	train-rmse:0.008211
# [88]	eval-aucpr:0.396296	eval-auc:0.865463	eval-mae:0.032867	eval-map:1	eval-rmse:0.070561	train-aucpr:0.568556	train-auc:0.888626	train-mae:0.003243	train-map:1	train-rmse:0.008191
# [89]	eval-aucpr:0.3963	eval-auc:0.865514	eval-mae:0.032867	eval-map:1	eval-rmse:0.07059	train-aucpr:0.568558	train-auc:0.88863	train-mae:0.003212	train-map:1	train-rmse:0.008159
# [90]	eval-aucpr:0.396299	eval-auc:0.865521	eval-mae:0.032822	eval-map:1	eval-rmse:0.07058	train-aucpr:0.568561	train-auc:0.888635	train-mae:0.003168	train-map:1	train-rmse:0.008132
# [91]	eval-aucpr:0.396134	eval-auc:0.865437	eval-mae:0.032853	eval-map:1	eval-rmse:0.070641	train-aucpr:0.568564	train-auc:0.88864	train-mae:0.003111	train-map:1	train-rmse:0.008097
# [92]	eval-aucpr:0.396141	eval-auc:0.865459	eval-mae:0.032843	eval-map:1	eval-rmse:0.07066	train-aucpr:0.568565	train-auc:0.888645	train-mae:0.003077	train-map:1	train-rmse:0.008079
# [93]	eval-aucpr:0.396143	eval-auc:0.865466	eval-mae:0.032858	eval-map:1	eval-rmse:0.070667	train-aucpr:0.568568	train-auc:0.888647	train-mae:0.00305	train-map:1	train-rmse:0.008063
# [94]	eval-aucpr:0.39607	eval-auc:0.865392	eval-mae:0.032872	eval-map:1	eval-rmse:0.070692	train-aucpr:0.568575	train-auc:0.888648	train-mae:0.00302	train-map:1	train-rmse:0.00803
# [95]	eval-aucpr:0.39607	eval-auc:0.865392	eval-mae:0.032877	eval-map:1	eval-rmse:0.070739	train-aucpr:0.568599	train-auc:0.888651	train-mae:0.002945	train-map:1	train-rmse:0.007962
# [96]	eval-aucpr:0.396229	eval-auc:0.865449	eval-mae:0.032837	eval-map:1	eval-rmse:0.070726	train-aucpr:0.568605	train-auc:0.888658	train-mae:0.002906	train-map:1	train-rmse:0.007918
# [97]	eval-aucpr:0.396212	eval-auc:0.865435	eval-mae:0.032849	eval-map:1	eval-rmse:0.070723	train-aucpr:0.568606	train-auc:0.888661	train-mae:0.00288	train-map:1	train-rmse:0.0079
# [98]	eval-aucpr:0.39619	eval-auc:0.865401	eval-mae:0.032816	eval-map:1	eval-rmse:0.070699	train-aucpr:0.568605	train-auc:0.888663	train-mae:0.002844	train-map:1	train-rmse:0.007858
# [99]	eval-aucpr:0.397019	eval-auc:0.865717	eval-mae:0.032778	eval-map:1	eval-rmse:0.070684	train-aucpr:0.568609	train-auc:0.888666	train-mae:0.002803	train-map:1	train-rmse:0.007813
# [100]	eval-aucpr:0.397021	eval-auc:0.865725	eval-mae:0.032759	eval-map:1	eval-rmse:0.070669	train-aucpr:0.568611	train-auc:0.888668	train-mae:0.002774	train-map:1	train-rmse:0.007786
# [101]	eval-aucpr:0.397001	eval-auc:0.865702	eval-mae:0.032747	eval-map:1	eval-rmse:0.070688	train-aucpr:0.568613	train-auc:0.888671	train-mae:0.00275	train-map:1	train-rmse:0.007774
# [102]	eval-aucpr:0.397018	eval-auc:0.865736	eval-mae:0.032729	eval-map:1	eval-rmse:0.070699	train-aucpr:0.568616	train-auc:0.888674	train-mae:0.002709	train-map:1	train-rmse:0.007738
# [103]	eval-aucpr:0.397018	eval-auc:0.865736	eval-mae:0.03273	eval-map:1	eval-rmse:0.070694	train-aucpr:0.568624	train-auc:0.888677	train-mae:0.002665	train-map:1	train-rmse:0.007676
# [104]	eval-aucpr:0.397019	eval-auc:0.865745	eval-mae:0.032721	eval-map:1	eval-rmse:0.070699	train-aucpr:0.568628	train-auc:0.88868	train-mae:0.002614	train-map:1	train-rmse:0.007609
# [105]	eval-aucpr:0.397022	eval-auc:0.865752	eval-mae:0.032723	eval-map:1	eval-rmse:0.070679	train-aucpr:0.568649	train-auc:0.888683	train-mae:0.00256	train-map:1	train-rmse:0.00755
# [106]	eval-aucpr:0.397022	eval-auc:0.865748	eval-mae:0.032715	eval-map:1	eval-rmse:0.07067	train-aucpr:0.56865	train-auc:0.888685	train-mae:0.002538	train-map:1	train-rmse:0.007535
# [107]	eval-aucpr:0.397007	eval-auc:0.865728	eval-mae:0.032717	eval-map:1	eval-rmse:0.070669	train-aucpr:0.568649	train-auc:0.888686	train-mae:0.00251	train-map:1	train-rmse:0.007514
# [108]	eval-aucpr:0.397007	eval-auc:0.865726	eval-mae:0.032722	eval-map:1	eval-rmse:0.070667	train-aucpr:0.568665	train-auc:0.888688	train-mae:0.002461	train-map:1	train-rmse:0.007471
# [109]	eval-aucpr:0.397027	eval-auc:0.865758	eval-mae:0.032704	eval-map:1	eval-rmse:0.070644	train-aucpr:0.568691	train-auc:0.888691	train-mae:0.002412	train-map:1	train-rmse:0.007434
# [110]	eval-aucpr:0.397027	eval-auc:0.86576	eval-mae:0.032714	eval-map:1	eval-rmse:0.070646	train-aucpr:0.568691	train-auc:0.888693	train-mae:0.002392	train-map:1	train-rmse:0.007424
# [111]	eval-aucpr:0.397014	eval-auc:0.86575	eval-mae:0.032671	eval-map:1	eval-rmse:0.07065	train-aucpr:0.568696	train-auc:0.888703	train-mae:0.002334	train-map:1	train-rmse:0.007388
# [112]	eval-aucpr:0.397019	eval-auc:0.865753	eval-mae:0.032636	eval-map:1	eval-rmse:0.070634	train-aucpr:0.568698	train-auc:0.888708	train-mae:0.002296	train-map:1	train-rmse:0.007373
# [113]	eval-aucpr:0.397022	eval-auc:0.86577	eval-mae:0.032637	eval-map:1	eval-rmse:0.070634	train-aucpr:0.568699	train-auc:0.88871	train-mae:0.002285	train-map:1	train-rmse:0.007369
# [114]	eval-aucpr:0.39668	eval-auc:0.865687	eval-mae:0.032604	eval-map:1	eval-rmse:0.070629	train-aucpr:0.568702	train-auc:0.888716	train-mae:0.002225	train-map:1	train-rmse:0.007349
# [115]	eval-aucpr:0.396736	eval-auc:0.865731	eval-mae:0.032569	eval-map:1	eval-rmse:0.070624	train-aucpr:0.568703	train-auc:0.888719	train-mae:0.002197	train-map:1	train-rmse:0.007338
# [116]	eval-aucpr:0.397114	eval-auc:0.865886	eval-mae:0.032571	eval-map:1	eval-rmse:0.070608	train-aucpr:0.568707	train-auc:0.888721	train-mae:0.002168	train-map:1	train-rmse:0.00731
# [117]	eval-aucpr:0.397109	eval-auc:0.865858	eval-mae:0.032533	eval-map:1	eval-rmse:0.070604	train-aucpr:0.568708	train-auc:0.888722	train-mae:0.002144	train-map:1	train-rmse:0.007299
# [118]	eval-aucpr:0.397028	eval-auc:0.865756	eval-mae:0.032572	eval-map:1	eval-rmse:0.07064	train-aucpr:0.56871	train-auc:0.888724	train-mae:0.002104	train-map:1	train-rmse:0.007269
# [119]	eval-aucpr:0.397042	eval-auc:0.865781	eval-mae:0.032561	eval-map:1	eval-rmse:0.070641	train-aucpr:0.568711	train-auc:0.888727	train-mae:0.002075	train-map:1	train-rmse:0.00726
# [120]	eval-aucpr:0.397032	eval-auc:0.865771	eval-mae:0.032568	eval-map:1	eval-rmse:0.070653	train-aucpr:0.568711	train-auc:0.888729	train-mae:0.002061	train-map:1	train-rmse:0.007257
# [121]	eval-aucpr:0.397002	eval-auc:0.865731	eval-mae:0.032579	eval-map:1	eval-rmse:0.07076	train-aucpr:0.568723	train-auc:0.88873	train-mae:0.002016	train-map:1	train-rmse:0.007205
# [122]	eval-aucpr:0.397358	eval-auc:0.865867	eval-mae:0.032552	eval-map:1	eval-rmse:0.070723	train-aucpr:0.568724	train-auc:0.888731	train-mae:0.001983	train-map:1	train-rmse:0.007181
# [123]	eval-aucpr:0.397332	eval-auc:0.865792	eval-mae:0.032418	eval-map:1	eval-rmse:0.070707	train-aucpr:0.56874	train-auc:0.888733	train-mae:0.001954	train-map:1	train-rmse:0.007161
# [124]	eval-aucpr:0.397325	eval-auc:0.865783	eval-mae:0.032419	eval-map:1	eval-rmse:0.070706	train-aucpr:0.568745	train-auc:0.888733	train-mae:0.001935	train-map:1	train-rmse:0.007153
# [125]	eval-aucpr:0.397328	eval-auc:0.865789	eval-mae:0.032411	eval-map:1	eval-rmse:0.070708	train-aucpr:0.568746	train-auc:0.888734	train-mae:0.001906	train-map:1	train-rmse:0.007141
# [126]	eval-aucpr:0.397328	eval-auc:0.865789	eval-mae:0.032415	eval-map:1	eval-rmse:0.070722	train-aucpr:0.568746	train-auc:0.888734	train-mae:0.001892	train-map:1	train-rmse:0.007136
# [127]	eval-aucpr:0.397327	eval-auc:0.865785	eval-mae:0.032421	eval-map:1	eval-rmse:0.070719	train-aucpr:0.568747	train-auc:0.888737	train-mae:0.001866	train-map:1	train-rmse:0.007124
# [128]	eval-aucpr:0.397327	eval-auc:0.865784	eval-mae:0.032417	eval-map:1	eval-rmse:0.070728	train-aucpr:0.568747	train-auc:0.888737	train-mae:0.00185	train-map:1	train-rmse:0.007118
# [129]	eval-aucpr:0.397313	eval-auc:0.865703	eval-mae:0.032422	eval-map:1	eval-rmse:0.070721	train-aucpr:0.568748	train-auc:0.888738	train-mae:0.001819	train-map:1	train-rmse:0.007099
# [130]	eval-aucpr:0.397312	eval-auc:0.865692	eval-mae:0.032425	eval-map:1	eval-rmse:0.070721	train-aucpr:0.568749	train-auc:0.888739	train-mae:0.001807	train-map:1	train-rmse:0.007096
# [131]	eval-aucpr:0.396868	eval-auc:0.865523	eval-mae:0.03242	eval-map:1	eval-rmse:0.070723	train-aucpr:0.568749	train-auc:0.888739	train-mae:0.001798	train-map:1	train-rmse:0.007093
# [132]	eval-aucpr:0.396875	eval-auc:0.865451	eval-mae:0.032485	eval-map:1	eval-rmse:0.070686	train-aucpr:0.56875	train-auc:0.888741	train-mae:0.001781	train-map:1	train-rmse:0.007083
# [133]	eval-aucpr:0.396855	eval-auc:0.865465	eval-mae:0.032528	eval-map:1	eval-rmse:0.070761	train-aucpr:0.568751	train-auc:0.888742	train-mae:0.001742	train-map:1	train-rmse:0.007053
# [134]	eval-aucpr:0.396846	eval-auc:0.865402	eval-mae:0.032625	eval-map:1	eval-rmse:0.070763	train-aucpr:0.568755	train-auc:0.888744	train-mae:0.001714	train-map:1	train-rmse:0.00703
# [135]	eval-aucpr:0.396526	eval-auc:0.8653	eval-mae:0.032605	eval-map:1	eval-rmse:0.070768	train-aucpr:0.568756	train-auc:0.888744	train-mae:0.001693	train-map:1	train-rmse:0.007017
# [136]	eval-aucpr:0.396506	eval-auc:0.865202	eval-mae:0.032664	eval-map:1	eval-rmse:0.070792	train-aucpr:0.568756	train-auc:0.888746	train-mae:0.001671	train-map:1	train-rmse:0.007008
# [137]	eval-aucpr:0.396506	eval-auc:0.865202	eval-mae:0.032663	eval-map:1	eval-rmse:0.070792	train-aucpr:0.568756	train-auc:0.888746	train-mae:0.00167	train-map:1	train-rmse:0.007008
# [138]	eval-aucpr:0.396506	eval-auc:0.865202	eval-mae:0.032663	eval-map:1	eval-rmse:0.070792	train-aucpr:0.568756	train-auc:0.888746	train-mae:0.00167	train-map:1	train-rmse:0.007008
# [139]	eval-aucpr:0.396506	eval-auc:0.865202	eval-mae:0.032662	eval-map:1	eval-rmse:0.070792	train-aucpr:0.568756	train-auc:0.888746	train-mae:0.00167	train-map:1	train-rmse:0.007008
# [140]	eval-aucpr:0.396506	eval-auc:0.865202	eval-mae:0.032662	eval-map:1	eval-rmse:0.070792	train-aucpr:0.568756	train-auc:0.888746	train-mae:0.00167	train-map:1	train-rmse:0.007008
# [141]	eval-aucpr:0.396506	eval-auc:0.865202	eval-mae:0.032662	eval-map:1	eval-rmse:0.070792	train-aucpr:0.568756	train-auc:0.888746	train-mae:0.00167	train-map:1	train-rmse:0.007008
# [142]	eval-aucpr:0.396506	eval-auc:0.865202	eval-mae:0.032662	eval-map:1	eval-rmse:0.070792	train-aucpr:0.568756	train-auc:0.888746	train-mae:0.00167	train-map:1	train-rmse:0.007008
# [143]	eval-aucpr:0.396506	eval-auc:0.865202	eval-mae:0.032662	eval-map:1	eval-rmse:0.070792	train-aucpr:0.568756	train-auc:0.888746	train-mae:0.00167	train-map:1	train-rmse:0.007008
# [144]	eval-aucpr:0.396506	eval-auc:0.865202	eval-mae:0.032662	eval-map:1	eval-rmse:0.070792	train-aucpr:0.568756	train-auc:0.888746	train-mae:0.00167	train-map:1	train-rmse:0.007008
# [145]	eval-aucpr:0.396506	eval-auc:0.865202	eval-mae:0.032662	eval-map:1	eval-rmse:0.070792	train-aucpr:0.568756	train-auc:0.888746	train-mae:0.00167	train-map:1	train-rmse:0.007008
# [146]	eval-aucpr:0.396506	eval-auc:0.865202	eval-mae:0.032662	eval-map:1	eval-rmse:0.070792	train-aucpr:0.568756	train-auc:0.888746	train-mae:0.00167	train-map:1	train-rmse:0.007008
# Stopping. Best iteration:
# [136]	eval-aucpr:0.396506	eval-auc:0.865202	eval-mae:0.032664	eval-map:1	eval-rmse:0.070792	train-aucpr:0.568756	train-auc:0.888746	train-mae:0.001671	train-map:1	train-rmse:0.007008

# %%
# save to binary file for faster loading
bst.save_model('cross.substrate.train.neil1.and.ajuba.substrates.model')
# save model to text file 
bst.dump_model('cross.substrate.train.neil1.and.ajuba.substrates.txt')

# %%
## get model predictions on the test, training, and eval splits 
test_pred = bst.predict(dtest)
train_pred=bst.predict(dtrain)
eval_pred=bst.predict(deval)

# %%
## Get performance metrics on full dataset 
from helpers import * 
print_aggregate_peformance_metrics(train_y,train_pred,
                                   eval_y,eval_pred,
                                   test_y,test_pred,
                                   positive_thresh=0.2)
# Out:
# Train
# 	Spearman corr : SpearmanrResult(correlation=0.9989671086763009, pvalue=0.0)
# 	Pearson corr : (0.9994274699406372, 0.0)
# 	MAE : 0.0016700949799981735
# 	MAPE : 0.02490899330107031
# 	RMSE : 0.007008358901444726
# 	auPRC : 0.999017378474429
# 	auROC : 0.9994147916456463
# Eval
# 	Spearman corr : SpearmanrResult(correlation=0.9036737601643081, pvalue=3.144391807347307e-58)
# 	Pearson corr : (0.9030297303281264, 5.104936867328688e-58)
# 	MAE : 0.03266214355219516
# 	MAPE : 0.408172131473209
# 	RMSE : 0.07079179577154025
# 	auPRC : 0.8434206100943588
# 	auROC : 0.9749333333333334
# Test
# 	Spearman corr : SpearmanrResult(correlation=0.09243475141790299, pvalue=0.02343903915905631)
# 	Pearson corr : (0.03185500751633759, 0.4356810294398824)
# 	MAE : 0.19743490240458839
# 	MAPE : 3.464810575185141
# 	RMSE : 0.247483464923803
# 	auPRC : 0.3976736257522886
# 	auROC : 0.5453899718204895

# %%
## Correlation values 
from scipy.stats import spearmanr,pearsonr
spearman_train=spearmanr(train_y,train_pred)
spearman_eval=spearmanr(eval_y,eval_pred)
spearman_test=spearmanr(test_y,test_pred)

pearson_train=pearsonr(train_y,train_pred)
pearson_eval=pearsonr(eval_y,eval_pred)
pearson_test=pearsonr(test_y,test_pred)

print("Spearman correlation:")
print("Train:"+str(spearman_train))
print("Eval:"+str(spearman_eval))
print("Test:"+str(spearman_test))
print("\n")
print("Pearson correlation:")
print("Train:"+str(pearson_train))
print("Eval:"+str(pearson_eval))
print("Test:"+str(pearson_test))
# Out:
# Spearman correlation:
# Train:SpearmanrResult(correlation=0.9989671086763009, pvalue=0.0)
# Eval:SpearmanrResult(correlation=0.9036737601643081, pvalue=3.144391807347307e-58)
# Test:SpearmanrResult(correlation=0.09243475141790299, pvalue=0.02343903915905631)
#
#
# Pearson correlation:
# Train:(0.9994274699406372, 0.0)
# Eval:(0.9030297303281264, 5.104936867328688e-58)
# Test:(0.03185500751633759, 0.4356810294398824)

# %%
## MAE
from sklearn.metrics import mean_absolute_error
mae_train=mean_absolute_error(train_y,train_pred)
print("MAE Train:"+str(mae_train))

mae_eval=mean_absolute_error(eval_y,eval_pred)
print("MAE Eval:"+str(mae_eval))

mae_test=mean_absolute_error(test_y,test_pred)
print("MAE Test:"+str(mae_test))
# Out:
# MAE Train:0.0016700949799981735
# MAE Eval:0.03266214355219516
# MAE Test:0.19743490240458839

# %%
## MAPE
pseudocount=0.01
mape_train=np.mean(np.abs((train_y - train_pred) /(pseudocount+train_y))) * 100
print("MAPE Train:"+str(mape_train)+"%")

mape_eval=np.mean(np.abs((eval_y - eval_pred) /(pseudocount+eval_y))) * 100
print("MAPE Eval:"+str(mape_eval)+"%")

mape_test=np.mean(np.abs((test_y - test_pred) /(pseudocount+test_y))) * 100
print("MAPE Test:"+str(mape_test)+"%")
# Out:
# MAPE Train:2.490899330107031%
# MAPE Eval:40.8172131473209%
# MAPE Test:346.4810575185141%

# %%
## RMSE
from sklearn.metrics import mean_squared_error
import math 
rmse_train=math.sqrt(mean_squared_error(train_y,train_pred))
print("RMSE Train:"+str(rmse_train))

rmse_eval=math.sqrt(mean_squared_error(eval_y,eval_pred))
print("RMSE Eval:"+str(rmse_eval))

rmse_test=math.sqrt(mean_squared_error(test_y,test_pred))
print("RMSE Test:"+str(rmse_test))
# Out:
# RMSE Train:0.007008358901444726
# RMSE Eval:0.07079179577154025
# RMSE Test:0.247483464923803

# %%
## PRC 
## PRC only valid for binary outcomes. 
## Editing levels < 0.5 are labeled as "0". 
## Editing levels >= 0.5 are labeled as "1". 

from sklearn.metrics import auc, precision_recall_curve

precision_train,recall_train,prc_thresholds_train=precision_recall_curve(train_y>=0.4,train_pred)
precision_eval,recall_eval,prc_thresholds_eval=precision_recall_curve(eval_y>=0.4,eval_pred)
precision_test,recall_test,prc_thresholds_test=precision_recall_curve(test_y>=0.2,test_pred)

auprc_train=auc(recall_train,precision_train)
auprc_eval=auc(recall_eval,precision_eval)
auprc_test=auc(recall_test,precision_test)

plt.plot(recall_train,precision_train,'r',label="Train:"+str(round(auprc_train,2)))
plt.plot(recall_eval,precision_eval,'g',label="Eval:"+str(round(auprc_eval,2)))
plt.plot(recall_test,precision_test,'b',label="Test:"+str(round(auprc_test,2)))
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("PRC")
plt.legend()

# %%
## ROC
from sklearn.metrics import roc_curve, roc_auc_score
fpr_train,tpr_train,roc_thresholds_train=roc_curve(train_y>=0.4,train_pred)
fpr_eval,tpr_eval,roc_thresholds_eval=roc_curve(eval_y>=0.4,eval_pred)
fpr_test,tpr_test,roc_thresholds_test=roc_curve(test_y>=0.2,test_pred)

auroc_train=roc_auc_score(train_y>=0.4,train_pred)
auroc_eval=roc_auc_score(eval_y>=0.4,eval_pred)
auroc_test=roc_auc_score(test_y>=0.2,test_pred)

plt.plot(fpr_train,tpr_train,'r',label="Train:"+str(round(auroc_train,2)))
plt.plot(fpr_eval,tpr_eval,'g',label="Eval:"+str(round(auroc_eval,2)))
plt.plot(fpr_test,tpr_test,'b',label="Test:"+str(round(auroc_test,2)))
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC")
plt.legend()

# %%
#calculate R^2, which is representative of variance explained 
# https://datascienceplus.com/extreme-gradient-boosting-with-r/
# https://arxiv.org/pdf/1706.06060.pdf

residuals = test_y - test_pred

y_test_mean = np.mean(test_pred)
print(y_test_mean)
#calculate total sum of squares 
tss=sum((test_y-y_test_mean)*(test_y-y_test_mean))
print(tss)
# Calculate residual sum of squares
rss =  sum(residuals*residuals)
print(rss)
# Calculate R-squared
rsq  =  1 - (rss/tss)
print('The R-square of the test data is ', round(rsq,3), '\n')
# Out:
# 0.23026101
# 13.605637860682634
# 36.81008731182538
# The R-square of the test data is  -1.706

# %%
#plot the test set predictions 
matplotlib.rcParams['figure.figsize'] = [20, 8]
plt.subplot(1,3,1)
plt.plot(list(train_y),list(train_pred),'o')
plt.xlabel("Observed train set editing level, Neil 1 Comp + AJUBA Comp")
plt.ylabel("Predicted train set editing level, Neil 1 Comp + AJUBA Comp")
plt.subplot(1,3,2)
plt.plot(list(eval_y),list(eval_pred),'o')
plt.xlabel("Observed eval set editing level, Neil 1 Comp + AJUBA Comp")
plt.ylabel("Predicted eval set editing level, Neil 1 Comp + AJUBA Comp")
plt.subplot(1,3,3)
plt.plot(list(test_y),list(test_pred),'o')
plt.xlabel("Observed test set editing level, TTYH2 Comp")
plt.ylabel("Predicted test set editing level, TTYH2 Comp")

plt.show()

# %%
matplotlib.rcParams['figure.figsize'] = [20, 30]
xgboost.plot_importance(bst)

# %%
#xgboost.to_graphviz(bst, num_trees=2)

# %%
# explain the model's predictions using SHAP values
explainer = shap.TreeExplainer(bst)
shap_values = explainer.shap_values(test_X)
shap_values.shape

# %%
test_y=pd.DataFrame(test_y)
max_index=test_y.index[test_y['editing_value'] == max(test_y['editing_value'])]
max_row=test_y.index.get_loc(max_index[0])
# visualize prediction for isoform with the highest editing level 
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[max_row,:], test_X.iloc[max_row,:])

# %%
# visualize prediction for isoform with the lowest editing level 
shap.initjs()
min_index=test_y.index[test_y['editing_value'] == min(test_y['editing_value'])]
min_row=test_y.index.get_loc(min_index[0])
shap.force_plot(explainer.expected_value, shap_values[min_row,:], test_X.iloc[min_row,:])

# %%
# visualize the training set predictions
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values,train_X)

# %%
# summarize the effect of all the features 
shap.summary_plot(shap_values, test_X)

# %%
# We can also just take the mean absolute value of the SHAP values for each feature 
# to get a standard bar plot (produces stacked bars for multi-class outputs):
shap.summary_plot(shap_values, test_X, plot_type="bar")

# %%
## Compute pairwise interaction values from TreeShap
shap_interaction_values=explainer.shap_interaction_values(test_X)
shap_interaction_values.shape

# %%
##Average interaction values across the datapoints in the test set 
mean_interaction_values=np.mean(shap_interaction_values,axis=0)

# %%
Index=test_X.columns
Cols=test_X.columns
mean_interaction_values_df = pd.DataFrame(mean_interaction_values, index=Index, columns=Cols)

# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
configure_plotly_browser_state()

trace = Heatmap(z=mean_interaction_values_df.values,
                   x=Cols,
                   y=Index)
iplot([trace],show_link=False)
